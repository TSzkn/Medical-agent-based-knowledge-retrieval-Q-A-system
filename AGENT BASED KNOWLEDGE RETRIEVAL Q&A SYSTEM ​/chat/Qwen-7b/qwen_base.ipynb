# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ##0. set up the environment

# %%
# !pip install --upgrade datasets
# !pip install py7zr
# !pip install xformers
# !pip install accelerate
# !pip install -i https://pypi.org/simple/ bitsandbytes
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 542.0/542.0 kB 4.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 18.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 23.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 20.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 401.2/401.2 kB 26.4 MB/s eta 0:00:00
# ...
#   Attempting uninstall: huggingface-hub
#     Found existing installation: huggingface-hub 0.20.3
#     Uninstalling huggingface-hub-0.20.3:
#       Successfully uninstalled huggingface-hub-0.20.3
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.6/67.6 kB 1.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 14.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 411.2/411.2 kB 45.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 138.9/138.9 kB 19.7 MB/s eta 0:00:00
# ...

# %%
pip install tiktoken
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 8.4 MB/s eta 0:00:00
# ...

# %%
pip install einops transformers_stream_generator
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.2/43.2 kB 814.1 kB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for transformers_stream_generator: filename=transformers_stream_generator-0.0.5-py3-none-any.whl size=12425 sha256=eeebe49cf9913b5f1e47c495f252769561a977d0badf5babd4bb1306fc3c2a9b
#   Stored in directory: /root/.cache/pip/wheels/95/4a/90/140f7b67d125906f6a165f38aad212ecb4a695ad0d87582437
# Successfully built transformers_stream_generator
# ...

# %%
pip install modelscope
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.7/5.7 MB 19.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 510.5/510.5 kB 49.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 283.4/283.4 kB 35.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.9/137.9 kB 18.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 254.7/254.7 kB 31.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.7/89.7 kB 14.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 83.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.0/94.0 kB 15.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 443.1/443.1 kB 51.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...

# %%
pip install optimum
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 417.0/417.0 kB 3.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 7.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 13.5 MB/s eta 0:00:00
# ...

# %%
pip install auto-gptq
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.5/23.5 MB 41.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.2/13.2 MB 43.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.1/199.1 kB 27.2 MB/s eta 0:00:00
# ...

# %%
pip install mpi4py -i http://pypi.doubanio.com/simple/ --trusted-host pypi.doubanio.com
# Out:
# Looking in indexes: http://pypi.doubanio.com/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 7.7 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Created wheel for mpi4py: filename=mpi4py-3.1.6-cp310-cp310-linux_x86_64.whl size=2746286 sha256=e3f48b75d621b6089c6d5104514e6242ff3ca610786201d61c7a5fd91c36a2f0
#   Stored in directory: /root/.cache/pip/wheels/9a/2c/04/4adce2d6536f60615441034c8eb87f7fb7910926fd92d4fe50
# Successfully built mpi4py
# ...

# %%
pip install "peft<0.8.0" deepspeed
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 168.3/168.3 kB 2.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 14.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.0/54.0 kB 7.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 307.2/307.2 kB 38.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.1/53.1 kB 8.0 MB/s eta 0:00:00
# ...
#   Created wheel for deepspeed: filename=deepspeed-0.14.2-py3-none-any.whl size=1432243 sha256=04cff3e1cfafc69d5bf4f85c5f2989ec7667e5fe36f96fff3725cdfbb840e150
#   Stored in directory: /root/.cache/pip/wheels/ea/7c/43/bed44d8414c099ff962b754f425f7ff77cc623cc8a98e0da70
# Successfully built deepspeed
# ...
#   Attempting uninstall: peft
#     Found existing installation: peft 0.10.0
#     Uninstalling peft-0.10.0:
#       Successfully uninstalled peft-0.10.0
# ...

# %% [markdown]
# ## load base model

# %%
import os
os.environ["MODELSCOPE_CACHE"] = "/content/drive/MyDrive/5004_rag/5005/model"

# %%
from modelscope import snapshot_download
from transformers import AutoModelForCausalLM, AutoTokenizer

# Downloading model checkpoint to a local dir model_dir
# model_dir = snapshot_download('qwen/Qwen-7B')
# model_dir = snapshot_download('qwen/Qwen-7B-Chat')
# model_dir = snapshot_download('qwen/Qwen-14B')
model_dir = snapshot_download('qwen/Qwen-7B-Chat-Int4')

# Loading local checkpoints
# trust_remote_code is still set as True since we still load codes from local dir instead of transformers
tokenizer = AutoTokenizer.from_pretrained(model_dir, trust_remote_code=True)
model = AutoModelForCausalLM.from_pretrained(
    model_dir,
    device_map="auto",
    trust_remote_code=True
).eval()
# Out:
# 2024-05-04 05:57:09,947 - modelscope - INFO - PyTorch version 2.3.0 Found.
# 2024-05-04 05:57:09,952 - modelscope - INFO - TensorFlow version 2.15.0 Found.
# 2024-05-04 05:57:09,953 - modelscope - INFO - Loading ast index from /content/drive/MyDrive/5004_rag/5005/model/ast_indexer
# 2024-05-04 05:57:09,955 - modelscope - INFO - No valid ast index found from /content/drive/MyDrive/5004_rag/5005/model/ast_indexer, generating ast index from prebuilt!
# 2024-05-04 05:57:10,031 - modelscope - INFO - Loading done! Current index file version is 1.14.0, with md5 61ef63cbff18305e222a69b9a5f592d3 and a total number of 976 components indexed
# 2024-05-04 05:57:13,642 - modelscope - WARNING - Model revision not specified, use revision: v1.1.8
# Downloading: 100%|██████████| 8.21k/8.21k [00:00<00:00, 10.9MB/s]
# Downloading: 100%|██████████| 50.8k/50.8k [00:00<00:00, 367kB/s]
# Downloading: 100%|██████████| 1.17k/1.17k [00:00<00:00, 5.02MB/s]
# ...

# %%
import sys
sys.path.append('/content/drive/MyDrive/5004_rag/5005/model/qwen/Qwen-7B-Chat-Int4')

# %%
import torch
from transformers import AutoModelForCausalLM, AutoTokenizer
from transformers import GenerationConfig
from qwen_generation_utils import make_context, decode_tokens, get_stop_words_ids

tokenizer = AutoTokenizer.from_pretrained(
    'qwen/Qwen-7B-Chat-Int4',
    pad_token='<|extra_0|>',
    eos_token='<|endoftext|>',
    padding_side='left',
    trust_remote_code=True
)
model = AutoModelForCausalLM.from_pretrained(
    'qwen/Qwen-7B-Chat-Int4',
    pad_token_id=tokenizer.pad_token_id,
    device_map="auto",
    trust_remote_code=True
).eval()

# %% [markdown]
# ## Batch Inference

# %%
model.generation_config = GenerationConfig.from_pretrained('qwen/Qwen-7B-Chat-Int4', pad_token_id=tokenizer.pad_token_id)
model.generation_config.top_p = 0.01 #refuse model to generate randomly
model.generation_config.temperature = 0.2 #refuse model to generate randomly

# %%
def generate_prompt(input):
  prompt_template = f"""
    分析用户是不是病人。如果是病人，他会询问如何治疗某种疾病.
    请根据不同的用户类型回答下面的问题

    交互格式如下：
    问题:用户提出的问题，如何治疗某种疾病或者其他类型问题
    回答:判断用户是不是病人,如果是病人,根据用户提出的问题，进行回答.如果不是,直接输出'查询数据库'

    现在开始：
    问题:{input}
    回答:
  """
  return prompt_template


# Qwen SFT traing foramt:

# [
#   {
#     "id": "identity_0",
#     "conversations": [
#       {
#         "from": "user",
#         "value": ""
#       },
#       {
#         "from": "assistant",
#         "value": ""
#       }
#     ]
#   }
# ]

# %%
import pandas as pd
test = pd.read_json('/content/drive/MyDrive/ISS/5005/finetuning/test.json',lines = True)
test

# %%
response,_ = model.chat(tokenizer,generate_prompt('十分的不舒服，总是难受，想知道牙龈出血一个月不痛有口臭怎么回事？'),history = None)
response
# Out:
# '是的，这位用户可能是病人，他可能正在经历口腔健康问题。\n 建议这位用户去看牙医进行检查和诊断，以了解具体的原因并得到相应的治疗建议。同时，他也需要注意口腔卫生，定期刷牙、使用牙线和漱口水，并避免吃过于刺激性的食物。如果他的症状持续存在或者加重，应该立即寻求医疗帮助。'

# %%
response,_ = model.chat(tokenizer,generate_prompt('精神分裂症导致什么后果？'),history = None)
response
# Out:
# "用户不是病人，直接输出'查询数据库'。"

# %%
for index,row in test.iterrows():
  row['ask'] = generate_prompt(row['ask'])
all_row_text = test['ask'].tolist()

# %%
small_lists = [all_row_text[i:i+10] for i in range(0, len(all_row_text), 10)]

big_list = []
for small_list in small_lists:
    big_list.append(small_list)

# %%
def batch_generate(small_list):
  batch_raw_text = []
  for q in small_list:
      raw_text, _ = make_context(
          tokenizer,
          q,
          system="You are a helpful assistant for medical area.",
          max_window_size=model.generation_config.max_window_size,
          chat_format=model.generation_config.chat_format,
      )
      batch_raw_text.append(raw_text)
  return batch_raw_text

# %%
from tqdm import tqdm

#each batch contains 10 samples
batch_response_list = []

for j in tqdm(range(len(big_list)), desc="Processing batches"):

    batch_raw_text = batch_generate(big_list[j])
    batch_input_ids = tokenizer(batch_raw_text, padding='longest')
    batch_input_ids = torch.LongTensor(batch_input_ids['input_ids']).to(model.device)
    batch_out_ids = model.generate(
        input_ids=batch_input_ids,
        return_dict_in_generate=False,
        generation_config=model.generation_config
    )
    padding_lens = [batch_input_ids[i].eq(tokenizer.pad_token_id).sum().item() for i in range(batch_input_ids.size(0))]
    # print(padding_lens)
    # print(batch_out_ids.shape)
    batch_response = [
        decode_tokens(
            batch_out_ids[i][padding_lens[i]:],
            tokenizer,
            raw_text_len=len(batch_raw_text[i]),
            context_length=(batch_input_ids[i].size(0) - padding_lens[i]),
            chat_format="chatml",
            verbose=False,
            errors='replace'
        ) for i in range(len(batch_raw_text))
    ]
    batch_response_list.append(batch_response)

# %%
len(batch_response_list)

# %%
prediction = []
for i in range(len(batch_response_list)):
  for j in range(len(batch_response_list[i])):
    prediction.append(batch_response_list[i][j])

# %%
prediction = pd.DataFrame(prediction,columns = ['prediction_base'])

# %%
prediction_base = pd.merge(
    test,
    prediction,
    left_index = True,
    right_index = True
)

# %%
prediction_base.to_json('/content/drive/MyDrive/ISS/5005/finetuning/prediction_base.json',force_ascii=False, orient='records', lines=True)

# %%
df_loaded = pd.read_json('/content/drive/MyDrive/ISS/5005/finetuning/prediction_base.json', lines=True)
df_loaded
