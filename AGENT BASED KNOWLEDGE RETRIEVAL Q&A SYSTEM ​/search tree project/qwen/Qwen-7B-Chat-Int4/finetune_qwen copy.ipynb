# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## 0.set up environment

# %%
# !pip install py7zr
#!pip install xformers
# !pip install accelerate
# !pip install -i https://pypi.org/simple/ bitsandbytes
# Out:
# Collecting py7zr
#   Downloading py7zr-0.21.0-py3-none-any.whl (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.6/67.6 kB 2.7 MB/s eta 0:00:00
# Collecting texttable (from py7zr)
#   Downloading texttable-1.7.0-py2.py3-none-any.whl (10 kB)
# Collecting pycryptodomex>=3.16.0 (from py7zr)
#   Downloading pycryptodomex-3.20.0-cp35-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 14.3 MB/s eta 0:00:00
# Collecting pyzstd>=0.15.9 (from py7zr)
#   Downloading pyzstd-0.15.10-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (411 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 411.2/411.2 kB 19.4 MB/s eta 0:00:00
# Collecting pyppmd<1.2.0,>=1.1.0 (from py7zr)
#   Downloading pyppmd-1.1.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (138 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 138.9/138.9 kB 18.0 MB/s eta 0:00:00
# Collecting pybcj<1.1.0,>=1.0.0 (from py7zr)
#   Downloading pybcj-1.0.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (49 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.7/49.7 kB 7.3 MB/s eta 0:00:00
# Collecting multivolumefile>=0.2.3 (from py7zr)
#   Downloading multivolumefile-0.2.3-py3-none-any.whl (17 kB)
# Collecting inflate64<1.1.0,>=1.0.0 (from py7zr)
#   Downloading inflate64-1.0.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (93 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.1/93.1 kB 13.5 MB/s eta 0:00:00
# Collecting brotli>=1.1.0 (from py7zr)
#   Downloading Brotli-1.1.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (3.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 30.5 MB/s eta 0:00:00
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from py7zr) (5.9.5)
# Installing collected packages: texttable, brotli, pyzstd, pyppmd, pycryptodomex, pybcj, multivolumefile, inflate64, py7zr
# Successfully installed brotli-1.1.0 inflate64-1.0.0 multivolumefile-0.2.3 py7zr-0.21.0 pybcj-1.0.2 pycryptodomex-3.20.0 pyppmd-1.1.0 pyzstd-0.15.10 texttable-1.7.0
# Collecting accelerate
#   Downloading accelerate-0.29.3-py3-none-any.whl (297 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 297.6/297.6 kB 6.9 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from accelerate) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from accelerate) (24.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from accelerate) (6.0.1)
# Requirement already satisfied: torch>=1.10.0 in /usr/local/lib/python3.10/dist-packages (from accelerate) (2.2.1+cu121)
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.10/dist-packages (from accelerate) (0.20.3)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from accelerate) (0.4.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (3.13.4)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (4.11.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (3.1.3)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (2023.6.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch>=1.10.0->accelerate)
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch>=1.10.0->accelerate)
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch>=1.10.0->accelerate)
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch>=1.10.0->accelerate)
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch>=1.10.0->accelerate)
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch>=1.10.0->accelerate)
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch>=1.10.0->accelerate)
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch>=1.10.0->accelerate)
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch>=1.10.0->accelerate)
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# Collecting nvidia-nccl-cu12==2.19.3 (from torch>=1.10.0->accelerate)
#   Using cached nvidia_nccl_cu12-2.19.3-py3-none-manylinux1_x86_64.whl (166.0 MB)
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch>=1.10.0->accelerate)
#   Using cached nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
# Requirement already satisfied: triton==2.2.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (2.2.0)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.10.0->accelerate)
#   Using cached nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->accelerate) (2.31.0)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->accelerate) (4.66.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.10.0->accelerate) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate) (2024.2.2)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.10.0->accelerate) (1.3.0)
# Installing collected packages: nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, accelerate
# Successfully installed accelerate-0.29.3 nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.19.3 nvidia-nvjitlink-cu12-12.4.127 nvidia-nvtx-cu12-12.1.105
# Looking in indexes: https://pypi.org/simple/
# Collecting bitsandbytes
#   Downloading bitsandbytes-0.43.1-py3-none-manylinux_2_24_x86_64.whl (119.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 119.8/119.8 MB 14.7 MB/s eta 0:00:00
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from bitsandbytes) (2.2.1+cu121)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from bitsandbytes) (1.25.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes) (3.13.4)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes) (4.11.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes) (3.1.3)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes) (2023.6.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.19.3 in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes) (2.19.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes) (12.1.105)
# Requirement already satisfied: triton==2.2.0 in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes) (2.2.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.10/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch->bitsandbytes) (12.4.127)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->bitsandbytes) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch->bitsandbytes) (1.3.0)
# Installing collected packages: bitsandbytes
# Successfully installed bitsandbytes-0.43.1

# %%
pip install tiktoken
# !pip install py7zr
#!pip install xformers
# !pip install accelerate
# !pip install -i https://pypi.org/simple/ bitsandbytes
# Out:
# Collecting tiktoken
#   Downloading tiktoken-0.6.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 13.0 MB/s eta 0:00:00
# Requirement already satisfied: regex>=2022.1.18 in /usr/local/lib/python3.10/dist-packages (from tiktoken) (2023.12.25)
# Requirement already satisfied: requests>=2.26.0 in /usr/local/lib/python3.10/dist-packages (from tiktoken) (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->tiktoken) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->tiktoken) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->tiktoken) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->tiktoken) (2024.2.2)
# Installing collected packages: tiktoken
# Successfully installed tiktoken-0.6.0

# %%
pip install einops transformers_stream_generator
pip install tiktoken
# !pip install py7zr
#!pip install xformers
# !pip install accelerate
# !pip install -i https://pypi.org/simple/ bitsandbytes
# Out:
# Collecting einops
#   Downloading einops-0.8.0-py3-none-any.whl (43 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.2/43.2 kB 1.8 MB/s eta 0:00:00
# Collecting transformers_stream_generator
#   Downloading transformers-stream-generator-0.0.5.tar.gz (13 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: transformers>=4.26.1 in /usr/local/lib/python3.10/dist-packages (from transformers_stream_generator) (4.40.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers>=4.26.1->transformers_stream_generator) (3.13.4)
# Requirement already satisfied: huggingface-hub<1.0,>=0.19.3 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.26.1->transformers_stream_generator) (0.20.3)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.26.1->transformers_stream_generator) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.26.1->transformers_stream_generator) (24.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.26.1->transformers_stream_generator) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.26.1->transformers_stream_generator) (2023.12.25)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers>=4.26.1->transformers_stream_generator) (2.31.0)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.26.1->transformers_stream_generator) (0.19.1)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.26.1->transformers_stream_generator) (0.4.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.26.1->transformers_stream_generator) (4.66.2)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.19.3->transformers>=4.26.1->transformers_stream_generator) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.19.3->transformers>=4.26.1->transformers_stream_generator) (4.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers>=4.26.1->transformers_stream_generator) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers>=4.26.1->transformers_stream_generator) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers>=4.26.1->transformers_stream_generator) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers>=4.26.1->transformers_stream_generator) (2024.2.2)
# Building wheels for collected packages: transformers_stream_generator
#   Building wheel for transformers_stream_generator (setup.py) ... done
#   Created wheel for transformers_stream_generator: filename=transformers_stream_generator-0.0.5-py3-none-any.whl size=12425 sha256=35d167f7dcbd6c5727a87cf9b9b6c241df345df7f98d40fee901bd0edaa7cb2b
#   Stored in directory: /root/.cache/pip/wheels/95/4a/90/140f7b67d125906f6a165f38aad212ecb4a695ad0d87582437
# Successfully built transformers_stream_generator
# Installing collected packages: einops, transformers_stream_generator
# Successfully installed einops-0.8.0 transformers_stream_generator-0.0.5

# %%
pip install modelscope
pip install einops transformers_stream_generator
pip install tiktoken
# !pip install py7zr
#!pip install xformers
# !pip install accelerate
# !pip install -i https://pypi.org/simple/ bitsandbytes
# Out:
# Collecting modelscope
#   Downloading modelscope-1.14.0-py3-none-any.whl (5.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.7/5.7 MB 23.7 MB/s eta 0:00:00
# Collecting addict (from modelscope)
#   Downloading addict-2.4.0-py3-none-any.whl (3.8 kB)
# Requirement already satisfied: attrs in /usr/local/lib/python3.10/dist-packages (from modelscope) (23.2.0)
# Collecting datasets<2.19.0,>=2.16.0 (from modelscope)
#   Downloading datasets-2.18.0-py3-none-any.whl (510 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 510.5/510.5 kB 32.6 MB/s eta 0:00:00
# Requirement already satisfied: einops in /usr/local/lib/python3.10/dist-packages (from modelscope) (0.8.0)
# Requirement already satisfied: filelock>=3.3.0 in /usr/local/lib/python3.10/dist-packages (from modelscope) (3.13.4)
# Requirement already satisfied: gast>=0.2.2 in /usr/local/lib/python3.10/dist-packages (from modelscope) (0.5.4)
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.10/dist-packages (from modelscope) (0.20.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from modelscope) (1.25.2)
# Collecting oss2 (from modelscope)
#   Downloading oss2-2.18.5.tar.gz (283 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 283.4/283.4 kB 34.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from modelscope) (2.0.3)
# Requirement already satisfied: Pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from modelscope) (9.4.0)
# Requirement already satisfied: pyarrow!=9.0.0,>=6.0.0 in /usr/local/lib/python3.10/dist-packages (from modelscope) (14.0.2)
# Requirement already satisfied: python-dateutil>=2.1 in /usr/local/lib/python3.10/dist-packages (from modelscope) (2.8.2)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from modelscope) (6.0.1)
# Requirement already satisfied: requests>=2.25 in /usr/local/lib/python3.10/dist-packages (from modelscope) (2.31.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from modelscope) (1.11.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from modelscope) (67.7.2)
# Collecting simplejson>=3.3.0 (from modelscope)
#   Downloading simplejson-3.19.2-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (137 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.9/137.9 kB 19.6 MB/s eta 0:00:00
# Requirement already satisfied: sortedcontainers>=1.5.9 in /usr/local/lib/python3.10/dist-packages (from modelscope) (2.4.0)
# Requirement already satisfied: tqdm>=4.64.0 in /usr/local/lib/python3.10/dist-packages (from modelscope) (4.66.2)
# Requirement already satisfied: urllib3>=1.26 in /usr/local/lib/python3.10/dist-packages (from modelscope) (2.0.7)
# Collecting yapf (from modelscope)
#   Downloading yapf-0.40.2-py3-none-any.whl (254 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 254.7/254.7 kB 31.3 MB/s eta 0:00:00
# Requirement already satisfied: pyarrow-hotfix in /usr/local/lib/python3.10/dist-packages (from datasets<2.19.0,>=2.16.0->modelscope) (0.6)
# Collecting dill<0.3.9,>=0.3.0 (from datasets<2.19.0,>=2.16.0->modelscope)
#   Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 17.5 MB/s eta 0:00:00
# Collecting xxhash (from datasets<2.19.0,>=2.16.0->modelscope)
#   Downloading xxhash-3.4.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 25.6 MB/s eta 0:00:00
# Collecting multiprocess (from datasets<2.19.0,>=2.16.0->modelscope)
#   Downloading multiprocess-0.70.16-py310-none-any.whl (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 19.9 MB/s eta 0:00:00
# Requirement already satisfied: fsspec[http]<=2024.2.0,>=2023.1.0 in /usr/local/lib/python3.10/dist-packages (from datasets<2.19.0,>=2.16.0->modelscope) (2023.6.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets<2.19.0,>=2.16.0->modelscope) (3.9.5)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from datasets<2.19.0,>=2.16.0->modelscope) (24.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->modelscope) (4.11.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.1->modelscope) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.25->modelscope) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.25->modelscope) (3.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.25->modelscope) (2024.2.2)
# Collecting crcmod>=1.7 (from oss2->modelscope)
#   Downloading crcmod-1.7.tar.gz (89 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.7/89.7 kB 13.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting pycryptodome>=3.4.7 (from oss2->modelscope)
#   Downloading pycryptodome-3.20.0-cp35-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 41.8 MB/s eta 0:00:00
# Collecting aliyun-python-sdk-kms>=2.4.1 (from oss2->modelscope)
#   Downloading aliyun_python_sdk_kms-2.16.2-py2.py3-none-any.whl (94 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.0/94.0 kB 13.6 MB/s eta 0:00:00
# Collecting aliyun-python-sdk-core>=2.13.12 (from oss2->modelscope)
#   Downloading aliyun-python-sdk-core-2.15.1.tar.gz (443 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 443.1/443.1 kB 40.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->modelscope) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->modelscope) (2024.1)
# Requirement already satisfied: importlib-metadata>=6.6.0 in /usr/local/lib/python3.10/dist-packages (from yapf->modelscope) (7.1.0)
# Requirement already satisfied: platformdirs>=3.5.1 in /usr/local/lib/python3.10/dist-packages (from yapf->modelscope) (4.2.1)
# Requirement already satisfied: tomli>=2.0.1 in /usr/local/lib/python3.10/dist-packages (from yapf->modelscope) (2.0.1)
# Collecting jmespath<1.0.0,>=0.9.3 (from aliyun-python-sdk-core>=2.13.12->oss2->modelscope)
#   Downloading jmespath-0.10.0-py2.py3-none-any.whl (24 kB)
# Requirement already satisfied: cryptography>=2.6.0 in /usr/local/lib/python3.10/dist-packages (from aliyun-python-sdk-core>=2.13.12->oss2->modelscope) (42.0.5)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets<2.19.0,>=2.16.0->modelscope) (1.3.1)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets<2.19.0,>=2.16.0->modelscope) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets<2.19.0,>=2.16.0->modelscope) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets<2.19.0,>=2.16.0->modelscope) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets<2.19.0,>=2.16.0->modelscope) (4.0.3)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata>=6.6.0->yapf->modelscope) (3.18.1)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.10/dist-packages (from cryptography>=2.6.0->aliyun-python-sdk-core>=2.13.12->oss2->modelscope) (1.16.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.12->cryptography>=2.6.0->aliyun-python-sdk-core>=2.13.12->oss2->modelscope) (2.22)
# Building wheels for collected packages: oss2, aliyun-python-sdk-core, crcmod
#   Building wheel for oss2 (setup.py) ... done
#   Created wheel for oss2: filename=oss2-2.18.5-py3-none-any.whl size=118148 sha256=4be3b3492ae8d9fc85eddc72dc1a683c694ac9aa1865863bed0d03c62d35108d
#   Stored in directory: /root/.cache/pip/wheels/c5/ec/94/a908b823ad209d91fb3cb809c0553032e496dd3d36218e4596
#   Building wheel for aliyun-python-sdk-core (setup.py) ... done
#   Created wheel for aliyun-python-sdk-core: filename=aliyun_python_sdk_core-2.15.1-py3-none-any.whl size=535325 sha256=51056c537b0f6ed2546f50e3474eba2f2f0df4fda37b512f5c0684683b29cada
#   Stored in directory: /root/.cache/pip/wheels/69/4b/8e/0a28e00f4cf43b273c18cce083804738d41013e017da922ce4
#   Building wheel for crcmod (setup.py) ... done
#   Created wheel for crcmod: filename=crcmod-1.7-cp310-cp310-linux_x86_64.whl size=31409 sha256=5de4f9d2595969479f4e4da5189e505c6b855e4f258d9374b308a6eb11a0c94a
#   Stored in directory: /root/.cache/pip/wheels/85/4c/07/72215c529bd59d67e3dac29711d7aba1b692f543c808ba9e86
# Successfully built oss2 aliyun-python-sdk-core crcmod
# Installing collected packages: crcmod, addict, xxhash, simplejson, pycryptodome, jmespath, dill, yapf, multiprocess, aliyun-python-sdk-core, datasets, aliyun-python-sdk-kms, oss2, modelscope
# Successfully installed addict-2.4.0 aliyun-python-sdk-core-2.15.1 aliyun-python-sdk-kms-2.16.2 crcmod-1.7 datasets-2.18.0 dill-0.3.8 jmespath-0.10.0 modelscope-1.14.0 multiprocess-0.70.16 oss2-2.18.5 pycryptodome-3.20.0 simplejson-3.19.2 xxhash-3.4.1 yapf-0.40.2

# %%
pip install auto-gptq
pip install modelscope
pip install einops transformers_stream_generator
pip install tiktoken
# !pip install py7zr
#!pip install xformers
# !pip install accelerate
# !pip install -i https://pypi.org/simple/ bitsandbytes
# Out:
# Collecting auto-gptq
#   Downloading auto_gptq-0.7.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (23.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.5/23.5 MB 60.8 MB/s eta 0:00:00
# Requirement already satisfied: accelerate>=0.26.0 in /usr/local/lib/python3.10/dist-packages (from auto-gptq) (0.29.3)
# Requirement already satisfied: datasets in /usr/local/lib/python3.10/dist-packages (from auto-gptq) (2.18.0)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.10/dist-packages (from auto-gptq) (0.1.99)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from auto-gptq) (1.25.2)
# Collecting rouge (from auto-gptq)
#   Downloading rouge-1.0.1-py3-none-any.whl (13 kB)
# Collecting gekko (from auto-gptq)
#   Downloading gekko-1.1.1-py3-none-any.whl (13.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.2/13.2 MB 97.3 MB/s eta 0:00:00
# Requirement already satisfied: torch>=1.13.0 in /usr/local/lib/python3.10/dist-packages (from auto-gptq) (2.2.1+cu121)
# Requirement already satisfied: safetensors in /usr/local/lib/python3.10/dist-packages (from auto-gptq) (0.4.3)
# Requirement already satisfied: transformers>=4.31.0 in /usr/local/lib/python3.10/dist-packages (from auto-gptq) (4.40.1)
# Collecting peft>=0.5.0 (from auto-gptq)
#   Downloading peft-0.10.0-py3-none-any.whl (199 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.1/199.1 kB 28.2 MB/s eta 0:00:00
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from auto-gptq) (4.66.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.26.0->auto-gptq) (24.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.26.0->auto-gptq) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.26.0->auto-gptq) (6.0.1)
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.26.0->auto-gptq) (0.20.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->auto-gptq) (3.13.4)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->auto-gptq) (4.11.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->auto-gptq) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->auto-gptq) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->auto-gptq) (3.1.3)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->auto-gptq) (2023.6.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->auto-gptq) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->auto-gptq) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->auto-gptq) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->auto-gptq) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->auto-gptq) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->auto-gptq) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->auto-gptq) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->auto-gptq) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->auto-gptq) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.19.3 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->auto-gptq) (2.19.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->auto-gptq) (12.1.105)
# Requirement already satisfied: triton==2.2.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->auto-gptq) (2.2.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.10/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.13.0->auto-gptq) (12.4.127)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.31.0->auto-gptq) (2023.12.25)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers>=4.31.0->auto-gptq) (2.31.0)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.31.0->auto-gptq) (0.19.1)
# Requirement already satisfied: pyarrow>=12.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets->auto-gptq) (14.0.2)
# Requirement already satisfied: pyarrow-hotfix in /usr/local/lib/python3.10/dist-packages (from datasets->auto-gptq) (0.6)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from datasets->auto-gptq) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets->auto-gptq) (2.0.3)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from datasets->auto-gptq) (3.4.1)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.10/dist-packages (from datasets->auto-gptq) (0.70.16)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets->auto-gptq) (3.9.5)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from rouge->auto-gptq) (1.16.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->auto-gptq) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->auto-gptq) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->auto-gptq) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->auto-gptq) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->auto-gptq) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->auto-gptq) (4.0.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers>=4.31.0->auto-gptq) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers>=4.31.0->auto-gptq) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers>=4.31.0->auto-gptq) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers>=4.31.0->auto-gptq) (2024.2.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.13.0->auto-gptq) (2.1.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets->auto-gptq) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets->auto-gptq) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets->auto-gptq) (2024.1)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.13.0->auto-gptq) (1.3.0)
# Installing collected packages: rouge, gekko, peft, auto-gptq
# Successfully installed auto-gptq-0.7.1 gekko-1.1.1 peft-0.10.0 rouge-1.0.1

# %%
pip install optimum
pip install auto-gptq
pip install modelscope
pip install einops transformers_stream_generator
pip install tiktoken
# !pip install py7zr
#!pip install xformers
# !pip install accelerate
# !pip install -i https://pypi.org/simple/ bitsandbytes
# Out:
# Collecting optimum
#   Downloading optimum-1.19.1-py3-none-any.whl (417 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 417.0/417.0 kB 8.4 MB/s eta 0:00:00
# Collecting coloredlogs (from optimum)
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 6.2 MB/s eta 0:00:00
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from optimum) (1.12)
# Requirement already satisfied: transformers[sentencepiece]<4.41.0,>=4.26.0 in /usr/local/lib/python3.10/dist-packages (from optimum) (4.40.1)
# Requirement already satisfied: torch>=1.11 in /usr/local/lib/python3.10/dist-packages (from optimum) (2.2.1+cu121)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from optimum) (24.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from optimum) (1.25.2)
# Requirement already satisfied: huggingface-hub>=0.8.0 in /usr/local/lib/python3.10/dist-packages (from optimum) (0.20.3)
# Requirement already satisfied: datasets in /usr/local/lib/python3.10/dist-packages (from optimum) (2.18.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.8.0->optimum) (3.13.4)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.8.0->optimum) (2023.6.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.8.0->optimum) (2.31.0)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.8.0->optimum) (4.66.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.8.0->optimum) (6.0.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.8.0->optimum) (4.11.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.11->optimum) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11->optimum) (3.1.3)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11->optimum) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11->optimum) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11->optimum) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11->optimum) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11->optimum) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11->optimum) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11->optimum) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11->optimum) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11->optimum) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.19.3 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11->optimum) (2.19.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11->optimum) (12.1.105)
# Requirement already satisfied: triton==2.2.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11->optimum) (2.2.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.10/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.11->optimum) (12.4.127)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers[sentencepiece]<4.41.0,>=4.26.0->optimum) (2023.12.25)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers[sentencepiece]<4.41.0,>=4.26.0->optimum) (0.19.1)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers[sentencepiece]<4.41.0,>=4.26.0->optimum) (0.4.3)
# Requirement already satisfied: sentencepiece!=0.1.92,>=0.1.91 in /usr/local/lib/python3.10/dist-packages (from transformers[sentencepiece]<4.41.0,>=4.26.0->optimum) (0.1.99)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.10/dist-packages (from transformers[sentencepiece]<4.41.0,>=4.26.0->optimum) (3.20.3)
# Collecting humanfriendly>=9.1 (from coloredlogs->optimum)
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 10.9 MB/s eta 0:00:00
# Requirement already satisfied: pyarrow>=12.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets->optimum) (14.0.2)
# Requirement already satisfied: pyarrow-hotfix in /usr/local/lib/python3.10/dist-packages (from datasets->optimum) (0.6)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from datasets->optimum) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets->optimum) (2.0.3)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from datasets->optimum) (3.4.1)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.10/dist-packages (from datasets->optimum) (0.70.16)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets->optimum) (3.9.5)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->optimum) (1.3.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->optimum) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->optimum) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->optimum) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->optimum) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->optimum) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->optimum) (4.0.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.8.0->optimum) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.8.0->optimum) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.8.0->optimum) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.8.0->optimum) (2024.2.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.11->optimum) (2.1.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets->optimum) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets->optimum) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets->optimum) (2024.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->datasets->optimum) (1.16.0)
# Installing collected packages: humanfriendly, coloredlogs, optimum
# Successfully installed coloredlogs-15.0.1 humanfriendly-10.0 optimum-1.19.1

# %%
pip install "peft<0.8.0" deepspeed
pip install optimum
pip install auto-gptq
pip install modelscope
pip install einops transformers_stream_generator
pip install tiktoken
# !pip install py7zr
#!pip install xformers
# !pip install accelerate
# !pip install -i https://pypi.org/simple/ bitsandbytes
# Out:
# Collecting peft<0.8.0
#   Downloading peft-0.7.1-py3-none-any.whl (168 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 168.3/168.3 kB 4.5 MB/s eta 0:00:00
# Collecting deepspeed
#   Downloading deepspeed-0.14.2.tar.gz (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 14.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from peft<0.8.0) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from peft<0.8.0) (24.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from peft<0.8.0) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from peft<0.8.0) (6.0.1)
# Requirement already satisfied: torch>=1.13.0 in /usr/local/lib/python3.10/dist-packages (from peft<0.8.0) (2.2.1+cu121)
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (from peft<0.8.0) (4.40.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from peft<0.8.0) (4.66.2)
# Requirement already satisfied: accelerate>=0.21.0 in /usr/local/lib/python3.10/dist-packages (from peft<0.8.0) (0.29.3)
# Requirement already satisfied: safetensors in /usr/local/lib/python3.10/dist-packages (from peft<0.8.0) (0.4.3)
# Requirement already satisfied: huggingface-hub>=0.17.0 in /usr/local/lib/python3.10/dist-packages (from peft<0.8.0) (0.20.3)
# Collecting hjson (from deepspeed)
#   Downloading hjson-3.1.0-py3-none-any.whl (54 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.0/54.0 kB 7.3 MB/s eta 0:00:00
# Collecting ninja (from deepspeed)
#   Downloading ninja-1.11.1.1-py2.py3-none-manylinux1_x86_64.manylinux_2_5_x86_64.whl (307 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 307.2/307.2 kB 16.5 MB/s eta 0:00:00
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.10/dist-packages (from deepspeed) (9.0.0)
# Requirement already satisfied: pydantic in /usr/local/lib/python3.10/dist-packages (from deepspeed) (2.7.1)
# Collecting pynvml (from deepspeed)
#   Downloading pynvml-11.5.0-py3-none-any.whl (53 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.1/53.1 kB 7.8 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.17.0->peft<0.8.0) (3.13.4)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.17.0->peft<0.8.0) (2023.6.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.17.0->peft<0.8.0) (2.31.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.17.0->peft<0.8.0) (4.11.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->peft<0.8.0) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->peft<0.8.0) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->peft<0.8.0) (3.1.3)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->peft<0.8.0) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->peft<0.8.0) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->peft<0.8.0) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->peft<0.8.0) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->peft<0.8.0) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->peft<0.8.0) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->peft<0.8.0) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->peft<0.8.0) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->peft<0.8.0) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.19.3 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->peft<0.8.0) (2.19.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->peft<0.8.0) (12.1.105)
# Requirement already satisfied: triton==2.2.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->peft<0.8.0) (2.2.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.10/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.13.0->peft<0.8.0) (12.4.127)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic->deepspeed) (0.6.0)
# Requirement already satisfied: pydantic-core==2.18.2 in /usr/local/lib/python3.10/dist-packages (from pydantic->deepspeed) (2.18.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers->peft<0.8.0) (2023.12.25)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers->peft<0.8.0) (0.19.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.13.0->peft<0.8.0) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.17.0->peft<0.8.0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.17.0->peft<0.8.0) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.17.0->peft<0.8.0) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.17.0->peft<0.8.0) (2024.2.2)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.13.0->peft<0.8.0) (1.3.0)
# Building wheels for collected packages: deepspeed
#   Building wheel for deepspeed (setup.py) ... done
#   Created wheel for deepspeed: filename=deepspeed-0.14.2-py3-none-any.whl size=1432242 sha256=d34827e9492b63fc539ac04bab01e7c70253f223978a321a293eaaa322878566
#   Stored in directory: /root/.cache/pip/wheels/ea/7c/43/bed44d8414c099ff962b754f425f7ff77cc623cc8a98e0da70
# Successfully built deepspeed
# Installing collected packages: ninja, hjson, pynvml, deepspeed, peft
#   Attempting uninstall: peft
#     Found existing installation: peft 0.10.0
#     Uninstalling peft-0.10.0:
#       Successfully uninstalled peft-0.10.0
# Successfully installed deepspeed-0.14.2 hjson-3.1.0 ninja-1.11.1.1 peft-0.7.1 pynvml-11.5.0

# %%
pip install mpi4py -i http://pypi.doubanio.com/simple/ --trusted-host pypi.doubanio.com
pip install "peft<0.8.0" deepspeed
pip install optimum
pip install auto-gptq
pip install modelscope
pip install einops transformers_stream_generator
pip install tiktoken
# !pip install py7zr
#!pip install xformers
# !pip install accelerate
# !pip install -i https://pypi.org/simple/ bitsandbytes
# Out:
# Looking in indexes: http://pypi.doubanio.com/simple/
# Collecting mpi4py
#   Downloading https://mirrors.cloud.tencent.com/pypi/packages/b3/17/1d146e0127b66f1945251f130afac430985d2f9d75a3c0330355f21d876a/mpi4py-3.1.6.tar.gz (2.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 5.6 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Building wheels for collected packages: mpi4py
#   Building wheel for mpi4py (pyproject.toml) ... done
#   Created wheel for mpi4py: filename=mpi4py-3.1.6-cp310-cp310-linux_x86_64.whl size=2746309 sha256=07d81d1eea702eb0e7094c5e86b5c16e767804e09878f1f5856a322e09ddd28b
#   Stored in directory: /root/.cache/pip/wheels/9a/2c/04/4adce2d6536f60615441034c8eb87f7fb7910926fd92d4fe50
# Successfully built mpi4py
# Installing collected packages: mpi4py
# Successfully installed mpi4py-3.1.6

# %% [markdown]
# ##1. load dataset which is processed by scripts

# %% [markdown]
# Qwen SFT traing foramt:
#
#
# [
#     {
#       "id": "identity_0",
#       "conversations": [
#         {
#           "from": "user",
#           "value": ""
#        },
#        {
#          "from": "assistant",
#          "value": ""
#        }
#      ]
#    }
#  ]

# %%
import pandas as pd
df = pd.read_json('/content/drive/MyDrive/ISS/5005/finetuning/train.json')

# %% [markdown]
# ## 2. Load and fine-tune the model with QLoRA

# %% [markdown]
# ### load qwen-7b-chat model

# %%
import os
os.environ["MODELSCOPE_CACHE"] = "/root/sdc1/qwen1.5-4int/qwen/Qwen-7B-Chat-Int4"

# %%
#下载模型
from modelscope import snapshot_download
from transformers import AutoModelForCausalLM, AutoTokenizer

model_dir = snapshot_download('qwen/Qwen-7B-Chat-Int4')

# Loading local checkpoints
# trust_remote_code is still set as True since we still load codes from local dir instead of transformers
tokenizer = AutoTokenizer.from_pretrained(model_dir, trust_remote_code=True)
model = AutoModelForCausalLM.from_pretrained(
    model_dir,
    device_map="auto",
    trust_remote_code=True
).eval()
# Out:
# 2024-05-01 10:06:06,108 - modelscope - WARNING - Model revision not specified, use revision: v1.1.8
# WARNING:transformers_modules.Qwen-7B-Chat-Int4.modeling_qwen:Warning: please make sure that you are using the latest codes and checkpoints, especially if you used Qwen-7B before 09.25.2023.请使用最新模型和代码，尤其如果你在9月25日前已经开始使用Qwen-7B，千万注意不要使用错误代码和模型。
# WARNING:transformers_modules.Qwen-7B-Chat-Int4.modeling_qwen:Try importing flash-attention for faster inference...
# WARNING:transformers_modules.Qwen-7B-Chat-Int4.modeling_qwen:Warning: import flash_attn rotary fail, please install FlashAttention rotary to get higher efficiency https://github.com/Dao-AILab/flash-attention/tree/main/csrc/rotary
# WARNING:transformers_modules.Qwen-7B-Chat-Int4.modeling_qwen:Warning: import flash_attn rms_norm fail, please install FlashAttention layer_norm to get higher efficiency https://github.com/Dao-AILab/flash-attention/tree/main/csrc/layer_norm
# WARNING:transformers_modules.Qwen-7B-Chat-Int4.modeling_qwen:Warning: import flash_attn fail, please install FlashAttention to get higher efficiency https://github.com/Dao-AILab/flash-attention
# /usr/local/lib/python3.10/dist-packages/transformers/modeling_utils.py:4371: FutureWarning: `_is_quantized_training_enabled` is going to be deprecated in transformers 4.39.0. Please use `model.hf_quantizer.is_trainable` instead
#   warnings.warn(
# Downloading:  66%|██████▌   | 1.25G/1.90G [00:24<00:04, 151MB/s]
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]

# %% [markdown]
# ### define a utility function to format prompts.

# %%
def generate_prompt(input):
  prompt_template = f"""
    分析用户是不是病人。如果是病人，他会询问如何治疗某种疾病.
    请根据不同的用户类型回答下面的问题

    交互格式如下：
    问题:用户提出的问题，如何治疗某种疾病或者其他类型问题
    回答:判断用户是不是病人,如果是病人,根据用户提出的问题，进行回答.如果不是,直接输出'<查询数据库>'

    现在开始：
    问题:{input}
    回答:
  """
  return prompt_template

# %%
for index,row in df.iterrows():
  row['conversations'][0]['value'] = generate_prompt(row['conversations'][0]['value'])

# %%
import json
import numpy as np
import matplotlib.pyplot as plt
import nltk

# Download NLTK's punkt tokenizer model
nltk.download('punkt')

# Prepare the data
token_counts = []
for index,row in df.iterrows():
    prompt = generate_prompt(row['conversations'][0]['value'])
    tokens = nltk.word_tokenize(prompt)  # Tokenize the prompt string using NLTK
    token_counts.append(len(tokens))

# Calculate statistics
mean_tokens = np.mean(token_counts)
max_tokens = np.max(token_counts)
min_tokens = np.min(token_counts)

# Plot the histogram
plt.figure(figsize=(10, 3))
plt.hist(token_counts, bins=50, color='skyblue', edgecolor='black')
plt.axvline(mean_tokens, color='red', linestyle='dashed', linewidth=1, label=f'Mean: {mean_tokens:.2f}')
plt.axvline(max_tokens, color='green', linestyle='dashed', linewidth=1, label=f'Max: {max_tokens}')
plt.axvline(min_tokens, color='orange', linestyle='dashed', linewidth=1, label=f'Min: {min_tokens}')
plt.title('Prompt Token Count Distribution')
plt.xlabel('Number of Tokens')
plt.ylabel('Frequency')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
df.to_json('/content/drive/MyDrive/ISS/5005/finetuning/train.json', orient='records')

# %% [markdown]
# ### finetuning qwen-7b-chat

# %% [markdown]
# **use deepspeed to accelrate the traing speed(All arguments are in the finetune_qlora.sh)**

# %% [markdown]
#   --fp16 True \
#   --num_train_epochs 2 \
#   --per_device_train_batch_size 16 \
#   --per_device_eval_batch_size 8 \
#   --gradient_accumulation_steps 4 \
#   --evaluation_strategy "no" \
#   --save_strategy "steps" \
#   --save_steps 1000 \
#   --save_total_limit 10 \
#   --learning_rate 3e-4 \
#   --weight_decay 0.1 \
#   --adam_beta2 0.95 \
#   --warmup_ratio 0.01 \
#   --lr_scheduler_type "cosine" \
#   --logging_steps 1 \
#   --report_to "none" \
#   --model_max_length 512 \

# %%
# !bash /content/drive/MyDrive/ISS/5005/finetuning/ft.sh
# Out:
# [2024-05-01 08:21:56,116] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
#  [WARNING]  async_io requires the dev libaio .so object and headers but these were not found.
#  [WARNING]  async_io: please install the libaio-dev package with apt
#  [WARNING]  If libaio is already installed (perhaps from source), try setting the CFLAGS and LDFLAGS environment variables to where it can be found.
#  [WARNING]  Please specify the CUTLASS repo directory as environment variable $CUTLASS_PATH
#  [WARNING]  sparse_attn requires a torch version >= 1.5 and < 2.0 but detected 2.3
#  [WARNING]  using untested triton version (2.3.0), only 1.0.0 is known to be compatible
# 2024-05-01 08:21:58.271129: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-05-01 08:21:58.271181: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-05-01 08:21:58.273128: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-05-01 08:21:59.628266: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# /usr/local/lib/python3.10/dist-packages/transformers/deepspeed.py:23: FutureWarning: transformers.deepspeed module is deprecated and will be removed in a future version. Please import deepspeed modules directly from transformers.integrations
#   warnings.warn(
# Using `disable_exllama` is deprecated and will be removed in version 4.37. Use `use_exllama` instead and specify the version with `exllama_config`.The value of `use_exllama` will be overwritten by `disable_exllama` passed in `GPTQConfig` or stored in your config file.
# /usr/local/lib/python3.10/dist-packages/transformers/quantizers/auto.py:159: UserWarning: You passed `quantization_config` or equivalent parameters to `from_pretrained` but the model you're loading already has a `quantization_config` attribute. The `quantization_config` from the model will be used.However, loading attributes (e.g. ['use_cuda_fp16', 'use_exllama', 'max_input_length', 'exllama_config', 'disable_exllama']) will be overwritten with the one you passed to `from_pretrained`. The rest will be ignored.
#   warnings.warn(warning_msg)
# CUDA extension not installed.
# CUDA extension not installed.
# Warning: please make sure that you are using the latest codes and checkpoints, especially if you used Qwen-7B before 09.25.2023.请使用最新模型和代码，尤其如果你在9月25日前已经开始使用Qwen-7B，千万注意不要使用错误代码和模型。
# Try importing flash-attention for faster inference...
# Warning: import flash_attn rotary fail, please install FlashAttention rotary to get higher efficiency https://github.com/Dao-AILab/flash-attention/tree/main/csrc/rotary
# Warning: import flash_attn rms_norm fail, please install FlashAttention layer_norm to get higher efficiency https://github.com/Dao-AILab/flash-attention/tree/main/csrc/layer_norm
# Warning: import flash_attn fail, please install FlashAttention to get higher efficiency https://github.com/Dao-AILab/flash-attention
# /usr/local/lib/python3.10/dist-packages/transformers/modeling_utils.py:4371: FutureWarning: `_is_quantized_training_enabled` is going to be deprecated in transformers 4.39.0. Please use `model.hf_quantizer.is_trainable` instead
#   warnings.warn(
# Loading checkpoint shards: 100% 3/3 [00:05<00:00,  1.84s/it]
# You are using an old version of the checkpointing format that is deprecated (We will also silently ignore `gradient_checkpointing_kwargs` in case you passed it).Please update to the new format on your modeling file. To use the new format, you need to completely remove the definition of the method `_set_gradient_checkpointing` in your model.
# trainable params: 143,130,624 || all params: 1,388,056,576 || trainable%: 10.311584302454254
# Loading data...
# Formatting inputs...Skip in lazy mode
# You are using an old version of the checkpointing format that is deprecated (We will also silently ignore `gradient_checkpointing_kwargs` in case you passed it).Please update to the new format on your modeling file. To use the new format, you need to completely remove the definition of the method `_set_gradient_checkpointing` in your model.
# Using /root/.cache/torch_extensions/py310_cu121 as PyTorch extensions root...
# Detected CUDA files, patching ldflags
# Emitting ninja build file /root/.cache/torch_extensions/py310_cu121/fused_adam/build.ninja...
# /usr/local/lib/python3.10/dist-packages/torch/utils/cpp_extension.py:1967: UserWarning: TORCH_CUDA_ARCH_LIST is not set, all archs for visible cards are included for compilation.
# If this is not desired, please set os.environ['TORCH_CUDA_ARCH_LIST'].
#   warnings.warn(
# Building extension module fused_adam...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# ninja: no work to do.
# Loading extension module fused_adam...
# Time to load fused_adam op: 0.11527037620544434 seconds
#   0% 0/624 [00:00<?, ?it/s]/usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:464: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.4 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# {'loss': 3.1367, 'grad_norm': 0.23558196425437927, 'learning_rate': 0.0, 'epoch': 0.0}
# {'loss': 2.795, 'grad_norm': 0.18545424938201904, 'learning_rate': 0.00010686215613240664, 'epoch': 0.01}
# {'loss': 2.9268, 'grad_norm': 0.21421921253204346, 'learning_rate': 0.0001693725102160739, 'epoch': 0.01}
# {'loss': 2.7607, 'grad_norm': 0.16931967437267303, 'learning_rate': 0.00021372431226481328, 'epoch': 0.01}
# {'loss': 2.5547, 'grad_norm': 0.14589115977287292, 'learning_rate': 0.00024812624260407484, 'epoch': 0.02}
# {'loss': 2.572, 'grad_norm': 0.1271691918373108, 'learning_rate': 0.0002762346663484805, 'epoch': 0.02}
# {'loss': 2.4124, 'grad_norm': 0.19288724660873413, 'learning_rate': 0.0003, 'epoch': 0.02}
# {'loss': 2.6729, 'grad_norm': 0.1500602662563324, 'learning_rate': 0.0003, 'epoch': 0.03}
# {'loss': 2.6445, 'grad_norm': 0.17175568640232086, 'learning_rate': 0.0003, 'epoch': 0.03}
# {'loss': 2.7419, 'grad_norm': 0.16971491277217865, 'learning_rate': 0.0003, 'epoch': 0.03}
# {'loss': 2.4435, 'grad_norm': 0.16844351589679718, 'learning_rate': 0.0003, 'epoch': 0.04}
# {'loss': 2.7612, 'grad_norm': 0.16059201955795288, 'learning_rate': 0.0003, 'epoch': 0.04}
# {'loss': 2.5342, 'grad_norm': 0.15653255581855774, 'learning_rate': 0.0003, 'epoch': 0.04}
# {'loss': 2.7087, 'grad_norm': 0.1407393366098404, 'learning_rate': 0.0003, 'epoch': 0.04}
# {'loss': 2.2439, 'grad_norm': 0.2053900957107544, 'learning_rate': 0.0003, 'epoch': 0.05}
# {'loss': 2.3594, 'grad_norm': 0.170949786901474, 'learning_rate': 0.0003, 'epoch': 0.05}
# {'loss': 2.4819, 'grad_norm': 0.16162541508674622, 'learning_rate': 0.0003, 'epoch': 0.05}
# {'loss': 2.3855, 'grad_norm': 0.15915226936340332, 'learning_rate': 0.0003, 'epoch': 0.06}
# {'loss': 2.4165, 'grad_norm': 0.1753004938364029, 'learning_rate': 0.0003, 'epoch': 0.06}
# {'loss': 2.2706, 'grad_norm': 0.19303913414478302, 'learning_rate': 0.0003, 'epoch': 0.06}
# {'loss': 2.156, 'grad_norm': 0.1889868676662445, 'learning_rate': 0.0003, 'epoch': 0.07}
# {'loss': 2.3654, 'grad_norm': 0.20935897529125214, 'learning_rate': 0.0003, 'epoch': 0.07}
# {'loss': 2.2048, 'grad_norm': 0.203970268368721, 'learning_rate': 0.0003, 'epoch': 0.07}
# {'loss': 2.5254, 'grad_norm': 0.24911737442016602, 'learning_rate': 0.0003, 'epoch': 0.08}
# {'loss': 1.727, 'grad_norm': 0.21682655811309814, 'learning_rate': 0.0003, 'epoch': 0.08}
# {'loss': 2.0663, 'grad_norm': 0.30029046535491943, 'learning_rate': 0.0003, 'epoch': 0.08}
# {'loss': 2.1044, 'grad_norm': 0.2503703534603119, 'learning_rate': 0.0003, 'epoch': 0.09}
# {'loss': 2.0375, 'grad_norm': 0.2240993231534958, 'learning_rate': 0.0003, 'epoch': 0.09}
# {'loss': 2.2729, 'grad_norm': 0.19988858699798584, 'learning_rate': 0.0003, 'epoch': 0.09}
# {'loss': 2.1266, 'grad_norm': 0.2310953140258789, 'learning_rate': 0.0003, 'epoch': 0.1}
# {'loss': 2.1421, 'grad_norm': 0.2826806306838989, 'learning_rate': 0.0003, 'epoch': 0.1}
# {'loss': 1.9987, 'grad_norm': 0.30739712715148926, 'learning_rate': 0.0003, 'epoch': 0.1}
# {'loss': 2.2803, 'grad_norm': 0.30371829867362976, 'learning_rate': 0.0003, 'epoch': 0.11}
# {'loss': 1.8267, 'grad_norm': 0.33760225772857666, 'learning_rate': 0.0003, 'epoch': 0.11}
# {'loss': 2.1857, 'grad_norm': 0.25527969002723694, 'learning_rate': 0.0003, 'epoch': 0.11}
# {'loss': 2.0975, 'grad_norm': 0.25446265935897827, 'learning_rate': 0.0003, 'epoch': 0.12}
# {'loss': 1.8797, 'grad_norm': 0.2240898162126541, 'learning_rate': 0.0003, 'epoch': 0.12}
# {'loss': 2.1317, 'grad_norm': 0.2607499957084656, 'learning_rate': 0.0003, 'epoch': 0.12}
# {'loss': 1.9769, 'grad_norm': 0.286577045917511, 'learning_rate': 0.0003, 'epoch': 0.12}
# {'loss': 2.0598, 'grad_norm': 0.2570977509021759, 'learning_rate': 0.0003, 'epoch': 0.13}
# {'loss': 2.1287, 'grad_norm': 0.26745638251304626, 'learning_rate': 0.0003, 'epoch': 0.13}
# {'loss': 2.14, 'grad_norm': 0.2835645377635956, 'learning_rate': 0.0003, 'epoch': 0.13}
# {'loss': 2.1251, 'grad_norm': 0.31048277020454407, 'learning_rate': 0.0003, 'epoch': 0.14}
# {'loss': 1.8512, 'grad_norm': 0.2943061888217926, 'learning_rate': 0.0003, 'epoch': 0.14}
# {'loss': 1.8855, 'grad_norm': 0.2452618032693863, 'learning_rate': 0.0003, 'epoch': 0.14}
# {'loss': 2.1007, 'grad_norm': 0.28306615352630615, 'learning_rate': 0.0003, 'epoch': 0.15}
# {'loss': 1.8405, 'grad_norm': 0.31877025961875916, 'learning_rate': 0.0003, 'epoch': 0.15}
# {'loss': 1.8145, 'grad_norm': 0.2994488477706909, 'learning_rate': 0.0003, 'epoch': 0.15}
# {'loss': 1.976, 'grad_norm': 0.30445241928100586, 'learning_rate': 0.0003, 'epoch': 0.16}
# {'loss': 1.6059, 'grad_norm': 0.2766474485397339, 'learning_rate': 0.0003, 'epoch': 0.16}
# {'loss': 2.0195, 'grad_norm': 0.3374026417732239, 'learning_rate': 0.0003, 'epoch': 0.16}
# {'loss': 2.2191, 'grad_norm': 0.33774515986442566, 'learning_rate': 0.0003, 'epoch': 0.17}
# {'loss': 1.6283, 'grad_norm': 0.3312996029853821, 'learning_rate': 0.0003, 'epoch': 0.17}
# {'loss': 1.941, 'grad_norm': 0.2988680601119995, 'learning_rate': 0.0003, 'epoch': 0.17}
# {'loss': 2.0967, 'grad_norm': 0.2890796363353729, 'learning_rate': 0.0003, 'epoch': 0.18}
# {'loss': 1.607, 'grad_norm': 0.30570030212402344, 'learning_rate': 0.0003, 'epoch': 0.18}
# {'loss': 1.6627, 'grad_norm': 0.2865683436393738, 'learning_rate': 0.0003, 'epoch': 0.18}
# {'loss': 1.7371, 'grad_norm': 0.30448681116104126, 'learning_rate': 0.0003, 'epoch': 0.19}
# {'loss': 1.9299, 'grad_norm': 0.30067071318626404, 'learning_rate': 0.0003, 'epoch': 0.19}
# {'loss': 1.8669, 'grad_norm': 0.382109135389328, 'learning_rate': 0.0003, 'epoch': 0.19}
# {'loss': 2.0526, 'grad_norm': 0.32973483204841614, 'learning_rate': 0.0003, 'epoch': 0.2}
# {'loss': 2.309, 'grad_norm': 0.3212225139141083, 'learning_rate': 0.0003, 'epoch': 0.2}
# {'loss': 1.7567, 'grad_norm': 0.3196954131126404, 'learning_rate': 0.0003, 'epoch': 0.2}
# {'loss': 1.8039, 'grad_norm': 0.3107990622520447, 'learning_rate': 0.0003, 'epoch': 0.2}
# {'loss': 2.0809, 'grad_norm': 0.2780699133872986, 'learning_rate': 0.0003, 'epoch': 0.21}
# {'loss': 1.7235, 'grad_norm': 0.2621229290962219, 'learning_rate': 0.0003, 'epoch': 0.21}
# {'loss': 1.6595, 'grad_norm': 0.3047488331794739, 'learning_rate': 0.0003, 'epoch': 0.21}
# {'loss': 2.1105, 'grad_norm': 0.28978225588798523, 'learning_rate': 0.0003, 'epoch': 0.22}
# {'loss': 1.5814, 'grad_norm': 0.29354041814804077, 'learning_rate': 0.0003, 'epoch': 0.22}
# {'loss': 2.037, 'grad_norm': 0.3158443570137024, 'learning_rate': 0.0003, 'epoch': 0.22}
# {'loss': 2.1688, 'grad_norm': 0.2752663195133209, 'learning_rate': 0.0003, 'epoch': 0.23}
# {'loss': 1.8507, 'grad_norm': 0.33925876021385193, 'learning_rate': 0.0003, 'epoch': 0.23}
# {'loss': 1.5388, 'grad_norm': 0.3664197325706482, 'learning_rate': 0.0003, 'epoch': 0.23}
# {'loss': 1.6686, 'grad_norm': 0.31361737847328186, 'learning_rate': 0.0003, 'epoch': 0.24}
# {'loss': 1.7361, 'grad_norm': 0.2679210603237152, 'learning_rate': 0.0003, 'epoch': 0.24}
# {'loss': 1.8987, 'grad_norm': 0.2887749671936035, 'learning_rate': 0.0003, 'epoch': 0.24}
# {'loss': 2.2347, 'grad_norm': 0.2624613642692566, 'learning_rate': 0.0003, 'epoch': 0.25}
# {'loss': 1.9083, 'grad_norm': 0.3174775540828705, 'learning_rate': 0.0003, 'epoch': 0.25}
# {'loss': 1.7902, 'grad_norm': 0.2953914999961853, 'learning_rate': 0.0003, 'epoch': 0.25}
# {'loss': 1.8945, 'grad_norm': 0.31119951605796814, 'learning_rate': 0.0003, 'epoch': 0.26}
# {'loss': 1.4686, 'grad_norm': 0.28676965832710266, 'learning_rate': 0.0003, 'epoch': 0.26}
# {'loss': 1.811, 'grad_norm': 0.2563122808933258, 'learning_rate': 0.0003, 'epoch': 0.26}
# {'loss': 1.6088, 'grad_norm': 0.24877199530601501, 'learning_rate': 0.0003, 'epoch': 0.27}
# {'loss': 1.5515, 'grad_norm': 0.27859511971473694, 'learning_rate': 0.0003, 'epoch': 0.27}
# {'loss': 1.6109, 'grad_norm': 0.30896249413490295, 'learning_rate': 0.0003, 'epoch': 0.27}
# {'loss': 1.9456, 'grad_norm': 0.2541808784008026, 'learning_rate': 0.0003, 'epoch': 0.28}
# {'loss': 1.6574, 'grad_norm': 0.25329405069351196, 'learning_rate': 0.0003, 'epoch': 0.28}
# {'loss': 1.2136, 'grad_norm': 0.30386587977409363, 'learning_rate': 0.0003, 'epoch': 0.28}
# {'loss': 1.5653, 'grad_norm': 0.25268837809562683, 'learning_rate': 0.0003, 'epoch': 0.28}
# {'loss': 1.3766, 'grad_norm': 0.3107065260410309, 'learning_rate': 0.0003, 'epoch': 0.29}
# {'loss': 1.7192, 'grad_norm': 0.30037423968315125, 'learning_rate': 0.0003, 'epoch': 0.29}
# {'loss': 1.8524, 'grad_norm': 0.2980104386806488, 'learning_rate': 0.0003, 'epoch': 0.29}
# {'loss': 1.8463, 'grad_norm': 0.26235660910606384, 'learning_rate': 0.0003, 'epoch': 0.3}
# {'loss': 1.6251, 'grad_norm': 0.29502755403518677, 'learning_rate': 0.0003, 'epoch': 0.3}
# {'loss': 1.9315, 'grad_norm': 0.3286764621734619, 'learning_rate': 0.0003, 'epoch': 0.3}
# {'loss': 1.9575, 'grad_norm': 0.32082870602607727, 'learning_rate': 0.0003, 'epoch': 0.31}
# {'loss': 1.6841, 'grad_norm': 0.28603219985961914, 'learning_rate': 0.0003, 'epoch': 0.31}
# {'loss': 2.046, 'grad_norm': 0.23660464584827423, 'learning_rate': 0.0003, 'epoch': 0.31}
# {'loss': 1.9185, 'grad_norm': 0.21651406586170197, 'learning_rate': 0.0003, 'epoch': 0.32}
# {'loss': 1.9832, 'grad_norm': 0.2552225887775421, 'learning_rate': 0.0003, 'epoch': 0.32}
# {'loss': 1.6911, 'grad_norm': 0.27830055356025696, 'learning_rate': 0.0003, 'epoch': 0.32}
# {'loss': 1.4512, 'grad_norm': 0.3052094578742981, 'learning_rate': 0.0003, 'epoch': 0.33}
# {'loss': 1.7518, 'grad_norm': 0.27495115995407104, 'learning_rate': 0.0003, 'epoch': 0.33}
# {'loss': 1.6975, 'grad_norm': 0.2750292420387268, 'learning_rate': 0.0003, 'epoch': 0.33}
# {'loss': 1.5728, 'grad_norm': 0.22733555734157562, 'learning_rate': 0.0003, 'epoch': 0.34}
# {'loss': 1.8336, 'grad_norm': 0.3275131583213806, 'learning_rate': 0.0003, 'epoch': 0.34}
# {'loss': 1.8102, 'grad_norm': 0.23892717063426971, 'learning_rate': 0.0003, 'epoch': 0.34}
# {'loss': 1.5324, 'grad_norm': 0.2769860327243805, 'learning_rate': 0.0003, 'epoch': 0.35}
# {'loss': 1.3578, 'grad_norm': 0.25130409002304077, 'learning_rate': 0.0003, 'epoch': 0.35}
# {'loss': 1.8732, 'grad_norm': 0.24081894755363464, 'learning_rate': 0.0003, 'epoch': 0.35}
# {'loss': 1.6579, 'grad_norm': 0.2781890630722046, 'learning_rate': 0.0003, 'epoch': 0.36}
# {'loss': 1.0857, 'grad_norm': 0.3006110191345215, 'learning_rate': 0.0003, 'epoch': 0.36}
# {'loss': 1.5994, 'grad_norm': 0.2479039579629898, 'learning_rate': 0.0003, 'epoch': 0.36}
# {'loss': 1.8479, 'grad_norm': 0.23900653421878815, 'learning_rate': 0.0003, 'epoch': 0.36}
# {'loss': 1.8971, 'grad_norm': 0.20904305577278137, 'learning_rate': 0.0003, 'epoch': 0.37}
# {'loss': 1.6937, 'grad_norm': 0.2524709403514862, 'learning_rate': 0.0003, 'epoch': 0.37}
# {'loss': 1.7548, 'grad_norm': 0.2657410502433777, 'learning_rate': 0.0003, 'epoch': 0.37}
# {'loss': 1.6109, 'grad_norm': 0.36933091282844543, 'learning_rate': 0.0003, 'epoch': 0.38}
# {'loss': 1.6598, 'grad_norm': 0.24009093642234802, 'learning_rate': 0.0003, 'epoch': 0.38}
# {'loss': 1.7598, 'grad_norm': 0.25099676847457886, 'learning_rate': 0.0003, 'epoch': 0.38}
# {'loss': 1.7878, 'grad_norm': 0.2430599182844162, 'learning_rate': 0.0003, 'epoch': 0.39}
# {'loss': 1.7339, 'grad_norm': 0.26722633838653564, 'learning_rate': 0.0003, 'epoch': 0.39}
# {'loss': 2.027, 'grad_norm': 0.23569519817829132, 'learning_rate': 0.0003, 'epoch': 0.39}
# {'loss': 1.4087, 'grad_norm': 0.22930657863616943, 'learning_rate': 0.0003, 'epoch': 0.4}
# {'loss': 1.6395, 'grad_norm': 0.2557806074619293, 'learning_rate': 0.0003, 'epoch': 0.4}
# {'loss': 1.6785, 'grad_norm': 0.2337038218975067, 'learning_rate': 0.0003, 'epoch': 0.4}
# {'loss': 1.6435, 'grad_norm': 0.2381366640329361, 'learning_rate': 0.0003, 'epoch': 0.41}
# {'loss': 1.4586, 'grad_norm': 0.24593693017959595, 'learning_rate': 0.0003, 'epoch': 0.41}
# {'loss': 1.3962, 'grad_norm': 0.24567937850952148, 'learning_rate': 0.0003, 'epoch': 0.41}
# {'loss': 1.8392, 'grad_norm': 0.25198355317115784, 'learning_rate': 0.0003, 'epoch': 0.42}
# {'loss': 1.4048, 'grad_norm': 0.27530571818351746, 'learning_rate': 0.0003, 'epoch': 0.42}
# {'loss': 1.8295, 'grad_norm': 0.20409256219863892, 'learning_rate': 0.0003, 'epoch': 0.42}
# {'loss': 1.9871, 'grad_norm': 0.3002716302871704, 'learning_rate': 0.0003, 'epoch': 0.43}
# {'loss': 1.675, 'grad_norm': 0.2508259415626526, 'learning_rate': 0.0003, 'epoch': 0.43}
# {'loss': 1.5259, 'grad_norm': 0.219561368227005, 'learning_rate': 0.0003, 'epoch': 0.43}
# {'loss': 1.4899, 'grad_norm': 0.245027095079422, 'learning_rate': 0.0003, 'epoch': 0.44}
# {'loss': 1.9349, 'grad_norm': 0.22851714491844177, 'learning_rate': 0.0003, 'epoch': 0.44}
# {'loss': 1.5896, 'grad_norm': 0.25655949115753174, 'learning_rate': 0.0003, 'epoch': 0.44}
# {'loss': 1.7389, 'grad_norm': 0.24942736327648163, 'learning_rate': 0.0003, 'epoch': 0.44}
# {'loss': 1.3906, 'grad_norm': 0.20524142682552338, 'learning_rate': 0.0003, 'epoch': 0.45}
# {'loss': 1.6748, 'grad_norm': 0.22308145463466644, 'learning_rate': 0.0003, 'epoch': 0.45}
# {'loss': 1.8306, 'grad_norm': 0.2333400845527649, 'learning_rate': 0.0003, 'epoch': 0.45}
# {'loss': 1.7153, 'grad_norm': 0.2664303481578827, 'learning_rate': 0.0003, 'epoch': 0.46}
# {'loss': 1.1606, 'grad_norm': 0.24558420479297638, 'learning_rate': 0.0003, 'epoch': 0.46}
# {'loss': 1.6094, 'grad_norm': 0.25213858485221863, 'learning_rate': 0.0003, 'epoch': 0.46}
# {'loss': 1.9176, 'grad_norm': 0.23281420767307281, 'learning_rate': 0.0003, 'epoch': 0.47}
# {'loss': 1.7291, 'grad_norm': 0.2564676105976105, 'learning_rate': 0.0003, 'epoch': 0.47}
# {'loss': 1.2577, 'grad_norm': 0.21456278860569, 'learning_rate': 0.0003, 'epoch': 0.47}
# {'loss': 1.3341, 'grad_norm': 0.20785203576087952, 'learning_rate': 0.0003, 'epoch': 0.48}
# {'loss': 1.7198, 'grad_norm': 0.2726489007472992, 'learning_rate': 0.0003, 'epoch': 0.48}
# {'loss': 1.8417, 'grad_norm': 0.22689557075500488, 'learning_rate': 0.0003, 'epoch': 0.48}
# {'loss': 1.9969, 'grad_norm': 0.24765998125076294, 'learning_rate': 0.0003, 'epoch': 0.49}
# {'loss': 1.5444, 'grad_norm': 0.22444505989551544, 'learning_rate': 0.0003, 'epoch': 0.49}
# {'loss': 1.6016, 'grad_norm': 0.26051831245422363, 'learning_rate': 0.0003, 'epoch': 0.49}
# {'loss': 1.8556, 'grad_norm': 0.2486560344696045, 'learning_rate': 0.0003, 'epoch': 0.5}
# {'loss': 1.3991, 'grad_norm': 0.21995560824871063, 'learning_rate': 0.0003, 'epoch': 0.5}
# {'loss': 2.1703, 'grad_norm': 0.2210579663515091, 'learning_rate': 0.0003, 'epoch': 0.5}
# {'loss': 2.0809, 'grad_norm': 0.2718351483345032, 'learning_rate': 0.0003, 'epoch': 0.51}
# {'loss': 1.9877, 'grad_norm': 0.2335355579853058, 'learning_rate': 0.0003, 'epoch': 0.51}
# {'loss': 1.6604, 'grad_norm': 0.24042761325836182, 'learning_rate': 0.0003, 'epoch': 0.51}
# {'loss': 1.8253, 'grad_norm': 0.24236655235290527, 'learning_rate': 0.0003, 'epoch': 0.52}
# {'loss': 1.3708, 'grad_norm': 0.2711699306964874, 'learning_rate': 0.0003, 'epoch': 0.52}
# {'loss': 1.6274, 'grad_norm': 0.2748848497867584, 'learning_rate': 0.0003, 'epoch': 0.52}
# {'loss': 1.8379, 'grad_norm': 0.2386362999677658, 'learning_rate': 0.0003, 'epoch': 0.52}
# {'loss': 1.5816, 'grad_norm': 0.2006392627954483, 'learning_rate': 0.0003, 'epoch': 0.53}
# {'loss': 1.9801, 'grad_norm': 0.2197204977273941, 'learning_rate': 0.0003, 'epoch': 0.53}
# {'loss': 1.6667, 'grad_norm': 0.20757336914539337, 'learning_rate': 0.0003, 'epoch': 0.53}
# {'loss': 1.4403, 'grad_norm': 0.2138749361038208, 'learning_rate': 0.0003, 'epoch': 0.54}
# {'loss': 1.7315, 'grad_norm': 0.21095265448093414, 'learning_rate': 0.0003, 'epoch': 0.54}
# {'loss': 1.4803, 'grad_norm': 0.22756662964820862, 'learning_rate': 0.0003, 'epoch': 0.54}
# {'loss': 1.886, 'grad_norm': 0.23921173810958862, 'learning_rate': 0.0003, 'epoch': 0.55}
# {'loss': 1.7979, 'grad_norm': 0.24384374916553497, 'learning_rate': 0.0003, 'epoch': 0.55}
# {'loss': 1.832, 'grad_norm': 0.21090665459632874, 'learning_rate': 0.0003, 'epoch': 0.55}
# {'loss': 1.7095, 'grad_norm': 0.21720604598522186, 'learning_rate': 0.0003, 'epoch': 0.56}
# {'loss': 1.864, 'grad_norm': 0.2609196603298187, 'learning_rate': 0.0003, 'epoch': 0.56}
# {'loss': 1.1831, 'grad_norm': 0.32917317748069763, 'learning_rate': 0.0003, 'epoch': 0.56}
# {'loss': 1.3641, 'grad_norm': 0.22739578783512115, 'learning_rate': 0.0003, 'epoch': 0.57}
# {'loss': 1.7664, 'grad_norm': 0.2471626251935959, 'learning_rate': 0.0003, 'epoch': 0.57}
# {'loss': 1.4593, 'grad_norm': 0.2306068241596222, 'learning_rate': 0.0003, 'epoch': 0.57}
# {'loss': 1.6076, 'grad_norm': 0.2923715114593506, 'learning_rate': 0.0003, 'epoch': 0.58}
# {'loss': 1.7784, 'grad_norm': 0.2083158791065216, 'learning_rate': 0.0003, 'epoch': 0.58}
# {'loss': 1.4817, 'grad_norm': 0.22059212625026703, 'learning_rate': 0.0003, 'epoch': 0.58}
# {'loss': 1.4202, 'grad_norm': 0.2044212967157364, 'learning_rate': 0.0003, 'epoch': 0.59}
# {'loss': 1.3044, 'grad_norm': 0.26819875836372375, 'learning_rate': 0.0003, 'epoch': 0.59}
# {'loss': 1.6614, 'grad_norm': 0.2097555249929428, 'learning_rate': 0.0003, 'epoch': 0.59}
# {'loss': 1.5198, 'grad_norm': 0.2472076267004013, 'learning_rate': 0.0003, 'epoch': 0.6}
# {'loss': 1.8638, 'grad_norm': 0.2043042778968811, 'learning_rate': 0.0003, 'epoch': 0.6}
# {'loss': 1.4238, 'grad_norm': 0.22630108892917633, 'learning_rate': 0.0003, 'epoch': 0.6}
# {'loss': 1.8026, 'grad_norm': 0.2431197315454483, 'learning_rate': 0.0003, 'epoch': 0.6}
#  30% 189/624 [25:49<59:22,  8.19s/it]Token indices sequence length is longer than the specified maximum sequence length for this model (542 > 512). Running this sequence through the model will result in indexing errors
# {'loss': 1.5292, 'grad_norm': 0.2611744999885559, 'learning_rate': 0.0003, 'epoch': 0.61}
# {'loss': 1.765, 'grad_norm': 0.2505011260509491, 'learning_rate': 0.0003, 'epoch': 0.61}
# {'loss': 1.4885, 'grad_norm': 0.27158495783805847, 'learning_rate': 0.0003, 'epoch': 0.61}
# {'loss': 1.626, 'grad_norm': 0.2395920306444168, 'learning_rate': 0.0003, 'epoch': 0.62}
# {'loss': 1.4061, 'grad_norm': 0.2218010425567627, 'learning_rate': 0.0003, 'epoch': 0.62}
# {'loss': 1.4229, 'grad_norm': 0.2245907336473465, 'learning_rate': 0.0003, 'epoch': 0.62}
# {'loss': 1.5557, 'grad_norm': 0.2354857176542282, 'learning_rate': 0.0003, 'epoch': 0.63}
# {'loss': 1.6883, 'grad_norm': 0.19779232144355774, 'learning_rate': 0.0003, 'epoch': 0.63}
# {'loss': 1.4794, 'grad_norm': 0.23322923481464386, 'learning_rate': 0.0003, 'epoch': 0.63}
# {'loss': 1.2041, 'grad_norm': 0.21762141585350037, 'learning_rate': 0.0003, 'epoch': 0.64}
# {'loss': 1.4915, 'grad_norm': 0.22434808313846588, 'learning_rate': 0.0003, 'epoch': 0.64}
# {'loss': 1.8163, 'grad_norm': 0.23125846683979034, 'learning_rate': 0.0003, 'epoch': 0.64}
# {'loss': 1.3603, 'grad_norm': 0.23624193668365479, 'learning_rate': 0.0003, 'epoch': 0.65}
# {'loss': 1.8796, 'grad_norm': 0.2235865294933319, 'learning_rate': 0.0003, 'epoch': 0.65}
# {'loss': 1.4648, 'grad_norm': 0.21034365892410278, 'learning_rate': 0.0003, 'epoch': 0.65}
# {'loss': 1.4717, 'grad_norm': 0.18645280599594116, 'learning_rate': 0.0003, 'epoch': 0.66}
# {'loss': 1.5604, 'grad_norm': 0.31309399008750916, 'learning_rate': 0.0003, 'epoch': 0.66}
# {'loss': 1.5124, 'grad_norm': 0.17945383489131927, 'learning_rate': 0.0003, 'epoch': 0.66}
# {'loss': 1.4831, 'grad_norm': 0.22530709207057953, 'learning_rate': 0.0003, 'epoch': 0.67}
# {'loss': 1.6251, 'grad_norm': 0.22957447171211243, 'learning_rate': 0.0003, 'epoch': 0.67}
# {'loss': 1.6907, 'grad_norm': 0.2271876037120819, 'learning_rate': 0.0003, 'epoch': 0.67}
# {'loss': 1.9598, 'grad_norm': 0.205679789185524, 'learning_rate': 0.0003, 'epoch': 0.68}
# {'loss': 1.642, 'grad_norm': 0.23261503875255585, 'learning_rate': 0.0003, 'epoch': 0.68}
# {'loss': 1.4677, 'grad_norm': 0.2403235286474228, 'learning_rate': 0.0003, 'epoch': 0.68}
# {'loss': 1.9259, 'grad_norm': 0.23685157299041748, 'learning_rate': 0.0003, 'epoch': 0.68}
# {'loss': 1.4738, 'grad_norm': 0.19010210037231445, 'learning_rate': 0.0003, 'epoch': 0.69}
# {'loss': 1.444, 'grad_norm': 0.197683647274971, 'learning_rate': 0.0003, 'epoch': 0.69}
# {'loss': 1.6252, 'grad_norm': 0.19243404269218445, 'learning_rate': 0.0003, 'epoch': 0.69}
# {'loss': 1.4576, 'grad_norm': 0.21870629489421844, 'learning_rate': 0.0003, 'epoch': 0.7}
# {'loss': 1.6172, 'grad_norm': 0.24039383232593536, 'learning_rate': 0.0003, 'epoch': 0.7}
# {'loss': 1.8663, 'grad_norm': 0.21908386051654816, 'learning_rate': 0.0003, 'epoch': 0.7}
# {'loss': 1.2355, 'grad_norm': 0.2765284776687622, 'learning_rate': 0.0003, 'epoch': 0.71}
# {'loss': 1.4681, 'grad_norm': 0.23339127004146576, 'learning_rate': 0.0003, 'epoch': 0.71}
# {'loss': 1.5648, 'grad_norm': 0.20609599351882935, 'learning_rate': 0.0003, 'epoch': 0.71}
# {'loss': 1.5398, 'grad_norm': 0.2596640884876251, 'learning_rate': 0.0003, 'epoch': 0.72}
# {'loss': 1.5115, 'grad_norm': 0.21246416866779327, 'learning_rate': 0.0003, 'epoch': 0.72}
# {'loss': 1.5884, 'grad_norm': 0.20245297253131866, 'learning_rate': 0.0003, 'epoch': 0.72}
# {'loss': 1.7463, 'grad_norm': 0.26047977805137634, 'learning_rate': 0.0003, 'epoch': 0.73}
# {'loss': 1.5354, 'grad_norm': 0.23245447874069214, 'learning_rate': 0.0003, 'epoch': 0.73}
# {'loss': 1.3575, 'grad_norm': 0.23553051054477692, 'learning_rate': 0.0003, 'epoch': 0.73}
# {'loss': 1.7758, 'grad_norm': 0.24189604818820953, 'learning_rate': 0.0003, 'epoch': 0.74}
# {'loss': 1.3922, 'grad_norm': 0.23255261778831482, 'learning_rate': 0.0003, 'epoch': 0.74}
# {'loss': 1.5186, 'grad_norm': 0.20843695104122162, 'learning_rate': 0.0003, 'epoch': 0.74}
# {'loss': 1.8187, 'grad_norm': 0.20474128425121307, 'learning_rate': 0.0003, 'epoch': 0.75}
# {'loss': 1.5078, 'grad_norm': 0.23436830937862396, 'learning_rate': 0.0003, 'epoch': 0.75}
# {'loss': 1.4302, 'grad_norm': 0.2538909912109375, 'learning_rate': 0.0003, 'epoch': 0.75}
# {'loss': 1.6605, 'grad_norm': 0.24448631703853607, 'learning_rate': 0.0003, 'epoch': 0.76}
# {'loss': 1.7371, 'grad_norm': 0.21674878895282745, 'learning_rate': 0.0003, 'epoch': 0.76}
# {'loss': 1.6118, 'grad_norm': 0.22930757701396942, 'learning_rate': 0.0003, 'epoch': 0.76}
# {'loss': 1.5181, 'grad_norm': 0.22302015125751495, 'learning_rate': 0.0003, 'epoch': 0.76}
# {'loss': 1.4609, 'grad_norm': 0.20501530170440674, 'learning_rate': 0.0003, 'epoch': 0.77}
# {'loss': 1.9589, 'grad_norm': 0.22930598258972168, 'learning_rate': 0.0003, 'epoch': 0.77}
# {'loss': 1.2347, 'grad_norm': 0.17543502151966095, 'learning_rate': 0.0003, 'epoch': 0.77}
# {'loss': 1.2771, 'grad_norm': 0.21265771985054016, 'learning_rate': 0.0003, 'epoch': 0.78}
# {'loss': 1.8257, 'grad_norm': 0.25758713483810425, 'learning_rate': 0.0003, 'epoch': 0.78}
# {'loss': 1.4136, 'grad_norm': 0.23045802116394043, 'learning_rate': 0.0003, 'epoch': 0.78}
# {'loss': 1.2044, 'grad_norm': 0.18797826766967773, 'learning_rate': 0.0003, 'epoch': 0.79}
# {'loss': 1.6925, 'grad_norm': 0.2432391196489334, 'learning_rate': 0.0003, 'epoch': 0.79}
# {'loss': 2.2426, 'grad_norm': 0.22760771214962006, 'learning_rate': 0.0003, 'epoch': 0.79}
# {'loss': 1.5171, 'grad_norm': 0.23867180943489075, 'learning_rate': 0.0003, 'epoch': 0.8}
# {'loss': 1.9092, 'grad_norm': 0.22878092527389526, 'learning_rate': 0.0003, 'epoch': 0.8}
# {'loss': 1.8885, 'grad_norm': 0.2458084374666214, 'learning_rate': 0.0003, 'epoch': 0.8}
# {'loss': 1.7073, 'grad_norm': 0.20956677198410034, 'learning_rate': 0.0003, 'epoch': 0.81}
# {'loss': 1.5249, 'grad_norm': 0.23826803267002106, 'learning_rate': 0.0003, 'epoch': 0.81}
# {'loss': 1.4645, 'grad_norm': 0.1909484714269638, 'learning_rate': 0.0003, 'epoch': 0.81}
# {'loss': 1.5615, 'grad_norm': 0.273696631193161, 'learning_rate': 0.0003, 'epoch': 0.82}
# {'loss': 1.5968, 'grad_norm': 0.24323973059654236, 'learning_rate': 0.0003, 'epoch': 0.82}
# {'loss': 1.6141, 'grad_norm': 0.21782277524471283, 'learning_rate': 0.0003, 'epoch': 0.82}
# {'loss': 1.481, 'grad_norm': 0.20383945107460022, 'learning_rate': 0.0003, 'epoch': 0.83}
# {'loss': 1.0856, 'grad_norm': 0.20003816485404968, 'learning_rate': 0.0003, 'epoch': 0.83}
# {'loss': 1.3875, 'grad_norm': 0.23224496841430664, 'learning_rate': 0.0003, 'epoch': 0.83}
# {'loss': 1.5158, 'grad_norm': 0.252747505903244, 'learning_rate': 0.0003, 'epoch': 0.84}
# {'loss': 1.3775, 'grad_norm': 0.23671527206897736, 'learning_rate': 0.0003, 'epoch': 0.84}
# {'loss': 1.4531, 'grad_norm': 0.24510499835014343, 'learning_rate': 0.0003, 'epoch': 0.84}
# {'loss': 1.5782, 'grad_norm': 0.20574907958507538, 'learning_rate': 0.0003, 'epoch': 0.84}
# {'loss': 1.7283, 'grad_norm': 0.27869635820388794, 'learning_rate': 0.0003, 'epoch': 0.85}
# {'loss': 1.5522, 'grad_norm': 0.20130190253257751, 'learning_rate': 0.0003, 'epoch': 0.85}
# {'loss': 1.6425, 'grad_norm': 0.19265878200531006, 'learning_rate': 0.0003, 'epoch': 0.85}
# {'loss': 1.7068, 'grad_norm': 0.2156674563884735, 'learning_rate': 0.0003, 'epoch': 0.86}
# {'loss': 1.572, 'grad_norm': 0.19291549921035767, 'learning_rate': 0.0003, 'epoch': 0.86}
# {'loss': 1.7029, 'grad_norm': 0.23406662046909332, 'learning_rate': 0.0003, 'epoch': 0.86}
# {'loss': 1.3384, 'grad_norm': 0.2117689549922943, 'learning_rate': 0.0003, 'epoch': 0.87}
# {'loss': 1.4586, 'grad_norm': 0.24599620699882507, 'learning_rate': 0.0003, 'epoch': 0.87}
# {'loss': 1.2838, 'grad_norm': 0.20169956982135773, 'learning_rate': 0.0003, 'epoch': 0.87}
# {'loss': 1.6372, 'grad_norm': 0.19356079399585724, 'learning_rate': 0.0003, 'epoch': 0.88}
# {'loss': 1.5107, 'grad_norm': 0.20748263597488403, 'learning_rate': 0.0003, 'epoch': 0.88}
# {'loss': 1.4819, 'grad_norm': 0.21069678664207458, 'learning_rate': 0.0003, 'epoch': 0.88}
# {'loss': 1.4759, 'grad_norm': 0.2115313559770584, 'learning_rate': 0.0003, 'epoch': 0.89}
# {'loss': 1.4236, 'grad_norm': 0.20012979209423065, 'learning_rate': 0.0003, 'epoch': 0.89}
# {'loss': 1.7892, 'grad_norm': 0.21230211853981018, 'learning_rate': 0.0003, 'epoch': 0.89}
# {'loss': 1.4503, 'grad_norm': 0.1959688663482666, 'learning_rate': 0.0003, 'epoch': 0.9}
# {'loss': 1.6424, 'grad_norm': 0.2711450755596161, 'learning_rate': 0.0003, 'epoch': 0.9}
# {'loss': 1.2156, 'grad_norm': 0.2139197438955307, 'learning_rate': 0.0003, 'epoch': 0.9}
# {'loss': 1.3404, 'grad_norm': 0.17917172610759735, 'learning_rate': 0.0003, 'epoch': 0.91}
# {'loss': 1.4738, 'grad_norm': 0.22458581626415253, 'learning_rate': 0.0003, 'epoch': 0.91}
# {'loss': 1.5929, 'grad_norm': 0.20559141039848328, 'learning_rate': 0.0003, 'epoch': 0.91}
# {'loss': 1.6653, 'grad_norm': 0.20333585143089294, 'learning_rate': 0.0003, 'epoch': 0.92}
# {'loss': 1.655, 'grad_norm': 0.21919946372509003, 'learning_rate': 0.0003, 'epoch': 0.92}
# {'loss': 1.1937, 'grad_norm': 0.1898326575756073, 'learning_rate': 0.0003, 'epoch': 0.92}
# {'loss': 1.4826, 'grad_norm': 0.2181897759437561, 'learning_rate': 0.0003, 'epoch': 0.92}
# {'loss': 1.5952, 'grad_norm': 0.2095005363225937, 'learning_rate': 0.0003, 'epoch': 0.93}
# {'loss': 1.6387, 'grad_norm': 0.2086430937051773, 'learning_rate': 0.0003, 'epoch': 0.93}
# {'loss': 1.5019, 'grad_norm': 0.21387463808059692, 'learning_rate': 0.0003, 'epoch': 0.93}
# {'loss': 1.7528, 'grad_norm': 0.22099356353282928, 'learning_rate': 0.0003, 'epoch': 0.94}
# {'loss': 1.9402, 'grad_norm': 0.20589038729667664, 'learning_rate': 0.0003, 'epoch': 0.94}
# {'loss': 2.0081, 'grad_norm': 0.227546826004982, 'learning_rate': 0.0003, 'epoch': 0.94}
# {'loss': 1.272, 'grad_norm': 0.20798739790916443, 'learning_rate': 0.0003, 'epoch': 0.95}
# {'loss': 1.7366, 'grad_norm': 0.2354811728000641, 'learning_rate': 0.0003, 'epoch': 0.95}
# {'loss': 1.5853, 'grad_norm': 0.21857820451259613, 'learning_rate': 0.0003, 'epoch': 0.95}
# {'loss': 1.6547, 'grad_norm': 0.21921725571155548, 'learning_rate': 0.0003, 'epoch': 0.96}
# {'loss': 1.558, 'grad_norm': 0.184507355093956, 'learning_rate': 0.0003, 'epoch': 0.96}
# {'loss': 1.8099, 'grad_norm': 0.21167607605457306, 'learning_rate': 0.0003, 'epoch': 0.96}
# {'loss': 1.571, 'grad_norm': 0.18741410970687866, 'learning_rate': 0.0003, 'epoch': 0.97}
# {'loss': 1.573, 'grad_norm': 0.21019108593463898, 'learning_rate': 0.0003, 'epoch': 0.97}
# {'loss': 1.3229, 'grad_norm': 0.26520323753356934, 'learning_rate': 0.0003, 'epoch': 0.97}
# {'loss': 1.3796, 'grad_norm': 0.25474485754966736, 'learning_rate': 0.0003, 'epoch': 0.98}
# {'loss': 1.4374, 'grad_norm': 0.2207963615655899, 'learning_rate': 0.0003, 'epoch': 0.98}
# {'loss': 1.5919, 'grad_norm': 0.22319404780864716, 'learning_rate': 0.0003, 'epoch': 0.98}
# {'loss': 1.7843, 'grad_norm': 0.19316883385181427, 'learning_rate': 0.0003, 'epoch': 0.99}
# {'loss': 1.5707, 'grad_norm': 0.22126980125904083, 'learning_rate': 0.0003, 'epoch': 0.99}
# {'loss': 1.3355, 'grad_norm': 0.1846545785665512, 'learning_rate': 0.0003, 'epoch': 0.99}
# {'loss': 1.6562, 'grad_norm': 0.21963690221309662, 'learning_rate': 0.0003, 'epoch': 1.0}
# {'loss': 1.6739, 'grad_norm': 0.23082610964775085, 'learning_rate': 0.0003, 'epoch': 1.0}
# {'loss': 1.0614, 'grad_norm': 0.18306681513786316, 'learning_rate': 0.0003, 'epoch': 1.0}
# {'loss': 1.0196, 'grad_norm': 0.17061279714107513, 'learning_rate': 0.0003, 'epoch': 1.0}
# {'loss': 1.172, 'grad_norm': 0.18918098509311676, 'learning_rate': 0.0003, 'epoch': 1.01}
# {'loss': 1.5758, 'grad_norm': 0.22498345375061035, 'learning_rate': 0.0003, 'epoch': 1.01}
# {'loss': 1.211, 'grad_norm': 0.20605088770389557, 'learning_rate': 0.0003, 'epoch': 1.01}
# {'loss': 1.3204, 'grad_norm': 0.20170432329177856, 'learning_rate': 0.0003, 'epoch': 1.02}
# {'loss': 0.8555, 'grad_norm': 0.23595920205116272, 'learning_rate': 0.0003, 'epoch': 1.02}
# {'loss': 1.7107, 'grad_norm': 0.21145687997341156, 'learning_rate': 0.0003, 'epoch': 1.02}
# {'loss': 1.7349, 'grad_norm': 0.30636078119277954, 'learning_rate': 0.0003, 'epoch': 1.03}
# {'loss': 1.6118, 'grad_norm': 0.3074900507926941, 'learning_rate': 0.0003, 'epoch': 1.03}
# {'loss': 1.4694, 'grad_norm': 0.2859030067920685, 'learning_rate': 0.0003, 'epoch': 1.03}
# {'loss': 1.041, 'grad_norm': 0.22226902842521667, 'learning_rate': 0.0003, 'epoch': 1.04}
# {'loss': 1.5216, 'grad_norm': 0.24332259595394135, 'learning_rate': 0.0003, 'epoch': 1.04}
# {'loss': 1.4583, 'grad_norm': 0.25145164132118225, 'learning_rate': 0.0003, 'epoch': 1.04}
# {'loss': 1.4372, 'grad_norm': 0.23934216797351837, 'learning_rate': 0.0003, 'epoch': 1.05}
# {'loss': 1.2566, 'grad_norm': 0.20123256742954254, 'learning_rate': 0.0003, 'epoch': 1.05}
# {'loss': 1.5091, 'grad_norm': 0.3141218423843384, 'learning_rate': 0.0003, 'epoch': 1.05}
# {'loss': 1.0922, 'grad_norm': 0.22577475011348724, 'learning_rate': 0.0003, 'epoch': 1.06}
# {'loss': 1.1116, 'grad_norm': 0.22583745419979095, 'learning_rate': 0.0003, 'epoch': 1.06}
# {'loss': 1.4157, 'grad_norm': 0.2924991548061371, 'learning_rate': 0.0003, 'epoch': 1.06}
# {'loss': 1.4076, 'grad_norm': 0.28536298871040344, 'learning_rate': 0.0003, 'epoch': 1.07}
# {'loss': 1.782, 'grad_norm': 0.25043782591819763, 'learning_rate': 0.0003, 'epoch': 1.07}
# {'loss': 1.4872, 'grad_norm': 0.31001025438308716, 'learning_rate': 0.0003, 'epoch': 1.07}
# {'loss': 0.8942, 'grad_norm': 0.22432757914066315, 'learning_rate': 0.0003, 'epoch': 1.08}
# {'loss': 1.7186, 'grad_norm': 0.2604289650917053, 'learning_rate': 0.0003, 'epoch': 1.08}
# {'loss': 1.2853, 'grad_norm': 0.28154048323631287, 'learning_rate': 0.0003, 'epoch': 1.08}
# {'loss': 1.39, 'grad_norm': 0.22151438891887665, 'learning_rate': 0.0003, 'epoch': 1.08}
# {'loss': 1.8118, 'grad_norm': 0.25167208909988403, 'learning_rate': 0.0003, 'epoch': 1.09}
# {'loss': 1.2058, 'grad_norm': 0.2723480761051178, 'learning_rate': 0.0003, 'epoch': 1.09}
# {'loss': 1.2225, 'grad_norm': 0.2495550811290741, 'learning_rate': 0.0003, 'epoch': 1.09}
# {'loss': 1.5737, 'grad_norm': 0.3041475713253021, 'learning_rate': 0.0003, 'epoch': 1.1}
# {'loss': 1.5674, 'grad_norm': 0.2852705121040344, 'learning_rate': 0.0003, 'epoch': 1.1}
# {'loss': 1.252, 'grad_norm': 0.21444343030452728, 'learning_rate': 0.0003, 'epoch': 1.1}
# {'loss': 1.3331, 'grad_norm': 0.265791118144989, 'learning_rate': 0.0003, 'epoch': 1.11}
# {'loss': 1.3006, 'grad_norm': 0.22222290933132172, 'learning_rate': 0.0003, 'epoch': 1.11}
# {'loss': 1.3598, 'grad_norm': 0.2488517165184021, 'learning_rate': 0.0003, 'epoch': 1.11}
# {'loss': 1.3123, 'grad_norm': 0.27086877822875977, 'learning_rate': 0.0003, 'epoch': 1.12}
# {'loss': 0.983, 'grad_norm': 0.2546516954898834, 'learning_rate': 0.0003, 'epoch': 1.12}
# {'loss': 1.2108, 'grad_norm': 0.2685859501361847, 'learning_rate': 0.0003, 'epoch': 1.12}
# {'loss': 1.5693, 'grad_norm': 0.31594204902648926, 'learning_rate': 0.0003, 'epoch': 1.13}
# {'loss': 1.8503, 'grad_norm': 0.2801695168018341, 'learning_rate': 0.0003, 'epoch': 1.13}
# {'loss': 1.4225, 'grad_norm': 0.2505979835987091, 'learning_rate': 0.0003, 'epoch': 1.13}
# {'loss': 1.5418, 'grad_norm': 0.29392486810684204, 'learning_rate': 0.0003, 'epoch': 1.14}
# {'loss': 1.3898, 'grad_norm': 0.24482643604278564, 'learning_rate': 0.0003, 'epoch': 1.14}
# {'loss': 1.6155, 'grad_norm': 0.3078708350658417, 'learning_rate': 0.0003, 'epoch': 1.14}
# {'loss': 1.1867, 'grad_norm': 0.23550209403038025, 'learning_rate': 0.0003, 'epoch': 1.15}
# {'loss': 1.6458, 'grad_norm': 0.24583670496940613, 'learning_rate': 0.0003, 'epoch': 1.15}
# {'loss': 1.2173, 'grad_norm': 0.23646263778209686, 'learning_rate': 0.0003, 'epoch': 1.15}
# {'loss': 1.3488, 'grad_norm': 0.27318838238716125, 'learning_rate': 0.0003, 'epoch': 1.16}
# {'loss': 1.3746, 'grad_norm': 0.2713097333908081, 'learning_rate': 0.0003, 'epoch': 1.16}
# {'loss': 1.4838, 'grad_norm': 0.2733055651187897, 'learning_rate': 0.0003, 'epoch': 1.16}
# {'loss': 1.5265, 'grad_norm': 0.27509602904319763, 'learning_rate': 0.0003, 'epoch': 1.16}
# {'loss': 1.4977, 'grad_norm': 0.29349395632743835, 'learning_rate': 0.0003, 'epoch': 1.17}
# {'loss': 1.3, 'grad_norm': 0.2850002348423004, 'learning_rate': 0.0003, 'epoch': 1.17}
# {'loss': 1.2263, 'grad_norm': 0.24850118160247803, 'learning_rate': 0.0003, 'epoch': 1.17}
# {'loss': 0.9083, 'grad_norm': 0.24097447097301483, 'learning_rate': 0.0003, 'epoch': 1.18}
# {'loss': 1.3387, 'grad_norm': 0.3788246214389801, 'learning_rate': 0.0003, 'epoch': 1.18}
# {'loss': 1.3624, 'grad_norm': 0.28060340881347656, 'learning_rate': 0.0003, 'epoch': 1.18}
# {'loss': 1.5541, 'grad_norm': 0.26921552419662476, 'learning_rate': 0.0003, 'epoch': 1.19}
# {'loss': 1.1948, 'grad_norm': 0.3024051785469055, 'learning_rate': 0.0003, 'epoch': 1.19}
# {'loss': 1.4618, 'grad_norm': 0.2833125591278076, 'learning_rate': 0.0003, 'epoch': 1.19}
# {'loss': 1.3056, 'grad_norm': 0.26038724184036255, 'learning_rate': 0.0003, 'epoch': 1.2}
# {'loss': 1.3384, 'grad_norm': 0.2487904131412506, 'learning_rate': 0.0003, 'epoch': 1.2}
# {'loss': 1.822, 'grad_norm': 0.26820752024650574, 'learning_rate': 0.0003, 'epoch': 1.2}
# {'loss': 1.5818, 'grad_norm': 0.27797549962997437, 'learning_rate': 0.0003, 'epoch': 1.21}
# {'loss': 1.4486, 'grad_norm': 0.22394415736198425, 'learning_rate': 0.0003, 'epoch': 1.21}
# {'loss': 1.4035, 'grad_norm': 0.2535633444786072, 'learning_rate': 0.0003, 'epoch': 1.21}
# {'loss': 1.1036, 'grad_norm': 0.25796249508857727, 'learning_rate': 0.0003, 'epoch': 1.22}
# {'loss': 1.5014, 'grad_norm': 0.22740650177001953, 'learning_rate': 0.0003, 'epoch': 1.22}
# {'loss': 1.402, 'grad_norm': 0.30535274744033813, 'learning_rate': 0.0003, 'epoch': 1.22}
# {'loss': 1.1425, 'grad_norm': 0.2690429389476776, 'learning_rate': 0.0003, 'epoch': 1.23}
# {'loss': 1.1338, 'grad_norm': 0.23979221284389496, 'learning_rate': 0.0003, 'epoch': 1.23}
# {'loss': 1.3316, 'grad_norm': 0.2355417162179947, 'learning_rate': 0.0003, 'epoch': 1.23}
# {'loss': 1.3643, 'grad_norm': 0.2299773246049881, 'learning_rate': 0.0003, 'epoch': 1.24}
# {'loss': 1.6026, 'grad_norm': 0.25321894884109497, 'learning_rate': 0.0003, 'epoch': 1.24}
# {'loss': 1.5703, 'grad_norm': 0.27598151564598083, 'learning_rate': 0.0003, 'epoch': 1.24}
# {'loss': 1.4537, 'grad_norm': 0.26026949286460876, 'learning_rate': 0.0003, 'epoch': 1.24}
# {'loss': 1.6575, 'grad_norm': 0.28430676460266113, 'learning_rate': 0.0003, 'epoch': 1.25}
# {'loss': 1.3499, 'grad_norm': 0.2358916699886322, 'learning_rate': 0.0003, 'epoch': 1.25}
# {'loss': 1.4914, 'grad_norm': 0.25377848744392395, 'learning_rate': 0.0003, 'epoch': 1.25}
# {'loss': 0.9665, 'grad_norm': 0.28994283080101013, 'learning_rate': 0.0003, 'epoch': 1.26}
# {'loss': 1.0561, 'grad_norm': 0.2275368571281433, 'learning_rate': 0.0003, 'epoch': 1.26}
# {'loss': 1.6685, 'grad_norm': 0.2768760323524475, 'learning_rate': 0.0003, 'epoch': 1.26}
# {'loss': 1.0671, 'grad_norm': 0.23488983511924744, 'learning_rate': 0.0003, 'epoch': 1.27}
# {'loss': 1.4323, 'grad_norm': 0.2637176513671875, 'learning_rate': 0.0003, 'epoch': 1.27}
# {'loss': 1.3035, 'grad_norm': 0.2781555950641632, 'learning_rate': 0.0003, 'epoch': 1.27}
# {'loss': 1.5741, 'grad_norm': 0.30123719573020935, 'learning_rate': 0.0003, 'epoch': 1.28}
# {'loss': 0.9836, 'grad_norm': 0.1989329606294632, 'learning_rate': 0.0003, 'epoch': 1.28}
# {'loss': 1.3289, 'grad_norm': 0.22368304431438446, 'learning_rate': 0.0003, 'epoch': 1.28}
# {'loss': 1.8135, 'grad_norm': 0.2438095510005951, 'learning_rate': 0.0003, 'epoch': 1.29}
# {'loss': 1.2023, 'grad_norm': 0.2154892385005951, 'learning_rate': 0.0003, 'epoch': 1.29}
# {'loss': 1.2281, 'grad_norm': 0.22428788244724274, 'learning_rate': 0.0003, 'epoch': 1.29}
# {'loss': 1.5565, 'grad_norm': 0.25634005665779114, 'learning_rate': 0.0003, 'epoch': 1.3}
# {'loss': 1.3996, 'grad_norm': 0.24927201867103577, 'learning_rate': 0.0003, 'epoch': 1.3}
# {'loss': 1.3186, 'grad_norm': 0.27187952399253845, 'learning_rate': 0.0003, 'epoch': 1.3}
# {'loss': 1.2068, 'grad_norm': 0.2872852683067322, 'learning_rate': 0.0003, 'epoch': 1.31}
# {'loss': 1.4831, 'grad_norm': 0.23513615131378174, 'learning_rate': 0.0003, 'epoch': 1.31}
# {'loss': 1.4256, 'grad_norm': 0.24104361236095428, 'learning_rate': 0.0003, 'epoch': 1.31}
# {'loss': 1.14, 'grad_norm': 0.24773986637592316, 'learning_rate': 0.0003, 'epoch': 1.32}
# {'loss': 1.4456, 'grad_norm': 0.24113678932189941, 'learning_rate': 0.0003, 'epoch': 1.32}
# {'loss': 1.4714, 'grad_norm': 0.29696956276893616, 'learning_rate': 0.0003, 'epoch': 1.32}
# {'loss': 1.1345, 'grad_norm': 0.30038079619407654, 'learning_rate': 0.0003, 'epoch': 1.32}
# {'loss': 1.209, 'grad_norm': 0.42181336879730225, 'learning_rate': 0.0003, 'epoch': 1.33}
# {'loss': 1.3872, 'grad_norm': 0.24767595529556274, 'learning_rate': 0.0003, 'epoch': 1.33}
# {'loss': 1.5714, 'grad_norm': 0.25543272495269775, 'learning_rate': 0.0003, 'epoch': 1.33}
# {'loss': 1.4718, 'grad_norm': 0.2760661840438843, 'learning_rate': 0.0003, 'epoch': 1.34}
# {'loss': 1.2808, 'grad_norm': 0.2771352529525757, 'learning_rate': 0.0003, 'epoch': 1.34}
# {'loss': 1.1381, 'grad_norm': 0.26179033517837524, 'learning_rate': 0.0003, 'epoch': 1.34}
# {'loss': 1.1545, 'grad_norm': 0.2540886700153351, 'learning_rate': 0.0003, 'epoch': 1.35}
# {'loss': 1.2512, 'grad_norm': 0.253018319606781, 'learning_rate': 0.0003, 'epoch': 1.35}
# {'loss': 1.6744, 'grad_norm': 0.25856104493141174, 'learning_rate': 0.0003, 'epoch': 1.35}
# {'loss': 1.2042, 'grad_norm': 0.2633807063102722, 'learning_rate': 0.0003, 'epoch': 1.36}
# {'loss': 1.3035, 'grad_norm': 0.2541237771511078, 'learning_rate': 0.0003, 'epoch': 1.36}
# {'loss': 1.1293, 'grad_norm': 0.23206277191638947, 'learning_rate': 0.0003, 'epoch': 1.36}
# {'loss': 1.2276, 'grad_norm': 0.25647881627082825, 'learning_rate': 0.0003, 'epoch': 1.37}
# {'loss': 1.3248, 'grad_norm': 0.3126797676086426, 'learning_rate': 0.0003, 'epoch': 1.37}
# {'loss': 1.2492, 'grad_norm': 0.2288515567779541, 'learning_rate': 0.0003, 'epoch': 1.37}
# {'loss': 1.0158, 'grad_norm': 0.28188326954841614, 'learning_rate': 0.0003, 'epoch': 1.38}
# {'loss': 1.325, 'grad_norm': 0.24558331072330475, 'learning_rate': 0.0003, 'epoch': 1.38}
# {'loss': 1.2423, 'grad_norm': 0.2852236330509186, 'learning_rate': 0.0003, 'epoch': 1.38}
# {'loss': 1.3647, 'grad_norm': 0.25808727741241455, 'learning_rate': 0.0003, 'epoch': 1.39}
# {'loss': 1.6628, 'grad_norm': 0.2965454161167145, 'learning_rate': 0.0003, 'epoch': 1.39}
# {'loss': 1.4483, 'grad_norm': 0.3298811614513397, 'learning_rate': 0.0003, 'epoch': 1.39}
# {'loss': 1.3073, 'grad_norm': 0.24300704896450043, 'learning_rate': 0.0003, 'epoch': 1.4}
# {'loss': 1.3201, 'grad_norm': 0.24964553117752075, 'learning_rate': 0.0003, 'epoch': 1.4}
# {'loss': 1.2069, 'grad_norm': 0.26695623993873596, 'learning_rate': 0.0003, 'epoch': 1.4}
# {'loss': 1.5738, 'grad_norm': 0.31350085139274597, 'learning_rate': 0.0003, 'epoch': 1.4}
# {'loss': 1.5515, 'grad_norm': 0.27596887946128845, 'learning_rate': 0.0003, 'epoch': 1.41}
# {'loss': 1.1876, 'grad_norm': 0.3101606070995331, 'learning_rate': 0.0003, 'epoch': 1.41}
# {'loss': 1.231, 'grad_norm': 0.2522048354148865, 'learning_rate': 0.0003, 'epoch': 1.41}
# {'loss': 1.2229, 'grad_norm': 0.2589019238948822, 'learning_rate': 0.0003, 'epoch': 1.42}
# {'loss': 1.2529, 'grad_norm': 0.25808456540107727, 'learning_rate': 0.0003, 'epoch': 1.42}
# {'loss': 1.6163, 'grad_norm': 0.305331289768219, 'learning_rate': 0.0003, 'epoch': 1.42}
# {'loss': 1.388, 'grad_norm': 0.23923355340957642, 'learning_rate': 0.0003, 'epoch': 1.43}
# {'loss': 1.6729, 'grad_norm': 0.27637621760368347, 'learning_rate': 0.0003, 'epoch': 1.43}
# {'loss': 1.2671, 'grad_norm': 0.2179311215877533, 'learning_rate': 0.0003, 'epoch': 1.43}
# {'loss': 1.2739, 'grad_norm': 0.2522384226322174, 'learning_rate': 0.0003, 'epoch': 1.44}
# {'loss': 1.3887, 'grad_norm': 0.26373913884162903, 'learning_rate': 0.0003, 'epoch': 1.44}
# {'loss': 1.3372, 'grad_norm': 0.24415867030620575, 'learning_rate': 0.0003, 'epoch': 1.44}
# {'loss': 1.1951, 'grad_norm': 0.3070306181907654, 'learning_rate': 0.0003, 'epoch': 1.45}
# {'loss': 1.3928, 'grad_norm': 0.22285833954811096, 'learning_rate': 0.0003, 'epoch': 1.45}
# {'loss': 1.4521, 'grad_norm': 0.2700776755809784, 'learning_rate': 0.0003, 'epoch': 1.45}
# {'loss': 1.449, 'grad_norm': 0.2543882727622986, 'learning_rate': 0.0003, 'epoch': 1.46}
# {'loss': 1.0753, 'grad_norm': 0.2606900632381439, 'learning_rate': 0.0003, 'epoch': 1.46}
# {'loss': 1.2411, 'grad_norm': 0.28889524936676025, 'learning_rate': 0.0003, 'epoch': 1.46}
# {'loss': 1.4441, 'grad_norm': 0.2387663573026657, 'learning_rate': 0.0003, 'epoch': 1.47}
# {'loss': 1.2833, 'grad_norm': 0.25354889035224915, 'learning_rate': 0.0003, 'epoch': 1.47}
# {'loss': 1.5435, 'grad_norm': 0.2862452268600464, 'learning_rate': 0.0003, 'epoch': 1.47}
# {'loss': 1.1078, 'grad_norm': 0.2365594059228897, 'learning_rate': 0.0003, 'epoch': 1.48}
# {'loss': 1.5605, 'grad_norm': 0.2691592574119568, 'learning_rate': 0.0003, 'epoch': 1.48}
# {'loss': 1.3998, 'grad_norm': 0.2774617671966553, 'learning_rate': 0.0003, 'epoch': 1.48}
# {'loss': 1.6615, 'grad_norm': 0.2799481749534607, 'learning_rate': 0.0003, 'epoch': 1.48}
# {'loss': 1.4554, 'grad_norm': 0.2716713547706604, 'learning_rate': 0.0003, 'epoch': 1.49}
# {'loss': 1.6489, 'grad_norm': 0.2839321196079254, 'learning_rate': 0.0003, 'epoch': 1.49}
# {'loss': 1.3428, 'grad_norm': 0.2733663022518158, 'learning_rate': 0.0003, 'epoch': 1.49}
# {'loss': 1.528, 'grad_norm': 0.25124579668045044, 'learning_rate': 0.0003, 'epoch': 1.5}
# {'loss': 1.5581, 'grad_norm': 0.31215816736221313, 'learning_rate': 0.0003, 'epoch': 1.5}
# {'loss': 1.4448, 'grad_norm': 0.27291059494018555, 'learning_rate': 0.0003, 'epoch': 1.5}
# {'loss': 1.2287, 'grad_norm': 0.2281176745891571, 'learning_rate': 0.0003, 'epoch': 1.51}
# {'loss': 1.2618, 'grad_norm': 0.26850080490112305, 'learning_rate': 0.0003, 'epoch': 1.51}
# {'loss': 1.517, 'grad_norm': 0.25139808654785156, 'learning_rate': 0.0003, 'epoch': 1.51}
# {'loss': 1.2302, 'grad_norm': 0.25113019347190857, 'learning_rate': 0.0003, 'epoch': 1.52}
# {'loss': 1.3391, 'grad_norm': 0.22408321499824524, 'learning_rate': 0.0003, 'epoch': 1.52}
# {'loss': 1.7243, 'grad_norm': 0.26680082082748413, 'learning_rate': 0.0003, 'epoch': 1.52}
# {'loss': 1.3149, 'grad_norm': 0.32906728982925415, 'learning_rate': 0.0003, 'epoch': 1.53}
# {'loss': 1.5774, 'grad_norm': 0.26625099778175354, 'learning_rate': 0.0003, 'epoch': 1.53}
# {'loss': 1.0894, 'grad_norm': 0.2722693383693695, 'learning_rate': 0.0003, 'epoch': 1.53}
# {'loss': 1.5217, 'grad_norm': 0.28143641352653503, 'learning_rate': 0.0003, 'epoch': 1.54}
# {'loss': 1.6061, 'grad_norm': 0.29359522461891174, 'learning_rate': 0.0003, 'epoch': 1.54}
# {'loss': 1.1968, 'grad_norm': 0.22790907323360443, 'learning_rate': 0.0003, 'epoch': 1.54}
# {'loss': 1.6011, 'grad_norm': 0.24299636483192444, 'learning_rate': 0.0003, 'epoch': 1.55}
# {'loss': 1.3466, 'grad_norm': 0.22724342346191406, 'learning_rate': 0.0003, 'epoch': 1.55}
# {'loss': 1.2535, 'grad_norm': 0.23505951464176178, 'learning_rate': 0.0003, 'epoch': 1.55}
# {'loss': 1.6918, 'grad_norm': 0.27666616439819336, 'learning_rate': 0.0003, 'epoch': 1.56}
# {'loss': 1.1989, 'grad_norm': 0.26260659098625183, 'learning_rate': 0.0003, 'epoch': 1.56}
# {'loss': 1.2333, 'grad_norm': 0.25772422552108765, 'learning_rate': 0.0003, 'epoch': 1.56}
# {'loss': 1.3115, 'grad_norm': 0.33998459577560425, 'learning_rate': 0.0003, 'epoch': 1.56}
# {'loss': 1.3132, 'grad_norm': 0.28244855999946594, 'learning_rate': 0.0003, 'epoch': 1.57}
# {'loss': 1.2191, 'grad_norm': 0.28293147683143616, 'learning_rate': 0.0003, 'epoch': 1.57}
# {'loss': 1.5538, 'grad_norm': 0.28236132860183716, 'learning_rate': 0.0003, 'epoch': 1.57}
# {'loss': 1.6337, 'grad_norm': 0.26945143938064575, 'learning_rate': 0.0003, 'epoch': 1.58}
# {'loss': 1.1396, 'grad_norm': 0.21280382573604584, 'learning_rate': 0.0003, 'epoch': 1.58}
# {'loss': 1.2168, 'grad_norm': 0.22697386145591736, 'learning_rate': 0.0003, 'epoch': 1.58}
# {'loss': 1.7394, 'grad_norm': 0.276534765958786, 'learning_rate': 0.0003, 'epoch': 1.59}
# {'loss': 1.1869, 'grad_norm': 0.22995887696743011, 'learning_rate': 0.0003, 'epoch': 1.59}
# {'loss': 1.5088, 'grad_norm': 0.28537753224372864, 'learning_rate': 0.0003, 'epoch': 1.59}
# {'loss': 1.2092, 'grad_norm': 0.26201072335243225, 'learning_rate': 0.0003, 'epoch': 1.6}
# {'loss': 1.5775, 'grad_norm': 0.30795910954475403, 'learning_rate': 0.0003, 'epoch': 1.6}
# {'loss': 1.576, 'grad_norm': 0.2527391016483307, 'learning_rate': 0.0003, 'epoch': 1.6}
# {'loss': 1.4511, 'grad_norm': 0.2977212071418762, 'learning_rate': 0.0003, 'epoch': 1.61}
# {'loss': 0.9956, 'grad_norm': 0.2479688972234726, 'learning_rate': 0.0003, 'epoch': 1.61}
# {'loss': 1.1015, 'grad_norm': 0.24924154579639435, 'learning_rate': 0.0003, 'epoch': 1.61}
# {'loss': 1.1606, 'grad_norm': 0.3036375939846039, 'learning_rate': 0.0003, 'epoch': 1.62}
# {'loss': 1.4495, 'grad_norm': 0.30782681703567505, 'learning_rate': 0.0003, 'epoch': 1.62}
# {'loss': 1.3466, 'grad_norm': 0.25976860523223877, 'learning_rate': 0.0003, 'epoch': 1.62}
# {'loss': 1.4287, 'grad_norm': 0.33528757095336914, 'learning_rate': 0.0003, 'epoch': 1.63}
# {'loss': 1.2996, 'grad_norm': 0.22888509929180145, 'learning_rate': 0.0003, 'epoch': 1.63}
# {'loss': 1.2078, 'grad_norm': 0.23436304926872253, 'learning_rate': 0.0003, 'epoch': 1.63}
# {'loss': 1.778, 'grad_norm': 0.2881903648376465, 'learning_rate': 0.0003, 'epoch': 1.64}
# {'loss': 1.9618, 'grad_norm': 0.2858888804912567, 'learning_rate': 0.0003, 'epoch': 1.64}
# {'loss': 1.1618, 'grad_norm': 0.25456854701042175, 'learning_rate': 0.0003, 'epoch': 1.64}
# {'loss': 1.177, 'grad_norm': 0.23776446282863617, 'learning_rate': 0.0003, 'epoch': 1.64}
# {'loss': 1.1707, 'grad_norm': 0.2358369529247284, 'learning_rate': 0.0003, 'epoch': 1.65}
# {'loss': 1.4214, 'grad_norm': 0.2870286703109741, 'learning_rate': 0.0003, 'epoch': 1.65}
# {'loss': 1.5684, 'grad_norm': 0.2741904854774475, 'learning_rate': 0.0003, 'epoch': 1.65}
# {'loss': 1.3775, 'grad_norm': 0.25060439109802246, 'learning_rate': 0.0003, 'epoch': 1.66}
# {'loss': 1.4396, 'grad_norm': 0.27922889590263367, 'learning_rate': 0.0003, 'epoch': 1.66}
# {'loss': 1.5345, 'grad_norm': 0.28598132729530334, 'learning_rate': 0.0003, 'epoch': 1.66}
# {'loss': 1.6979, 'grad_norm': 0.315355122089386, 'learning_rate': 0.0003, 'epoch': 1.67}
# {'loss': 1.1497, 'grad_norm': 0.20832319557666779, 'learning_rate': 0.0003, 'epoch': 1.67}
# {'loss': 1.3181, 'grad_norm': 0.23657451570034027, 'learning_rate': 0.0003, 'epoch': 1.67}
# {'loss': 1.3912, 'grad_norm': 0.23783722519874573, 'learning_rate': 0.0003, 'epoch': 1.68}
# {'loss': 1.2085, 'grad_norm': 0.3056313395500183, 'learning_rate': 0.0003, 'epoch': 1.68}
# {'loss': 1.1927, 'grad_norm': 0.23265288770198822, 'learning_rate': 0.0003, 'epoch': 1.68}
# {'loss': 1.3228, 'grad_norm': 0.2328839898109436, 'learning_rate': 0.0003, 'epoch': 1.69}
# {'loss': 1.689, 'grad_norm': 0.2618285119533539, 'learning_rate': 0.0003, 'epoch': 1.69}
# {'loss': 1.4723, 'grad_norm': 0.28339773416519165, 'learning_rate': 0.0003, 'epoch': 1.69}
# {'loss': 1.5921, 'grad_norm': 0.29478251934051514, 'learning_rate': 0.0003, 'epoch': 1.7}
# {'loss': 1.5876, 'grad_norm': 0.27393099665641785, 'learning_rate': 0.0003, 'epoch': 1.7}
# {'loss': 1.2846, 'grad_norm': 0.29559656977653503, 'learning_rate': 0.0003, 'epoch': 1.7}
# {'loss': 1.4775, 'grad_norm': 0.2814454734325409, 'learning_rate': 0.0003, 'epoch': 1.71}
# {'loss': 1.0133, 'grad_norm': 0.2519916594028473, 'learning_rate': 0.0003, 'epoch': 1.71}
# {'loss': 1.3743, 'grad_norm': 0.25572431087493896, 'learning_rate': 0.0003, 'epoch': 1.71}
# {'loss': 1.6647, 'grad_norm': 0.2846616506576538, 'learning_rate': 0.0003, 'epoch': 1.72}
# {'loss': 1.4641, 'grad_norm': 0.2380606085062027, 'learning_rate': 0.0003, 'epoch': 1.72}
# {'loss': 1.3503, 'grad_norm': 0.28096240758895874, 'learning_rate': 0.0003, 'epoch': 1.72}
# {'loss': 1.5764, 'grad_norm': 0.2636552155017853, 'learning_rate': 0.0003, 'epoch': 1.72}
# {'loss': 1.3685, 'grad_norm': 0.2451029121875763, 'learning_rate': 0.0003, 'epoch': 1.73}
# {'loss': 1.4634, 'grad_norm': 0.2741929590702057, 'learning_rate': 0.0003, 'epoch': 1.73}
# {'loss': 1.6886, 'grad_norm': 0.2953261435031891, 'learning_rate': 0.0003, 'epoch': 1.73}
# {'loss': 1.3784, 'grad_norm': 0.31923478841781616, 'learning_rate': 0.0003, 'epoch': 1.74}
# {'loss': 1.2838, 'grad_norm': 0.2544088065624237, 'learning_rate': 0.0003, 'epoch': 1.74}
# {'loss': 1.2713, 'grad_norm': 0.2644839286804199, 'learning_rate': 0.0003, 'epoch': 1.74}
# {'loss': 1.4286, 'grad_norm': 0.3051242530345917, 'learning_rate': 0.0003, 'epoch': 1.75}
# {'loss': 1.2532, 'grad_norm': 0.27256521582603455, 'learning_rate': 0.0003, 'epoch': 1.75}
# {'loss': 1.3799, 'grad_norm': 0.27047979831695557, 'learning_rate': 0.0003, 'epoch': 1.75}
# {'loss': 1.4703, 'grad_norm': 0.305782675743103, 'learning_rate': 0.0003, 'epoch': 1.76}
# {'loss': 1.3961, 'grad_norm': 0.2779965102672577, 'learning_rate': 0.0003, 'epoch': 1.76}
# {'loss': 1.4295, 'grad_norm': 0.2905580401420593, 'learning_rate': 0.0003, 'epoch': 1.76}
# {'loss': 1.3768, 'grad_norm': 0.251992404460907, 'learning_rate': 0.0003, 'epoch': 1.77}
# {'loss': 1.5374, 'grad_norm': 0.2967507839202881, 'learning_rate': 0.0003, 'epoch': 1.77}
# {'loss': 1.5508, 'grad_norm': 0.2789076268672943, 'learning_rate': 0.0003, 'epoch': 1.77}
# {'loss': 1.3119, 'grad_norm': 0.26110509037971497, 'learning_rate': 0.0003, 'epoch': 1.78}
# {'loss': 1.1291, 'grad_norm': 0.24595622718334198, 'learning_rate': 0.0003, 'epoch': 1.78}
# {'loss': 1.1959, 'grad_norm': 0.2381688505411148, 'learning_rate': 0.0003, 'epoch': 1.78}
# {'loss': 1.7397, 'grad_norm': 0.2787625193595886, 'learning_rate': 0.0003, 'epoch': 1.79}
# {'loss': 1.0279, 'grad_norm': 0.22909390926361084, 'learning_rate': 0.0003, 'epoch': 1.79}
# {'loss': 1.5038, 'grad_norm': 0.27826282382011414, 'learning_rate': 0.0003, 'epoch': 1.79}
# {'loss': 1.4905, 'grad_norm': 0.28962358832359314, 'learning_rate': 0.0003, 'epoch': 1.8}
# {'loss': 1.4188, 'grad_norm': 0.24275797605514526, 'learning_rate': 0.0003, 'epoch': 1.8}
# {'loss': 1.4229, 'grad_norm': 0.24228094518184662, 'learning_rate': 0.0003, 'epoch': 1.8}
# {'loss': 1.2579, 'grad_norm': 0.22380590438842773, 'learning_rate': 0.0003, 'epoch': 1.8}
# {'loss': 1.3991, 'grad_norm': 0.25175508856773376, 'learning_rate': 0.0003, 'epoch': 1.81}
# {'loss': 1.8305, 'grad_norm': 0.2856065630912781, 'learning_rate': 0.0003, 'epoch': 1.81}
# {'loss': 1.4023, 'grad_norm': 0.25444063544273376, 'learning_rate': 0.0003, 'epoch': 1.81}
# {'loss': 1.1658, 'grad_norm': 0.21885356307029724, 'learning_rate': 0.0003, 'epoch': 1.82}
# {'loss': 1.3482, 'grad_norm': 0.2441968321800232, 'learning_rate': 0.0003, 'epoch': 1.82}
# {'loss': 1.4263, 'grad_norm': 0.2457789182662964, 'learning_rate': 0.0003, 'epoch': 1.82}
# {'loss': 1.2993, 'grad_norm': 0.2565532326698303, 'learning_rate': 0.0003, 'epoch': 1.83}
# {'loss': 1.3899, 'grad_norm': 0.276082843542099, 'learning_rate': 0.0003, 'epoch': 1.83}
# {'loss': 1.0537, 'grad_norm': 0.24634699523448944, 'learning_rate': 0.0003, 'epoch': 1.83}
# {'loss': 1.6144, 'grad_norm': 0.2455407977104187, 'learning_rate': 0.0003, 'epoch': 1.84}
# {'loss': 1.4628, 'grad_norm': 0.24424055218696594, 'learning_rate': 0.0003, 'epoch': 1.84}
# {'loss': 1.5638, 'grad_norm': 0.23516909778118134, 'learning_rate': 0.0003, 'epoch': 1.84}
# {'loss': 1.3906, 'grad_norm': 0.3034379482269287, 'learning_rate': 0.0003, 'epoch': 1.85}
# {'loss': 1.2954, 'grad_norm': 0.24674862623214722, 'learning_rate': 0.0003, 'epoch': 1.85}
# {'loss': 1.1947, 'grad_norm': 0.30168378353118896, 'learning_rate': 0.0003, 'epoch': 1.85}
# {'loss': 1.4547, 'grad_norm': 0.2651521861553192, 'learning_rate': 0.0003, 'epoch': 1.86}
# {'loss': 1.3204, 'grad_norm': 0.2261260598897934, 'learning_rate': 0.0003, 'epoch': 1.86}
# {'loss': 1.2127, 'grad_norm': 0.24551436305046082, 'learning_rate': 0.0003, 'epoch': 1.86}
# {'loss': 1.4481, 'grad_norm': 0.2658191919326782, 'learning_rate': 0.0003, 'epoch': 1.87}
# {'loss': 1.682, 'grad_norm': 0.2561931312084198, 'learning_rate': 0.0003, 'epoch': 1.87}
# {'loss': 1.4512, 'grad_norm': 0.31886133551597595, 'learning_rate': 0.0003, 'epoch': 1.87}
# {'loss': 1.2905, 'grad_norm': 0.25756633281707764, 'learning_rate': 0.0003, 'epoch': 1.88}
# {'loss': 1.0771, 'grad_norm': 0.21958555281162262, 'learning_rate': 0.0003, 'epoch': 1.88}
# {'loss': 1.2085, 'grad_norm': 0.27604010701179504, 'learning_rate': 0.0003, 'epoch': 1.88}
# {'loss': 1.4171, 'grad_norm': 0.2770652770996094, 'learning_rate': 0.0003, 'epoch': 1.88}
# {'loss': 1.5281, 'grad_norm': 0.25486448407173157, 'learning_rate': 0.0003, 'epoch': 1.89}
# {'loss': 1.2019, 'grad_norm': 0.23199160397052765, 'learning_rate': 0.0003, 'epoch': 1.89}
# {'loss': 1.2737, 'grad_norm': 0.26507285237312317, 'learning_rate': 0.0003, 'epoch': 1.89}
# {'loss': 1.2913, 'grad_norm': 0.25708669424057007, 'learning_rate': 0.0003, 'epoch': 1.9}
# {'loss': 1.3081, 'grad_norm': 0.30484098196029663, 'learning_rate': 0.0003, 'epoch': 1.9}
# {'loss': 1.3918, 'grad_norm': 0.24506990611553192, 'learning_rate': 0.0003, 'epoch': 1.9}
# {'loss': 1.4297, 'grad_norm': 0.27698665857315063, 'learning_rate': 0.0003, 'epoch': 1.91}
# {'loss': 1.2193, 'grad_norm': 0.25115370750427246, 'learning_rate': 0.0003, 'epoch': 1.91}
# {'loss': 1.3964, 'grad_norm': 0.2980114817619324, 'learning_rate': 0.0003, 'epoch': 1.91}
# {'loss': 1.097, 'grad_norm': 0.2577498257160187, 'learning_rate': 0.0003, 'epoch': 1.92}
# {'loss': 1.4141, 'grad_norm': 0.3009359836578369, 'learning_rate': 0.0003, 'epoch': 1.92}
# {'loss': 1.7388, 'grad_norm': 0.3078732490539551, 'learning_rate': 0.0003, 'epoch': 1.92}
# {'loss': 1.2272, 'grad_norm': 0.2794477939605713, 'learning_rate': 0.0003, 'epoch': 1.93}
# {'loss': 1.4889, 'grad_norm': 0.246933713555336, 'learning_rate': 0.0003, 'epoch': 1.93}
# {'loss': 1.5005, 'grad_norm': 0.2734253704547882, 'learning_rate': 0.0003, 'epoch': 1.93}
# {'loss': 1.637, 'grad_norm': 0.26508408784866333, 'learning_rate': 0.0003, 'epoch': 1.94}
# {'loss': 1.075, 'grad_norm': 0.19998937845230103, 'learning_rate': 0.0003, 'epoch': 1.94}
# {'loss': 1.6549, 'grad_norm': 0.27301305532455444, 'learning_rate': 0.0003, 'epoch': 1.94}
# {'loss': 1.394, 'grad_norm': 0.2251371592283249, 'learning_rate': 0.0003, 'epoch': 1.95}
# {'loss': 1.5413, 'grad_norm': 0.2660946249961853, 'learning_rate': 0.0003, 'epoch': 1.95}
# {'loss': 1.3864, 'grad_norm': 0.29464372992515564, 'learning_rate': 0.0003, 'epoch': 1.95}
# {'loss': 1.3629, 'grad_norm': 0.23664526641368866, 'learning_rate': 0.0003, 'epoch': 1.96}
# {'loss': 1.2097, 'grad_norm': 0.2578013241291046, 'learning_rate': 0.0003, 'epoch': 1.96}
# {'loss': 1.4254, 'grad_norm': 0.2768037021160126, 'learning_rate': 0.0003, 'epoch': 1.96}
# {'loss': 1.73, 'grad_norm': 0.34390050172805786, 'learning_rate': 0.0003, 'epoch': 1.96}
# {'loss': 1.3446, 'grad_norm': 0.3484850823879242, 'learning_rate': 0.0003, 'epoch': 1.97}
# {'loss': 1.3439, 'grad_norm': 0.27395644783973694, 'learning_rate': 0.0003, 'epoch': 1.97}
# {'loss': 1.6618, 'grad_norm': 0.2823140025138855, 'learning_rate': 0.0003, 'epoch': 1.97}
# {'loss': 1.1751, 'grad_norm': 0.2537735104560852, 'learning_rate': 0.0003, 'epoch': 1.98}
# {'loss': 1.3614, 'grad_norm': 0.24410143494606018, 'learning_rate': 0.0003, 'epoch': 1.98}
# {'loss': 1.0832, 'grad_norm': 0.23744407296180725, 'learning_rate': 0.0003, 'epoch': 1.98}
# {'loss': 1.3846, 'grad_norm': 0.2670050263404846, 'learning_rate': 0.0003, 'epoch': 1.99}
# {'loss': 1.3925, 'grad_norm': 0.30843493342399597, 'learning_rate': 0.0003, 'epoch': 1.99}
# {'loss': 1.3731, 'grad_norm': 0.26329511404037476, 'learning_rate': 0.0003, 'epoch': 1.99}
# {'loss': 1.2678, 'grad_norm': 0.25536373257637024, 'learning_rate': 0.0003, 'epoch': 2.0}
# {'train_runtime': 5096.3275, 'train_samples_per_second': 3.924, 'train_steps_per_second': 0.122, 'train_loss': 1.5610001765382595, 'epoch': 2.0}
# 100% 624/624 [1:24:56<00:00,  8.17s/it]

# %% [markdown]
# ## 3. Run inference using the fine-tuned model

# %% [markdown]
# load the finetuned model

# %%
pip install mpi4py -i http://pypi.doubanio.com/simple/ --trusted-host pypi.doubanio.com
pip install "peft<0.8.0" deepspeed
pip install optimum
pip install auto-gptq
pip install modelscope
pip install einops transformers_stream_generator
pip install tiktoken
pip install py7zr
#!pip install xformers
pip install accelerate
pip install -i https://pypi.org/simple/ bitsandbytes

# %%
import sys
sys.path.append('/root/sdc1/qwen1.5-4int/qwen/Qwen-7B-Chat-Int4')

# %%
import sys
sys.path.append('/root/sdc1/qwen1.5-4int/qwen/Qwen-7B-Chat-Int4')

from peft import AutoPeftModelForCausalLM

import torch
from transformers import AutoModelForCausalLM, AutoTokenizer
from transformers import GenerationConfig
from qwen_generation_utils import make_context, decode_tokens, get_stop_words_ids
from peft import AutoPeftModelForCausalLM

tokenizer = AutoTokenizer.from_pretrained(
    '/root/sdc1/qwen1.5-4int/model_finetuning',
    pad_token='<|extra_0|>',
    eos_token='<|endoftext|>',
    padding_side='left',
    trust_remote_code=True
)

model = AutoPeftModelForCausalLM.from_pretrained(
    '/root/sdc1/qwen1.5-4int/model_finetuning',
    pad_token_id=tokenizer.pad_token_id,
    device_map="auto",
    trust_remote_code=True
).eval()
# Out:
# ---------------------------------------------------------------------------
# HFValidationError                         Traceback (most recent call last)
# File ~/yes/envs/qwen2/lib/python3.10/site-packages/transformers/utils/hub.py:398, in cached_file(path_or_repo_id, filename, cache_dir, force_download, resume_download, proxies, token, revision, local_files_only, subfolder, repo_type, user_agent, _raise_exceptions_for_gated_repo, _raise_exceptions_for_missing_entries, _raise_exceptions_for_connection_errors, _commit_hash, **deprecated_kwargs)
#     396 try:
#     397     # Load from URL or cache if already cached
# --> 398     resolved_file = hf_hub_download(
#     399         path_or_repo_id,
#     400         filename,
#     401         subfolder=None if len(subfolder) == 0 else subfolder,
#     402         repo_type=repo_type,
#     403         revision=revision,
#     404         cache_dir=cache_dir,
#     405         user_agent=user_agent,
#     406         force_download=force_download,
#     407         proxies=proxies,
#     408         resume_download=resume_download,
#     409         token=token,
#     410         local_files_only=local_files_only,
#     411     )
#     412 except GatedRepoError as e:
#
# File ~/yes/envs/qwen2/lib/python3.10/site-packages/huggingface_hub/utils/_validators.py:111, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#     110 if arg_name in ["repo_id", "from_id", "to_id"]:
# --> 111     validate_repo_id(arg_value)
#     113 elif arg_name == "token" and arg_value is not None:
#
# File ~/yes/envs/qwen2/lib/python3.10/site-packages/huggingface_hub/utils/_validators.py:159, in validate_repo_id(repo_id)
#     158 if repo_id.count("/") > 1:
# --> 159     raise HFValidationError(
#     160         "Repo id must be in the form 'repo_name' or 'namespace/repo_name':"
#     161         f" '{repo_id}'. Use `repo_type` argument if needed."
#     162     )
#     164 if not REPO_ID_REGEX.match(repo_id):
#
# HFValidationError: Repo id must be in the form 'repo_name' or 'namespace/repo_name': '/content/drive/MyDrive/ISS/5005/finetuning/model/qwen/Qwen-7B-Chat-Int4'. Use `repo_type` argument if needed.
#
# The above exception was the direct cause of the following exception:
#
# OSError                                   Traceback (most recent call last)
# Cell In[6], line 20
#      10 from peft import AutoPeftModelForCausalLM
#      12 tokenizer = AutoTokenizer.from_pretrained(
#      13     '/root/sdc1/qwen1.5-4int/model_finetuning',
#      14     pad_token='<|extra_0|>',
#    (...)
#      17     trust_remote_code=True
#      18 )
# ---> 20 model = AutoPeftModelForCausalLM.from_pretrained(
#      21     '/root/sdc1/qwen1.5-4int/model_finetuning',
#      22     pad_token_id=tokenizer.pad_token_id,
#      23     device_map="auto",
#      24     trust_remote_code=True
#      25 ).eval()
#
# File ~/yes/envs/qwen2/lib/python3.10/site-packages/peft/auto.py:101, in _BaseAutoPeftModel.from_pretrained(cls, pretrained_model_name_or_path, adapter_name, is_trainable, config, **kwargs)
#      96 else:
#      97     raise ValueError(
#      98         "Cannot infer the auto class from the config, please make sure that you are loading the correct model for your task type."
#      99     )
# --> 101 base_model = target_class.from_pretrained(base_model_path, **kwargs)
#     103 return cls._target_peft_class.from_pretrained(
#     104     base_model,
#     105     pretrained_model_name_or_path,
#    (...)
#     109     **kwargs,
#     110 )
#
# File ~/yes/envs/qwen2/lib/python3.10/site-packages/transformers/models/auto/auto_factory.py:484, in _BaseAutoModelClass.from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#     481 if commit_hash is None:
#     482     if not isinstance(config, PretrainedConfig):
#     483         # We make a call to the config file first (which may be absent) to get the commit hash as soon as possible
# --> 484         resolved_config_file = cached_file(
#     485             pretrained_model_name_or_path,
#     486             CONFIG_NAME,
#     487             _raise_exceptions_for_gated_repo=False,
#     488             _raise_exceptions_for_missing_entries=False,
#     489             _raise_exceptions_for_connection_errors=False,
#     490             **hub_kwargs,
#     491         )
#     492         commit_hash = extract_commit_hash(resolved_config_file, commit_hash)
#     493     else:
#
# File ~/yes/envs/qwen2/lib/python3.10/site-packages/transformers/utils/hub.py:462, in cached_file(path_or_repo_id, filename, cache_dir, force_download, resume_download, proxies, token, revision, local_files_only, subfolder, repo_type, user_agent, _raise_exceptions_for_gated_repo, _raise_exceptions_for_missing_entries, _raise_exceptions_for_connection_errors, _commit_hash, **deprecated_kwargs)
#     460     raise EnvironmentError(f"There was a specific connection error when trying to load {path_or_repo_id}:\n{err}")
#     461 except HFValidationError as e:
# --> 462     raise EnvironmentError(
#     463         f"Incorrect path_or_model_id: '{path_or_repo_id}'. Please provide either the path to a local folder or the repo_id of a model on the Hub."
#     464     ) from e
#     465 return resolved_file
#
# OSError: Incorrect path_or_model_id: '/content/drive/MyDrive/ISS/5005/finetuning/model/qwen/Qwen-7B-Chat-Int4'. Please provide either the path to a local folder or the repo_id of a model on the Hub.

# %% [markdown]
# pick two samples to inference

# %%
prompt = generate_prompt('精神分裂症导致什么后果？')
response,_ = model.chat(tokenizer,prompt,history = None)
response
# Out:
# '请查询数据库'

# %%
prompt = generate_prompt('十分的不舒服，总是难受，想知道牙龈出血一个月不痛有口臭怎么回事？')
response,_ = model.chat(tokenizer,prompt,history = None)
response
# Out:
# '口腔卫生不良，刷牙方法不正确可以引起牙龈炎、牙周病等，口腔内的食物残渣和细菌分解代谢物，长期沉积就会产生口臭；一些牙周疾病或口腔黏膜疾病，比如智齿冠周炎、口腔溃疡、牙髓炎等也容易导致口臭；另外如果唾液腺功能下降，会导致口腔干燥，也会出现口臭的情况。'

# %% [markdown]
# ### Batch Inference

# %%
model.generation_config = GenerationConfig.from_pretrained('qwen/Qwen-7B-Chat-Int4', pad_token_id=tokenizer.pad_token_id)
model.generation_config.top_p = 0 #refuse model to generate randomly
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# generation_config.json:   0%|          | 0.00/273 [00:00<?, ?B/s]

# %%
import pandas as pd
test = pd.read_json('/content/drive/MyDrive/ISS/5005/finetuning/test.json',lines = True)
test
# Out:
#                                                    ask  \
# 0    爷爷他是因为脑出血后，才有的癫痫病，后台父亲就隔代遗传到了爷爷的癫痫病，癫痫病复发下来，真的...
# 1                                         什么是肾功能异常的症状？
# 2           我母亲今年60岁，今天去医院做了彩超，患胆囊炎。请问：慢性胆囊炎的治疗方法都有什么？
# 3    女宝宝，目前4岁，刚开始，嗓子眼有点痛，察觉到，吞咽好像有点困难，并且，有点发烧也没精神，请...
# 4                                     精神分裂症诊断的主要特征是什么？
# ..                                                 ...
# 995                                   孤独症谱系障碍的治疗方法有哪些？
# 996                                       蜘蛛咬伤会造成什么后果？
# 997              我奶奶的高血压有点严重，我想知道这种高血压食盐摄入量要控制在什么范围内呢？
# 998                                         什么是童年焦虑障碍？
# 999       本人女40岁突然感到了不适，去检查后竟然得了这个病，请问：喉癌晚期不治疗较多还能活多久？
#
#                                                 answer
# 0    你好，根据你描述的情况看来癫痫症状需要有及时的尽早查明原因，早发觉，早治疗，建议患者首先实施...
# 1                                               请查询数据库
# 2    目前皆以切除胆囊疗效最。手术疗法包括1.急性胆囊炎：一般主张经12~24小时积极的内科治疗，...
# 3    扁桃体炎治疗期间饮食也是非常关键的一点，建议宝妈是可以给孩子多吃一些蔬菜和水果的，因为很多水...
# 4                                               请查询数据库
# ..                                                 ...
# 995                                             请查询数据库
# 996                                             请查询数据库
# 997  根据您目前叙述的情况，您说你奶奶高血压有点严重，这种情况确实需要有控制盐的摄取，让你奶奶一天...
# 998                                             请查询数据库
# 999  喉癌是恶性疾病，通过叙述患者这样的情况是很麻烦，喉癌已经做了全切手术，患者要注意自己的饮食作...
#
# [1000 rows x 2 columns]

# %%
for index,row in test.iterrows():
  row['ask'] = generate_prompt(row['ask'])
all_row_text = test['ask'].tolist()

# %%
small_lists = [all_row_text[i:i+10] for i in range(0, len(all_row_text), 10)]

big_list = []
for small_list in small_lists:
    big_list.append(small_list)

# %%
def batch_generate(small_list):
  batch_raw_text = []
  for q in small_list:
      raw_text, _ = make_context(
          tokenizer,
          q,
          system="You are a helpful assistant for medical area.",
          max_window_size=model.generation_config.max_window_size,
          chat_format=model.generation_config.chat_format,
      )
      batch_raw_text.append(raw_text)
  return batch_raw_text

# %% [markdown]
# Inference on the whole testset and save the results (1000 samples, L4 GPU usage 15.9 G, duration 2h , speed 3s/sample)

# %%
#each batch contains 10 samples
batch_response_list = []
for j in range(len(big_list)):
  print(j)
  batch_raw_text = batch_generate(big_list[j])
  batch_input_ids = tokenizer(batch_raw_text, padding='longest')
  batch_input_ids = torch.LongTensor(batch_input_ids['input_ids']).to(model.device)
  batch_out_ids = model.generate(
      input_ids = batch_input_ids,
      return_dict_in_generate=False,
      generation_config=model.generation_config
  )
  padding_lens = [batch_input_ids[i].eq(tokenizer.pad_token_id).sum().item() for i in range(batch_input_ids.size(0))]
  print(padding_lens)
  print(batch_out_ids.shape)
  batch_response = [
      decode_tokens(
          batch_out_ids[i][padding_lens[i]:],
          tokenizer,
          raw_text_len=len(batch_raw_text[i]),
          context_length=(batch_input_ids[i].size(0)-padding_lens[i]),
          chat_format="chatml",
          verbose=False,
          errors='replace'
      ) for i in range(len(batch_raw_text))
  ]
  batch_response_list.append(batch_response)
# Out:
# 0
# [2, 44, 21, 5, 42, 37, 8, 0, 44, 14]
# torch.Size([10, 681])
# 1
# [59, 0, 40, 23, 63, 62, 62, 53, 62, 23]
# torch.Size([10, 701])
# 2
# [40, 10, 16, 43, 42, 27, 43, 39, 0, 9]
# torch.Size([10, 685])
# 3
# [51, 49, 52, 53, 31, 0, 27, 35, 54, 38]
# torch.Size([10, 692])
# 4
# [37, 16, 49, 45, 51, 12, 34, 45, 50, 0]
# torch.Size([10, 689])
# 5
# [0, 24, 41, 40, 43, 38, 37, 8, 41, 39]
# torch.Size([10, 680])
# 6
# [24, 12, 41, 0, 0, 1, 1, 4, 43, 41]
# torch.Size([10, 678])
# 7
# [0, 29, 44, 41, 46, 3, 42, 22, 46, 24]
# torch.Size([10, 683])
# 8
# [30, 14, 0, 31, 4, 15, 48, 28, 47, 49]
# torch.Size([10, 688])
# 9
# [21, 36, 16, 6, 26, 36, 39, 34, 0, 27]
# torch.Size([10, 677])
# 10
# [44, 10, 48, 7, 0, 3, 50, 45, 29, 5]
# torch.Size([10, 687])
# 11
# [0, 50, 17, 11, 55, 29, 16, 20, 38, 24]
# torch.Size([10, 693])
# 12
# [43, 0, 19, 40, 42, 12, 42, 38, 12, 43]
# torch.Size([10, 681])
# 13
# [45, 43, 46, 31, 49, 0, 48, 49, 18, 19]
# torch.Size([10, 686])
# 14
# [36, 39, 13, 22, 36, 9, 0, 32, 40, 41]
# torch.Size([10, 678])
# 15
# [36, 38, 35, 30, 35, 37, 38, 38, 19, 0]
# torch.Size([10, 677])
# 16
# [17, 38, 36, 38, 37, 35, 38, 0, 30, 39]
# torch.Size([10, 678])
# 17
# [6, 42, 7, 8, 22, 20, 44, 45, 0, 43]
# torch.Size([10, 684])
# 18
# [21, 36, 16, 0, 24, 12, 39, 14, 14, 21]
# torch.Size([10, 678])
# 19
# [6, 16, 45, 6, 47, 12, 0, 34, 3, 51]
# torch.Size([10, 688])
# 20
# [40, 41, 39, 36, 38, 24, 38, 0, 39, 37]
# torch.Size([10, 680])
# 21
# [0, 49, 20, 3, 53, 12, 6, 49, 13, 49]
# torch.Size([10, 688])
# 22
# [7, 22, 6, 25, 26, 25, 0, 16, 31, 30]
# torch.Size([10, 668])
# 23
# [0, 29, 47, 10, 49, 48, 48, 29, 27, 47]
# torch.Size([10, 687])
# 24
# [47, 0, 1, 46, 47, 1, 11, 48, 34, 7]
# torch.Size([10, 686])
# 25
# [38, 35, 6, 37, 39, 35, 39, 36, 0, 0]
# torch.Size([10, 676])
# 26
# [48, 12, 49, 0, 46, 15, 28, 46, 48, 14]
# torch.Size([10, 686])
# 27
# [24, 0, 15, 21, 20, 24, 9, 20, 21, 26]
# torch.Size([10, 663])
# 28
# [45, 45, 45, 0, 46, 46, 44, 44, 16, 43]
# torch.Size([10, 684])
# 29
# [7, 30, 0, 38, 6, 38, 15, 41, 39, 16]
# torch.Size([10, 680])
# 30
# [2, 47, 0, 53, 32, 26, 29, 11, 4, 7]
# torch.Size([10, 688])
# 31
# [0, 36, 24, 37, 37, 17, 32, 43, 17, 37]
# torch.Size([10, 679])
# 32
# [15, 37, 23, 19, 0, 35, 38, 22, 5, 18]
# torch.Size([10, 675])
# 33
# [0, 15, 48, 49, 16, 32, 52, 48, 9, 51]
# torch.Size([10, 690])
# 34
# [9, 47, 41, 23, 21, 8, 44, 0, 19, 43]
# torch.Size([10, 683])
# 35
# [14, 36, 43, 17, 1, 26, 7, 0, 13, 40]
# torch.Size([10, 681])
# 36
# [43, 0, 22, 12, 32, 6, 47, 24, 49, 48]
# torch.Size([10, 685])
# 37
# [0, 48, 12, 50, 47, 48, 21, 49, 15, 30]
# torch.Size([10, 688])
# 38
# [6, 49, 13, 14, 31, 47, 0, 44, 21, 49]
# torch.Size([10, 688])
# 39
# [50, 16, 25, 36, 0, 57, 56, 43, 57, 56]
# torch.Size([10, 695])
# 40
# [30, 37, 36, 38, 37, 37, 0, 35, 35, 36]
# torch.Size([10, 676])
# 41
# [41, 42, 44, 46, 40, 4, 42, 0, 41, 27]
# torch.Size([10, 683])
# 42
# [36, 43, 16, 42, 40, 24, 18, 42, 40, 0]
# torch.Size([10, 680])
# 43
# [12, 30, 16, 34, 4, 3, 39, 6, 21, 0]
# torch.Size([10, 679])
# 44
# [0, 36, 14, 12, 39, 34, 39, 35, 0, 39]
# torch.Size([10, 678])
# 45
# [6, 8, 41, 41, 24, 40, 0, 38, 41, 40]
# torch.Size([10, 680])
# 46
# [25, 19, 28, 43, 60, 21, 34, 60, 0, 59]
# torch.Size([10, 698])
# 47
# [41, 0, 42, 8, 29, 41, 25, 10, 44, 11]
# torch.Size([10, 682])
# 48
# [34, 15, 36, 40, 41, 6, 14, 41, 39, 0]
# torch.Size([10, 677])
# 49
# [21, 27, 16, 11, 33, 26, 34, 0, 34, 34]
# torch.Size([10, 672])
# 50
# [18, 36, 17, 15, 39, 18, 39, 4, 35, 0]
# torch.Size([10, 677])
# 51
# [30, 10, 46, 0, 41, 50, 14, 29, 29, 34]
# torch.Size([10, 687])
# 52
# [39, 37, 42, 12, 15, 0, 27, 41, 6, 4]
# torch.Size([10, 681])
# 53
# [15, 16, 14, 0, 39, 38, 1, 39, 16, 31]
# torch.Size([10, 676])
# 54
# [6, 32, 31, 7, 31, 35, 0, 36, 37, 34]
# torch.Size([10, 675])
# 55
# [43, 42, 15, 0, 45, 44, 41, 0, 25, 39]
# torch.Size([10, 682])
# 56
# [51, 51, 51, 51, 54, 10, 52, 52, 46, 0]
# torch.Size([10, 691])
# 57
# [0, 42, 44, 45, 6, 23, 19, 43, 41, 18]
# torch.Size([10, 682])
# 58
# [27, 8, 38, 46, 5, 26, 0, 23, 19, 8]
# torch.Size([10, 683])
# 59
# [41, 63, 14, 58, 59, 60, 0, 27, 62, 31]
# torch.Size([10, 702])
# 60
# [38, 37, 24, 0, 39, 38, 42, 35, 43, 11]
# torch.Size([10, 679])
# 61
# [40, 41, 1, 41, 4, 39, 38, 43, 27, 0]
# torch.Size([10, 680])
# 62
# [1, 48, 0, 46, 45, 7, 45, 34, 46, 5]
# torch.Size([10, 685])
# 63
# [43, 0, 15, 45, 23, 27, 43, 26, 9, 1]
# torch.Size([10, 685])
# 64
# [43, 0, 44, 19, 44, 45, 47, 45, 44, 4]
# torch.Size([10, 684])
# 65
# [43, 12, 45, 11, 14, 0, 48, 31, 8, 30]
# torch.Size([10, 684])
# 66
# [48, 38, 24, 40, 0, 53, 53, 37, 49, 47]
# torch.Size([10, 691])
# 67
# [40, 49, 48, 51, 38, 2, 18, 28, 0, 53]
# torch.Size([10, 692])
# 68
# [31, 37, 46, 35, 42, 20, 1, 43, 0, 0]
# torch.Size([10, 684])
# 69
# [3, 42, 0, 26, 43, 25, 45, 46, 9, 42]
# torch.Size([10, 682])
# 70
# [39, 6, 0, 40, 38, 42, 41, 41, 4, 4]
# torch.Size([10, 680])
# 71
# [27, 48, 25, 0, 10, 50, 9, 50, 25, 38]
# torch.Size([10, 687])
# 72
# [5, 33, 36, 41, 0, 35, 39, 34, 34, 36]
# torch.Size([10, 677])
# 73
# [0, 54, 55, 56, 38, 57, 29, 55, 21, 23]
# torch.Size([10, 696])
# 74
# [41, 38, 37, 40, 7, 39, 8, 0, 36, 40]
# torch.Size([10, 679])
# 75
# [55, 50, 53, 54, 50, 11, 0, 19, 16, 52]
# torch.Size([10, 693])
# 76
# [44, 10, 13, 46, 49, 34, 51, 0, 20, 46]
# torch.Size([10, 689])
# 77
# [24, 0, 41, 11, 44, 30, 7, 15, 0, 42]
# torch.Size([10, 682])
# 78
# [22, 40, 40, 0, 42, 36, 36, 44, 1, 32]
# torch.Size([10, 681])
# 79
# [38, 39, 0, 23, 39, 4, 1, 7, 38, 13]
# torch.Size([10, 679])
# 80
# [45, 43, 43, 45, 28, 49, 34, 3, 0, 46]
# torch.Size([10, 685])
# 81
# [45, 23, 18, 0, 43, 9, 4, 30, 21, 9]
# torch.Size([10, 683])
# 82
# [40, 18, 45, 46, 25, 23, 15, 45, 0, 42]
# torch.Size([10, 684])
# 83
# [0, 40, 37, 37, 23, 14, 27, 34, 16, 10]
# torch.Size([10, 678])
# 84
# [20, 15, 20, 20, 21, 21, 17, 18, 0, 20]
# torch.Size([10, 658])
# 85
# [44, 9, 43, 44, 30, 45, 0, 41, 9, 43]
# torch.Size([10, 685])
# 86
# [40, 15, 23, 33, 4, 38, 36, 0, 2, 36]
# torch.Size([10, 677])
# 87
# [31, 38, 39, 15, 0, 38, 39, 37, 40, 36]
# torch.Size([10, 678])
# 88
# [38, 41, 41, 7, 40, 39, 0, 13, 2, 40]
# torch.Size([10, 680])
# 89
# [11, 0, 0, 51, 32, 50, 37, 28, 51, 36]
# torch.Size([10, 691])
# 90
# [17, 46, 43, 12, 42, 12, 12, 45, 48, 0]
# torch.Size([10, 687])
# 91
# [23, 39, 5, 11, 24, 42, 0, 36, 42, 9]
# torch.Size([10, 679])
# 92
# [43, 45, 21, 22, 10, 2, 36, 43, 0, 32]
# torch.Size([10, 683])
# 93
# [8, 41, 4, 5, 0, 23, 39, 37, 43, 40]
# torch.Size([10, 679])
# 94
# [41, 0, 12, 5, 24, 21, 45, 2, 29, 41]
# torch.Size([10, 304])
# 95
# [37, 32, 53, 55, 19, 41, 53, 51, 20, 0]
# torch.Size([10, 692])
# 96
# [30, 58, 58, 50, 37, 58, 41, 11, 9, 0]
# torch.Size([10, 697])
# 97
# [56, 22, 56, 51, 64, 37, 62, 62, 28, 0]
# torch.Size([10, 699])
# 98
# [19, 22, 34, 18, 41, 1, 15, 5, 4, 0]
# torch.Size([10, 678])
# 99
# [22, 24, 16, 25, 10, 21, 23, 8, 25, 0]
# torch.Size([10, 661])

# %%
prediction = []
for i in range(len(batch_response_list)):
  for j in range(len(batch_response_list[i])):
    prediction.append(batch_response_list[i][j])

# %%
prediction = pd.DataFrame(prediction,columns = ['prediction_finetune'])

# %%
prediction_finetune = pd.merge(
    test,
    prediction,
    left_index = True,
    right_index = True
)

# %%
prediction_finetune.to_json('./prediction_finetune.json')
