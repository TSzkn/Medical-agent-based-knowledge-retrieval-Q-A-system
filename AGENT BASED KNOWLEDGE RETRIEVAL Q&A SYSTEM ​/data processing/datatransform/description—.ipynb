# %%
import pandas as pd
import openai

def summarize_content(content, api_key):
    # Set OpenAI API key
    openai.api_key = api_key
    # Build a conversation flow to simulate a summarization task
    messages = [
        {"role": "system", "content": "I need to generate a description of the node based on the following content, summarize everything below into 30 words or less:"},
        {"role": "user", "content": content}
    ]
    # Call OpenAI API to summarize the content
    response = openai.chat.completions.create(
        model="gpt-3.5-turbo",
        messages=messages,
        temperature=0.5,
        max_tokens=150
    )
    return response.choices[0].message.content.strip()

def generate_descriptions(df, api_key):
    df['description'] = ''  # Add 'description' column
    last_level = None  # Track the level of the last row
    for i in df.index[::-1]:
        content = df.at[i, 'content']
        level = df.at[i, 'level']

        if level == 3 or (last_level is not None and level == last_level):
            # If the current row is a third-level node, or the current row and the last row are at the same level
            df.at[i, 'description'] = summarize_content(content, api_key)
        elif level in [1, 2]:
            # If it is a first or second-level node, summarize the current node and all its child nodes below
            if i < len(df) - 1:
                next_idx = df[(df.index > i) & (df['level'] <= level)].index.min()
                next_idx = next_idx if pd.notna(next_idx) else len(df)
                contents = df.loc[i:next_idx-1, 'content'].str.cat(sep=' ')
                df.at[i, 'description'] = summarize_content(contents, api_key)
        print(f"Processed row {i} / level {level} with description: {df.at[i, 'description']}")
        last_level = level  # Update the last row's level to the current row's level

    return df

# Read CSV file
df = pd.read_csv('health_4.csv')

# Call function to generate descriptions
updated_df = generate_descriptions(df, 'your_api_key_here')

# Save the updated CSV file
updated_df.to_csv('health_4_description.csv', index=False)
print("Updated CSV has been saved.")
# Out:
# Processed row 278 / level 2.0 with description:
# Processed row 277 / level 3.0 with description: 急性感染及创伤处理：抗生素治疗、切开引流、清创湿润换药、手术治疗及支持性措施。
# Processed row 276 / level 3.0 with description: 石鱼刺伤治疗要点：激素、利尿剂、抗感染、器官支持、呼吸治疗。
# Processed row 275 / level 3.0 with description: 处理石头鱼刺伤：拔刺、清洗、热水浸泡、药物治疗、季德胜蛇药片，预防破伤风。
# Processed row 274 / level 3.0 with description: 迅速处置伤口，评估病情，及时抗过敏、抗休克，有效支持器官功能。
# Processed row 273 / level 2.0 with description: 迅速处理伤口，及时识别危象，有效清除毒素，全面治疗并支持器官功能。
# Processed row 272 / level 3.0 with description: 海蜇蛰伤表现为刺痛、瘙痒、红肿，严重者可有水疱、坏死。局部处理、预防破伤风、止痛为主要治疗。
# Processed row 271 / level 3.0 with description: 海蛇咬伤表现为疼痛、麻木，毒牙痕微小，全身中毒症状严重，需早用抗毒血清治疗。
# Processed row 270 / level 2.0 with description: 海蛇咬伤后症状严重，需早用抗蛇毒血清；海蜇蛰伤局部处理，预防感染。
# Processed row 269 / level 3.0 with description: 多项辅助检查异常，包括血常规、肝肾功能、心肌酶谱、凝血功能等，心电图显示心律失常。
# Processed row 268 / level 3.0 with description: 刺伤引起局部及全身症状，包括疼痛、肿胀、麻痹、中毒反应及过敏性休克。
# Processed row 267 / level 3.0 with description: 石头鱼鳍棘刺伤。
# Processed row 266 / level 2.0 with description: 石头鱼鳍棘刺伤引起局部症状，可导致全身中毒反应和过敏性休克，辅助检查显示多种异常。
# Processed row 265 / level 3.0 with description: 急性蜂窝组织炎、皮肤坏死、创伤弧菌感染、破伤风等刺伤后并发症。
# Processed row 264 / level 3.0 with description: 石头鱼鳍棘刺伤后可能引发全身中毒反应，包括恶心、呕吐、皮下瘀斑等症状，极少数病例可危及生命。
# Processed row 263 / level 3.0 with description: 背鳍棘刺伤后局部肿胀、疼痛、灼热、麻痹，向心端扩展，皮肤发黑，持续数月。
# Processed row 262 / level 2.0 with description: 石头鱼刺伤表现多样，轻者局部症状，重者全身中毒，包括局部肿胀、痛苦、中毒症状，甚至生命危险。
# Processed row 261 / level 2.0 with description: 石头鱼背鳍、臀鳍和腹鳍的毒棘及毒囊内含有多种致命毒素，可引起严重中毒症状。
# Processed row 260 / level 2.0 with description: 石头鱼分布广泛，以南海、东海、黄海和渤海为主产区。肉质鲜美，但易刺伤厨师、渔民和游客。
# Processed row 259 / level 1.0 with description: 石头鱼属于毒鲉科，常见于海底，毒性强，刺伤可引起中毒症状，常见于厨师、渔民。需紧急处理和诊疗规范。
# Processed row 258 / level 3.0 with description: 蜘蛛咬伤患者心理干预关键：正确认识蜘蛛咬伤，减少焦虑恐惧，避免心理创伤。
# Processed row 257 / level 3.0 with description: 非新生儿破伤风诊疗规范（2019年版）是国家卫生健康委员会发布的指导标准。
# Processed row 256 / level 3.0 with description: 重度患者中毒应立即注射盐酸肾上腺素，保持气道通畅，急性呼吸衰竭需气管插管+机械通气，避免常规血液净化疗法。
# Processed row 255 / level 3.0 with description: 治疗包括营养支持、维持水电解质平衡，利尿剂减肿，导泻促代谢，抗生素根据情况使用，中医中药对毒虫致伤有疗效。
# Processed row 254 / level 3.0 with description: 国内无抗毒血清，治疗主要是抗组胺药、糖皮质激素，早期使用可减轻炎症和过敏反应。针对毒素引起的症状可使用M型胆碱受体阻滞剂治疗。
# Processed row 253 / level 3.0 with description: 蜘蛛咬伤引起疼痛，需充分镇痛，可选非甾体抗炎药或阿片类药物，烦躁不安者可适度镇静。
# Processed row 252 / level 3.0 with description: 紧急处理咬伤伤口，冲洗消毒，局部封闭或吸排，冷敷肿胀，水疱需切开引流，清洗变态反应部位，使用皮质激素。
# Processed row 251 / level 3.0 with description: 迅速减缓毒液吸收，转送医院救治。保持冷静，远离蜘蛛，记录特征，留存蜘蛛照片或浸泡在酒精中，减少活动，去除限制物品，加压包扎，清洁创口，观察生命体征。
# Processed row 250 / level 2.0 with description: 蜘蛛咬伤急救及治疗要点：辨别咬伤、冷静处理、清洁消毒、镇痛抗毒、支持治疗、心理干预。
# Processed row 249 / level 3.0 with description: 严重疼痛、意识丧失，多脏器功能损伤，包括肾、心、肝功能受损，伴有酸中毒、低血钾、中毒性休克。
# Processed row 248 / level 3.0 with description: 皮肤症状外，出现轻度呼吸、循环系统症状，疼痛加剧，意识改变，心律失常，心肌损伤，肺水肿，肾功能损害，低钾血症。
# Processed row 247 / level 3.0 with description: 局部皮肤红肿热痛，伴头晕、头痛、烦躁、恶心、呕吐、腹痛、腹泻，VAS评分＜3。
# Processed row 246 / level 2.0 with description: 局部皮肤红肿热痛，伴头晕、恶心、腹痛，疼痛程度不同，可伴意识改变、心律失常、器官功能损伤。
# Processed row 245 / level 3.0 with description: 蜘蛛咬伤与其他毒虫咬伤的鉴别及治疗要点。
# Processed row 244 / level 3.0 with description: 毒蛇咬伤呈“..”分布的毒牙咬痕，蜘蛛咬伤有针刺疼痛、皮疹、水肿，需及时使用抗蛇毒血清。
# Processed row 243 / level 2.0 with description: 各类毒虫咬伤的特征及治疗要点：毒蛇咬伤呈“..”分布，蜘蛛咬伤有剧痛、青紫、水肿，需清除毒液，使用抗毒血清。其他毒虫咬伤需根据特征鉴别治疗。
# Processed row 242 / level 2.0 with description: 蜘蛛咬伤诊断依据病史、临床表现，结合地域、蜘蛛种类判断病情。
# Processed row 241 / level 3.0 with description: 蜘蛛咬伤表现为局部症状和全身症状，包括发热、头痛、恶心、呕吐、四肢无力等。
# Processed row 240 / level 3.0 with description: 咬伤区域剧烈疼痛，出现皮疹、水肿、牙痕，可能伴有水泡和组织坏死。
# Processed row 239 / level 2.0 with description: 蜘蛛咬伤表现为局部症状和全身反应，局部疼痛、水肿、皮疹，全身症状有发热、头痛、恶心等。
# Processed row 238 / level 2.0 with description: 蜘蛛毒素是复杂的生物毒素混合物，包含多种小分子物质和蛋白质，可分为神经毒素、坏死毒素和混合毒素。
# Processed row 237 / level 2.0 with description: 蜘蛛咬伤常见于户外活动，多发生在雨季和高温天气。剧毒蜘蛛约有10种，需及时救治。
# Processed row 236 / level 1.0 with description: 蜘蛛广泛分布，咬伤急症，病情症状复杂，缺乏统一诊疗标准，需规范救治流程。
# Processed row 235 / level 2.0 with description: 蜱咬伤的诊疗流程图。
# Processed row 234 / level 2.0 with description: 户外活动需穿长袖衣裤，检查蜱，如被咬需及时就医。
# Processed row 233 / level 3.0 with description: 蜱咬伤患者需定期随访，如出现相关症状应尽早就医治疗。
# Processed row 232 / level 3.0 with description: 紧急处理蜱虫，呼吸受损需氧疗。
# Processed row 231 / level 3.0 with description: 口服或注射抗组胺药物治疗轻度症状。
# Processed row 230 / level 3.0 with description: 用盐酸利多卡因麻醉，镊子去蜱，碘伏消毒，口器残留手术取出，细菌感染抗感染治疗。
# Processed row 229 / level 3.0 with description: 被蜱咬伤需立即就医取出蜱，防过敏休克和瘫痪，注意预防破伤风。
# Processed row 228 / level 2.0 with description: 蜱咬伤需立即医治，去除蜱并评估病情，注意过敏反应和破伤风预防，必要时抗感染和抗过敏治疗。
# Processed row 227 / level 3.0 with description: 蜈蚣咬伤症状多样，局部疼痛、红肿，伴眩晕、恶心等，治疗原则为清除毒素、止痛消肿、抗过敏。
# Processed row 226 / level 3.0 with description: 蚂蚁蜇伤引发局部症状及过敏性休克，需立即脱离环境，评估病情，积极治疗，提供器官支持。
# Processed row 225 / level 3.0 with description: 蜂蜇引起疼痛、红肿，全身中毒症状需警惕。应立即脱离伤环境，评估病情，积极治疗，支持器官功能。
# Processed row 224 / level 2.0 with description: 蜇伤需迅速处理，包括脱离环境、评估病情、抗过敏、抗休克、器官支持；蚂蚁蜇伤需警惕过敏性休克；蜈蚣咬伤需清除毒素、止痛消肿、抗过敏。
# Processed row 223 / level 3.0 with description: 血常规检查显示白细胞计数升高。
# Processed row 222 / level 3.0 with description: 可能患有蜱传播的疾病，如莱姆病或流行性脑膜炎。
# Processed row 221 / level 3.0 with description: 根据流行病学史和临床表现进行诊断。
# Processed row 220 / level 2.0 with description: 诊断通过流行病学史、临床表现，包括蜱叮咬史、体检发现蜱、白细胞计数升高。
# Processed row 219 / level 3.0 with description: 蜱咬可引发多种感染性疾病，表现各异。
# Processed row 218 / level 3.0 with description: 食物过敏反应症状严重，包括呕吐、腹泻、荨麻疹、水肿、呼吸困难、血压下降，甚至过敏性休克。
# Processed row 217 / level 3.0 with description: 神经系统疾病，表现为厌食、嗜睡、共济失调、瘫痪、流涎、眼球震颤、瞳孔不对称、呕吐，最终死于呼吸衰竭。
# Processed row 216 / level 3.0 with description: 过敏反应表现为皮肤症状、呼吸道阻塞和循环衰竭；休克表现为收缩压下降、意识障碍。
# Processed row 215 / level 3.0 with description: 蜱假头插入皮肤造成痣状伤口，红肿流血，触摸坚硬。
# Processed row 214 / level 2.0 with description: 蜱咬伤引发过敏反应和感染性疾病，表现为皮肤症状、呼吸道阻塞、休克和神经系统症状。
# Processed row 213 / level 3.0 with description: 蜱可传播多种病原体致感染性疾病，包括脑炎、出血热、血小板减少综合征、螺旋体病等。
# Processed row 212 / level 3.0 with description: 蜱叮咬引发抗α-半乳糖 IgE，食红肉激活肥大细胞导致延迟过敏反应。
# Processed row 211 / level 3.0 with description: 硬蜱通过神经毒素阻断神经肌肉传导，导致肌肉麻痹，患者可能呼吸衰竭死亡。雌性蜱摄食4-7天后出现症状。
# Processed row 210 / level 3.0 with description: 蜱叮咬引起皮肤损伤、瘙痒、疼痛、出血，严重时可导致感染、组织炎症。
# Processed row 209 / level 2.0 with description: 蜱叮咬会导致局部伤口、疼痛、感染，传播多种疾病，甚至引发肌肉麻痹和呼吸衰竭。
# Processed row 208 / level 2.0 with description: 蜱是寄螨目、蜱总科昆虫，分硬蜱和软蜱两类，传播疾病并寄生于脊椎动物体表。全球有800余种，中国有100余种硬蜱和10余种软蜱，常见种类有全沟硬蜱、草原革蜱等。
# Processed row 207 / level 1.0 with description: 蜱广泛分布，可传播多种疾病。蜱叮咬人引发多种症状，需及时诊疗。
# Processed row 206 / level 2.0 with description: 生成节点描述：数字115。
# Processed row 205 / level 2.0 with description: 积极开展爱国卫生运动，清理垃圾，加强蚂蚁防护，宣传防控知识。
# Processed row 204 / level 3.0 with description: 蚂蚁蜇伤患者心理干预：正确认识蚂蚁蜇伤，消除顾虑，缓解焦虑，促进康复。
# Processed row 203 / level 3.0 with description: 蚂蚁蜇伤需防破伤风，按破伤风预防指南处理。
# Processed row 202 / level 3.0 with description: 软组织感染需抗感染治疗及引流；喉头水肿应早期处理气道及药物；心律失常需针对性药物及原因治疗。
# Processed row 201 / level 3.0 with description: 使用软碱性液冲洗，冷敷减轻蜇伤症状，局部激素药膏治疗，避免弄破水疱，抗过敏处理。
# Processed row 200 / level 3.0 with description: 紧急过敏救治：立即肾上腺素0.01 mg/kg体重，多次给药；配合其他药物和措施，监测生命体征，如有需要进行心肺复苏。
# Processed row 199 / level 3.0 with description: 迅速脱离蚂蚁蜇伤环境，评估病情，抗过敏、休克，及时支持器官功能。
# Processed row 198 / level 2.0 with description: 国内缺乏抗毒血清，蚂蚁蜇伤需迅速救治，包括抗过敏、器官支持等措施，防止感染，心理干预也很重要。
# Processed row 197 / level 2.0 with description: 毒蛇咬伤需抗蛇毒血清；蜈蚣蜇伤需抗过敏治疗；隐翅虫皮炎需清洗止痛。
# Processed row 196 / level 2.0 with description: 根据蚂蚁蜇伤史和临床表现进行诊断，包括蜇伤史和局部症状，可能引发全身过敏反应。
# Processed row 195 / level 3.0 with description: 心电图显示心律失常，彩超可见脓肿低回声团块。
# Processed row 194 / level 3.0 with description: 肝功能、心肌酶谱和凝血功能指标轻度异常。
# Processed row 193 / level 3.0 with description: 根据提供的内容，总结为"请求生成节点描述"。
# Processed row 192 / level 2.0 with description: 肝功能、心肌酶谱、凝血功能异常，心电图显示心律失常，彩超可见脓肿。
# Processed row 191 / level 3.0 with description: 蜇伤后感染、淋巴管炎、喉头水肿、心律失常。
# Processed row 190 / level 3.0 with description: 蚂蚁蜇伤引发过敏性休克，表现为休克症状、皮肤反应、呼吸道阻塞和循环衰竭。
# Processed row 189 / level 3.0 with description: 蜇伤后症状多样，包括瘙痒、皮疹、红斑，严重者可出现头晕、昏迷、抽搐等危及生命。
# Processed row 188 / level 3.0 with description: 蚂蚁蜇伤表现为风团、红晕、水疱、脓疱，严重时可出现大面积局部反应。
# Processed row 187 / level 2.0 with description: 蚂蚁蜇伤可能引发风团、水疱、大面积反应、过敏休克、感染、淋巴管炎、喉头水肿、心律失常。
# Processed row 186 / level 2.0 with description: 蚂蚁蜇伤引发中毒反应，毒液含多种活性成分，导致细胞毒性、过敏反应、神经毒性等症状。
# Processed row 185 / level 2.0 with description: 蚂蚁广泛分布全球，中国主要在南方地区，蚂蚁蜇伤多发生在4-10月，15%产生严重反应，2%系统性反应，火蚁蜇伤更危险。
# Processed row 184 / level 1.0 with description: 蚂蚁是社会性昆虫，全球分布广泛，种类繁多。蚂蚁蜇伤毒液复杂，引发过敏反应，需及时处理。
# Processed row 183 / level 2.0 with description: 海蜇蜇伤诊治流程包括冲洗、止血、消炎、止痛等措施，及时就医，避免过敏反应。
# Processed row 182 / level 3.0 with description: 遇海蜇或碎片勿直接接触，防蜇伤。
# Processed row 181 / level 3.0 with description: 雨后海蜇靠近海边，不宜游泳。
# Processed row 180 / level 2.0 with description: 预防海蜇蜇伤：避免接触海蜇，设置警示牌，不要在雨后海里游泳，不直接用手触摸海蜇。
# Processed row 179 / level 3.0 with description: 海蜇蜇伤患者治疗措施：根据分型采取不同治疗；局部处理、预防破伤风、对症治疗、并发症处理、感染预防。
# Processed row 178 / level 3.0 with description: 海蜇蜇伤处理要点：上岸脱离环境，海水冲洗伤处，用工具清除触手，热水浸泡，及时就医。
# Processed row 177 / level 3.0 with description: 海蜇蜇伤应快速脱离环境，清除毒液，观察生命体征，抗过敏、休克治疗，防并发症。
# Processed row 176 / level 2.0 with description: 海蜇蜇伤应立即脱离环境，清除毒液，观察生命体征，及时治疗并发症，注意预防破伤风。
# Processed row 175 / level 3.0 with description: 遗传性血管性水肿，常染色体显性遗传，皮肤和呼吸道黏膜水肿，易在刺激下发作，呼吸道症状类似海蜇蜇伤。
# Processed row 174 / level 3.0 with description: 迷走血管性晕厥多由情绪反应引起，表现为面色苍白、恶心、出冷汗、晕厥，易误诊为过敏性休克。治疗可用阿托品类药物。
# Processed row 173 / level 3.0 with description: 海胆刺伤急性期红肿疼痛，皮炎紫红斑，全身毒性反应如低血压、呼吸困难，慢性期肉芽肿、关节炎等。
# Processed row 172 / level 3.0 with description: 海蛇咬伤症状：瞬时疼痛、麻木感，毒牙痕，全身中毒症状，呼吸困难，可致死。
# Processed row 171 / level 3.0 with description: 珊瑚刺伤表现为疼痛、红斑、瘙痒，易受损伤部位为前臂、肘、膝，伤口周围红斑几分钟内出现，1-2小时消失。极少数病例可引发严重炎症和坏死。
# Processed row 170 / level 2.0 with description: 海蜇蜇伤需与珊瑚刺伤、海蛇咬伤、海胆刺伤、迷走血管性晕厥和遗传性血管性水肿相鉴别。
# Processed row 169 / level 3.0 with description: 轻型：局部皮损，无全身表现。
# 中型：局部皮损，轻微全身表现。
# 重型：严重全身表现，器官功能障碍。
# Processed row 168 / level 3.0 with description: 海蜇蜇伤史与典型表现可确诊，不明或不典型时需显微镜检查皮肤内刺丝囊。
# Processed row 167 / level 2.0 with description: 海蜇蜇伤可通过临床表现或显微镜检查确诊。轻型局部皮损，中型伴全身表现，重型有严重全身表现和器官功能障碍。
# Processed row 166 / level 2.0 with description: 多数患者白细胞增高，CRP升高，心、肝、肾等脏器指标异常，凝血功能异常，心电图异常，X线表现。
# Processed row 165 / level 3.0 with description: 海蜇毒素引发过敏性休克，表现为血压下降、皮肤症状、呼吸困难、意识丧失等。
# Processed row 164 / level 3.0 with description: 蜇伤后全身过敏反应表现多样，包括皮肤变化、呼吸困难、心血管问题、消化不适、肌肉痛等。
# Processed row 163 / level 3.0 with description: 海蜇蜇伤表现为触电样刺痛、红斑、鞭痕状皮损，伴有烧灼感，痊愈时间取决于伤情严重程度。
# Processed row 162 / level 2.0 with description: 海蜇蜇伤严重程度取决于皮损面积、就诊时间等因素，表现为局部红肿、疼痛，中重型可导致全身过敏反应、休克。
# Processed row 161 / level 2.0 with description: 海蜇毒液含多种毒素，致皮肤坏死、溶血及多器官损伤，引起心、肺、肝、肾等严重毒性。
# Processed row 160 / level 2.0 with description: 沿海地区海蜇蜇伤高发，主要集中在秦皇岛、威海、大连和三亚，发生在6-9月，男性多于女性，病死率约1-3‰。
# Processed row 159 / level 1.0 with description: 海蜇是海洋中腔肠软体动物，腔肠动物门腔肠水母科，透明或半透明，口腕部有毒，常见于中国沿海，可引起严重伤害。高发期6-9月，男性多于女性，病死率约1-3‰。毒液含多种毒素，可引起皮肤损伤、全身过敏反应、休克、死亡。需及时洗净
# Processed row 158 / level 3.0 with description: 需要更多信息来生成节点描述。
# Processed row 157 / level 3.0 with description: 需要根据以下内容生成节点的描述，将以下所有内容总结一下到30字以内：
# Processed row 156 / level 3.0 with description: 请提供要总结的内容，我会尽力帮助您生成节点描述。
# Processed row 155 / level 2.0 with description: 中度及以上病情、多基础疾病，需高级生命支持和血液净化治疗的转诊，注意病情评估和交接。
# Processed row 154 / level 3.0 with description: 需要生成节点描述，请提供相关内容。
# Processed row 153 / level 3.0 with description: 重症监护病房治疗包括血液灌流、肾脏替代疗法、血浆置换、呼吸机辅助通气等。
# Processed row 152 / level 3.0 with description: 需要进行连续肾脏替代治疗以辅助治疗。
# Processed row 151 / level 3.0 with description: 过敏应急处理包括肾上腺素注射，水化碱化治疗，血液灌流，透析，对症支持。
# Processed row 150 / level 3.0 with description: 局部治疗，对症支持，轻度过敏反应可用少量激素或抗组胺药物，观察病情。
# Processed row 149 / level 2.0 with description: 局部治疗对症支持，过敏反应可用激素或抗组胺药物，重者需肾上腺素注射，全身水化及碱化治疗，血液灌流及透析治疗。
# Processed row 148 / level 3.0 with description: 胡蜂蜇伤早评估根据蜇刺数量、过敏反应和器官受损分级处理。轻度至极重度四级，需及时处理。
# Processed row 147 / level 3.0 with description: 蜇伤处理方法：拔除刺、清洗伤口、用食醋涂抹或口服蛇药片。
# Processed row 146 / level 2.0 with description: 胡蜂蜇伤早期救治关键，立即前往医院评估病情，局部清洁处理，早评估分级处理。
# Processed row 145 / level 2.0 with description: 胡蜂蜇伤特征：蜇伤处疼痛、皮肤瘀斑、溃疡凹陷；需用酸性液体处理。
# Processed row 144 / level 2.0 with description: 胡蜂蜇伤病史，出现相关症状可确诊。
# Processed row 143 / level 2.0 with description: 胡蜂毒素引起的多器官功能损害，包括过敏反应、横纹肌溶解、血管内溶血等，严重者可能导致多器官功能障碍综合征。
# Processed row 142 / level 2.0 with description: 胡蜂毒素具有强攻击性，含多种毒素，引发过敏反应和全身炎症，严重时可导致死亡。
# Processed row 141 / level 2.0 with description: 胡蜂季节性蜇伤，主要发生在8-10月，城乡分布广泛，男性中年人为主要受害群体。
# Processed row 140 / level 1.0 with description: 中国植被丰盛，退耕还林后胡蜂增多，蜇伤发生率上升。多种胡蜂分布全国，蜇伤严重可致多器官损害。
# Processed row 139 / level 3.0 with description: 禽类啄伤可能导致破伤风和感染性疾病，需按规范预防，传染性疾病包括多种病原微生物，需专科会诊治疗。
# Processed row 138 / level 3.0 with description: 禽类啄伤需警惕感染，常见细菌包括大肠杆菌和沙门氏菌等。对高危伤口需考虑预防性抗生素应用。
# Processed row 137 / level 3.0 with description: 处理禽类啄伤：伤口冲洗、消毒，眼部特别需专科处理，注意敷料选择和伤口闭合。
# Processed row 136 / level 3.0 with description: 禽类啄伤需动态观察，记录伤口情况，防感染，重视眼部和脑部伤害，注意免疫反应和潜在并发症。
# Processed row 135 / level 2.0 with description: 禽类啄伤需尽早就医，规范处理包括伤情评估、伤口处理、预防感染、破伤风预防和传染病鉴别。需动态观察伤情变化，重视眼部和脑部伤情，及时处理感染风险。
# Processed row 134 / level 3.0 with description: 禽类啄伤易导致感染疾病，需化验检查鉴别，眼部超声检查、CT和MRI有助于诊断。感染主要为大肠杆菌和沙门菌，少见创伤性脑损伤。传染性疾病可通过呼吸道分泌物传播。
# Processed row 133 / level 3.0 with description: 禽类动物啄伤常见损伤包括撕裂、穿刺和撕脱伤，严重程度从轻微皮肤伤到严重组织器官伤，表现为局部红肿、疼痛，甚至贯通伤、骨折。
# Processed row 132 / level 2.0 with description: 禽类啄伤可造成轻微至严重损伤，需注意感染性和传染性疾病的鉴别诊断，眼部超声、CT和MRI检查有助于评估伤情。
# Processed row 131 / level 3.0 with description: 禽类传播病原体致感染，引发全身炎症，甚至脓毒症。
# Processed row 130 / level 3.0 with description: 禽类啄伤引入异物，激发免疫反应，过敏体质者易产生过敏反应。
# Processed row 129 / level 3.0 with description: 禽类喙锐利，硬度高，啄物时施加高压，造成多种机械性损伤。
# Processed row 128 / level 2.0 with description: 禽类啄伤可引起局部和全身反应，包括机械性损伤和感染，需警惕免疫反应和过敏，防止脓毒症。
# Processed row 127 / level 1.0 with description: 全球有9000多种鸟类，中国1300多种，常见啄伤人。啄伤部位多为面部、眼睛，需规范诊疗防感染。
# Processed row 126 / level 3.0 with description: 狂犬病预防应遵循规范指南，注意野猪咬伤可能传播风险。
# Processed row 125 / level 3.0 with description: 猪咬伤需预防破伤风感染，根据规范使用疫苗预防。
# Processed row 124 / level 3.0 with description: 预防伤口感染关键措施：正确清洁、闭合伤口；高风险患者需预防性使用抗生素，根据药敏结果调整治疗。
# Processed row 123 / level 3.0 with description: 伤口冲洗、消毒、清创、闭合及敷料选择等处理要点。
# Processed row 122 / level 3.0 with description: 接诊医师应迅速检查伤口出血情况，实施止血措施并纠正休克，了解患者受伤情况及疫苗接种史，详细记录伤口信息。
# Processed row 121 / level 2.0 with description: 伤口检查、止血、冲洗、消毒、清创、闭合、敷料选择、预防感染、破伤风、狂犬病预防。
# Processed row 120 / level 2.0 with description: 猪咬伤患者需尽快转至有经验的医疗机构，进行伤情评估、伤口处理和预防感染、破伤风、狂犬病。
# Processed row 119 / level 1.0 with description: 猪咬伤需及时处理，包括伤口冲洗、消毒、清创、闭合和预防感染，注意破伤风和狂犬病预防。
# Processed row 118 / level 2.0 with description: 马咬伤需及时诊断治疗，注意止血挽救生命。
# Processed row 117 / level 3.0 with description: 狂犬病预防，注意马的感染风险，遵循相关规范指南进行预防控制。
# Processed row 116 / level 3.0 with description: 马咬伤易感染破伤风，需按规范预防。
# Processed row 115 / level 3.0 with description: 马咬伤易感染多种病原体，伤口清洗、闭合是预防关键。深部伤口及高危因素患者需预防性使用抗生素。
# Processed row 114 / level 3.0 with description: 咬伤局部处置关键：清创消毒，软组织保留，缝合原则。深度清创，适时缝合，延迟深层伤口闭合。
# Processed row 113 / level 3.0 with description: 实验室检查需氧菌和厌氧菌培养，X线和超声检查评估骨折和异物，CT扫描评估咬伤范围。
# Processed row 112 / level 3.0 with description: 接诊医师需迅速处理严重创伤，检查并记录伤口情况，注意过敏史及全身反应，确保患者生命体征稳定。
# Processed row 111 / level 2.0 with description: 马咬伤处理：检查生命体征，询问受伤情况，清洗消毒伤口，实验室检查，X光/超声检查，CT扫描，缝合处理，预防感染。
# Processed row 110 / level 1.0 with description: 马咬伤的处理：包括急救、检查、清创消毒、伤口处理、预防感染和疫苗接种等。
# Processed row 109 / level 3.0 with description: 猕猴B病毒感染表现多样，需及时处理，防止暴露后感染，伐昔洛韦是有效预防药物。
# Processed row 108 / level 3.0 with description: 狂犬病预防：野生猴咬伤可能传播狂犬病，需按规范预防处理。
# Processed row 107 / level 3.0 with description: 猴咬伤易感染破伤风，需按规范使用疫苗预防。
# Processed row 106 / level 3.0 with description: 预防伤口感染关键：正确冲洗伤口、清创、覆盖闭合；高危患者应预防性使用抗生素，根据药敏结果调整治疗。
# Processed row 105 / level 3.0 with description: 伤口冲洗清洁，消毒后清创术处理，慎重选择伤口闭合时机，选择适当敷料促进愈合。
# Processed row 104 / level 3.0 with description: 接诊医师应检查伤口出血、止血措施、休克处理，询问受伤情况、病史，记录伤口信息，联系猴管理者获取相关信息。
# Processed row 103 / level 2.0 with description: 接诊医师应迅速止血、详细询问、冲洗伤口、消毒、清创、闭合伤口，预防感染并进行疫苗预防。
# Processed row 102 / level 2.0 with description: 猴咬伤应立即冲洗伤口，转运至有经验医疗机构，进行伤情评估、处理伤口、预防感染等规范处置。
# Processed row 101 / level 2.0 with description: 猴咬伤诊断关键在于猕猴属咬伤，需考虑B病毒暴露。
# Processed row 100 / level 2.0 with description: 野生猴咬伤可能导致感染狂犬病、破伤风和B病毒，病死率高。
# Processed row 99 / level 1.0 with description: 猴是非人灵长类动物总称，我国猕猴分布广泛，常见于科研和旅游。猴咬伤需及时清洁、预防感染，应规范处理，防止破伤风、狂犬病、B病毒感染。
# Processed row 98 / level 3.0 with description: 蛇咬伤救治要点：快速抗蛇毒血清治疗，咬伤创面处理，并发症处理，中医中药辅助，康复治疗。
# Processed row 97 / level 3.0 with description: 评估生命体征，早期清创处理，包括胸外心脏按压、人工呼吸、伤口清洗、神经毒蛇咬伤处理。
# Processed row 96 / level 3.0 with description: 蛇咬伤应迅速脱离，不要捕捉蛇，保持冷静，观察蛇特征，清洗伤口，紧急就医。
# Processed row 95 / level 2.0 with description: 毒蛇咬伤急救要点：迅速清除毒液，使用抗蛇毒血清，注意伤口处理和并发症预防，中西医结合治疗。
# Processed row 94 / level 3.0 with description: 蛇咬伤特征：毒蛇咬伤有毒牙痕，剧痛、肿胀等全身症状；无毒蛇咬伤呈弧形牙痕，轻微症状。其他毒虫咬伤需根据不同症状进行鉴别治疗。
# Processed row 93 / level 3.0 with description: 蛇咬伤诊断依据病史、临床表现，包括时间、地点、症状、体征，结合地域、蛇种辨认及实验室检查。
# Processed row 92 / level 2.0 with description: 蛇咬伤诊断主要依据病史、临床表现、地域、蛇种辨认、病情严重程度判断。毒蛇咬伤特征为毒牙痕、剧痛、肿胀，需与无毒蛇、其他毒虫咬伤鉴别。
# Processed row 91 / level 3.0 with description: SSS评估方法广泛应用，详细客观，可减少抗蛇毒血清剂量，降低医疗费用。
# Processed row 90 / level 3.0 with description: 蛇咬伤临床评估表，简便实用，适合急诊医师判断严重程度。
# Processed row 89 / level 2.0 with description: 蛇伤评估方法：简易实用，适用急诊；详细客观，广泛应用。
# Processed row 88 / level 3.0 with description: 蛇咬伤可导致血常规、凝血功能、血生化异常，需综合检测明确蛇毒类型。
# Processed row 87 / level 3.0 with description: 无毒蛇咬伤轻微，局部疼痛出血，全身轻度不适；有毒蛇咬伤严重，局部肿胀出血，全身多系统受损。
# Processed row 86 / level 2.0 with description: 无毒蛇咬伤局部疼痛轻微，全身症状不明显；有毒蛇咬伤根据蛇毒种类表现不同，可涉及多系统。血常规、凝血功能、生化检查及特殊检测可帮助诊断。
# Processed row 85 / level 3.0 with description: 蛇毒对多系统造成损害，分为血液毒、神经毒和细胞毒三类，引起不同中毒症状。
# Processed row 84 / level 3.0 with description: 我国常见的伤人蛇种类包括无毒蛇和毒蛇，毒蛇分为不同类型，如神经毒、血液毒、细胞毒和混合毒类。
# Processed row 83 / level 3.0 with description: 毒蛇毒性成分多样，包括酶、多肽、蛋白等，分为神经、血液和细胞毒素三类，各因地域、季节和蛇龄而异。
# Processed row 82 / level 2.0 with description: 毒蛇含多种毒性成分，分为神经、血液和细胞毒素类。我国常见毒蛇有眼镜蛇、竹叶青等，对人体神经、血液、肌肉等系统造成损害。
# Processed row 81 / level 2.0 with description: 蛇咬伤常见，我国每年病例数百万，毒蛇咬伤约10-30万人，70%为青壮年，病死率5%，致残率25%-30%。农村偏远地区多见，缺乏监测报告，发病率严重低估。
# Processed row 80 / level 1.0 with description: 蛇咬伤是常见的动物致伤疾病，毒蛇咬伤需及时救治，防止全身中毒，减少死亡率。【30字】
# Processed row 79 / level 2.0 with description: 啮齿动物致伤的诊治流程。
# Processed row 78 / level 2.0 with description: 与啮齿动物接触者需注意行为规范和防护，保护自己免受伤害。注意婴幼儿和虚弱者的安全，及时处理伤口并预防感染，接种肾综合征出血热疫苗。
# Processed row 77 / level 3.0 with description: 啮齿动物致伤患者需心理治疗与康复干预，重视创伤后应激障碍综合征，及时就诊专门医疗机构。
# Processed row 76 / level 3.0 with description: 鼠咬热、肾综合征出血热、破伤风病原、症状、治疗及预防措施。
# Processed row 75 / level 3.0 with description: 啮齿动物咬伤易引发破伤风，需评估接种史，及时进行免疫预防。
# Processed row 74 / level 3.0 with description: 啮齿动物罕见感染狂犬病，风险极低。预防措施可依据规范指南进行。
# Processed row 73 / level 3.0 with description: 伤口评估、清创处理及抗生素使用要点。初步评估及清洗伤口，根据情况决定缝合，抗生素应根据感染情况选择。
# Processed row 72 / level 2.0 with description: 评估伤口及动物致伤情况，清洗伤口，及早清创缝合，避免感染；针对不同感染风险使用抗生素；注意狂犬病风险，及时处理伤口，预防并发症。
# Processed row 71 / level 2.0 with description: 啮齿动物接触史，诊断主要依据特异创伤表现，需与毒蛇、蜘蛛咬伤鉴别。
# Processed row 70 / level 3.0 with description: 鼠咬热、肾综合征出血热、破伤风：动物传染病，症状多样，需警惕。
# Processed row 69 / level 3.0 with description: 啮齿动物咬伤表现为局部疼痛、肿胀，鼠伤呈锯齿状小齿痕，易发生在手足、颜面部；兔伤呈对称门齿状。
# Processed row 68 / level 2.0 with description: 啮齿动物伤口特征及传染病风险。
# Processed row 67 / level 3.0 with description: 动物传播寄生虫致病原体感染，主要涉及啮齿动物致伤传染病。
# Processed row 66 / level 3.0 with description: 病原体侵入人体引发感染。
# Processed row 65 / level 3.0 with description: 动物咬伤主要由啮齿动物引起，特点为常见于卫生条件差地区，多发生在睡眠中，女性居多，四肢多受伤，婴幼儿致伤最高。
# Processed row 64 / level 2.0 with description: 啮齿动物咬伤引发的机械性损伤，常见于卫生条件差的地区，多发生在睡眠中，女性和婴幼儿为主要受害者。常见传播病原体为细菌、病毒和寄生虫。
# Processed row 63 / level 2.0 with description: 啮齿动物是啃咬食物的哺乳动物，携带多种病原体传播给人类，包括多种疾病，需关注防控。
# Processed row 62 / level 1.0 with description: 啮齿动物致伤，常见传播感染性疾病，需及时清洁伤口、评估风险、预防感染。注意防护与治疗，避免潜在健康威胁。
# Processed row 61 / level 2.0 with description: 猫抓咬伤的诊疗流程。
# Processed row 60 / level 3.0 with description: 猫抓咬伤患者及家属可能出现PTSD，需心理干预。需警惕狂犬病恐怖症，及时就医。
# Processed row 59 / level 3.0 with description: 处理猫伤口感染需局部抗生素软膏，清创消毒；狂犬病需伤口处置、疫苗接种等；破伤风引起全身骨骼肌强直；淋巴结肿大需抗感染治疗。
# Processed row 58 / level 3.0 with description: 猫抓咬后患者需根据暴露情况接种狂犬病和破伤风疫苗预防。
# Processed row 57 / level 3.0 with description: 猫咬伤后需警惕感染，建议对严重伤口或免疫受损者使用抗生素预防或治疗，复杂情况可进行细菌培养。
# Processed row 56 / level 3.0 with description: 活动性出血应压迫止血，伤口处理流程包括伤口分级、冲洗、清创和闭合。
# Processed row 55 / level 3.0 with description: 对猫抓咬伤部位，适当镇痛；躁动患者，镇静治疗。
# Processed row 54 / level 2.0 with description: 猫抓咬伤处理包括止血、清洗、清创、闭合，预防感染、狂犬病和破伤风，注意心理干预。
# Processed row 53 / level 3.0 with description: 猫抓病通过血液、淋巴结脓液和组织检测，诊断汉赛巴尔通体感染。早期白细胞减少，淋巴结化脓后白细胞升高、中性粒细胞增多、血沉加快。
# Processed row 52 / level 3.0 with description: 评估致伤猫来源、猫免疫史和伤者免疫史。
# Processed row 51 / level 3.0 with description: 描述：不同部位、类型的伤口及感染特征。
# Processed row 50 / level 3.0 with description: 紧急处理猫抓咬伤患者，优先评估和稳定ABC原则：A（Airway）B（Breathe）C（Circulation）。
# Processed row 49 / level 3.0 with description: 猫抓咬伤病史，症状、体征及检查结果支持确诊。
# Processed row 48 / level 2.0 with description: 猫抓咬伤患者应综合病史、症状、体征和检查，重点评估ABC原则，包括伤口部位、类型、感染情况，猫和患者的免疫史，进行病原体检测。
# Processed row 47 / level 3.0 with description: 四肢红线，硬肿压痛，全身症状。
# Processed row 46 / level 3.0 with description: 圆形皮疹，红疙瘩小水泡，痒感。
# Processed row 45 / level 3.0 with description: 感染性疾病，皮肤病变后局部淋巴结肿大，伴急性炎症反应，猫抓病的典型表现。
# Processed row 44 / level 3.0 with description: 猫抓咬伤常导致出血、疼痛、肿胀、畸形和功能障碍。
# Processed row 43 / level 2.0 with description: 猫抓病常见于四肢，伤口局部肿胀、疼痛、出血，伴有全身症状，可引发严重并发症。
# Processed row 42 / level 3.0 with description: 猫抓咬伤引发深部感染，病原体包括巴氏杆菌和猫抓病病原体，易导致严重并发症。
# Processed row 41 / level 3.0 with description: 猫抓咬伤多为机械性损伤。
# Processed row 40 / level 2.0 with description: 猫抓咬伤易感染，病原体包括多种细菌，引发并发症，需警惕猫抓病。
# Processed row 39 / level 2.0 with description: 猫抓咬伤风险高，每年我国数万人受伤。
# Processed row 38 / level 1.0 with description: 猫是常见宠物，潜在风险需重视。常见并发症包括猫抓病，需注意预防和治疗。需及时清洁伤口并评估处理，注意心理干预。
# Processed row 37 / level 2.0 with description: 犬咬伤患者及家属心理问题需关注，PTSD风险高，需及早干预，避免不良影响。需重视狂犬病恐怖症，心理治疗至关重要。
# Processed row 36 / level 2.0 with description: 建议对高危伤口采取预防性应用抗生素，密切观察感染情况，必要时进行手术探查和更换敏感抗生素。
# Processed row 35 / level 2.0 with description: 伤口处理要及时止血、清洗冲洗，消毒灭菌，清创扩创，选择合适的闭合方式，延迟闭合适用于特殊情况。
# Processed row 34 / level 2.0 with description: 犬咬伤易感染狂犬病，应按规范预防处理，避免发病。
# Processed row 33 / level 2.0 with description: 犬咬伤需警惕感染破伤风风险，应按规范接种破伤风疫苗预防。
# Processed row 32 / level 2.0 with description: 犬咬伤需全面评估，包括血培养、伤口培养、影像学检查，尤其对于有感染迹象或深部伤口需警惕骨髓炎等并发症。
# Processed row 31 / level 2.0 with description: 犬咬伤易导致多种组织损伤，包括感染。咬伤后治疗延迟是感染发生率高的重要因素之一。
# Processed row 30 / level 2.0 with description: 犬咬伤后生命体征评估及处理：稳定气道、呼吸支持、循环支持、出血控制，镇痛镇静。
# Processed row 29 / level 2.0 with description: 全球犬咬伤严重，中国犬只数量居首，狂犬病传播风险高，死亡率高，对健康和社会造成严重危害。
# Processed row 28 / level 1.0 with description: 犬咬伤是常见的动物致伤，需早期处理、预防感染、注意狂犬病。全球每年犬咬伤近亿次，我国犬只数量最多，需重视处理。
# Processed row 27 / level 2.0 with description: 狂犬病的诊疗流程。
# Processed row 26 / level 2.0 with description: 依据《狂犬病暴露预防处置工作规范》和《狂犬病预防控制技术指南》，进行狂犬病预防。
# Processed row 25 / level 3.0 with description: 狂犬病目前无有效抗病毒药物和免疫调节剂，不推荐使用利巴韦林和疫苗治疗，糖皮质激素可能产生负面影响。
# Processed row 24 / level 3.0 with description: 狂犬病患者重症监护治疗：控制脑水肿、神经保护、呼吸循环支持，重点在于气管插管、机械通气。
# Processed row 23 / level 3.0 with description: 镇静、镇痛、抗唾液、退热、营养支持。
# Processed row 22 / level 3.0 with description: 患者隔离安静，医护执行预防措施，床边护栏防坠床，监测生命体征，给予心理支持。
# Processed row 21 / level 3.0 with description: 狂犬病患者需单间隔离，监测生命体征，重点支持治疗，包括抗病毒和免疫调节，必要时提供脏器支持。
# Processed row 20 / level 2.0 with description: 狂犬病患者需单间隔离，密切监测生命体征，重要脏器支持，镇静、镇痛、营养支持，避免使用抗病毒和免疫调节剂。
# Processed row 19 / level 3.0 with description: 周围神经脱髓鞘疾病，表现为对称性麻痹、感觉障碍，多数可恢复，严重者可致死。治疗以支持为主。
# Processed row 18 / level 3.0 with description: 小儿麻痹症是由脊髓灰质炎病毒引起的急性传染病，主要表现为弛缓性瘫痪，治疗以支持和促进康复为主。
# Processed row 17 / level 3.0 with description: 多种病毒引起软脑膜炎，急性发病，表现为发热、头痛等，脑脊液检查白细胞升高，治疗主要对症支持。
# Processed row 16 / level 3.0 with description: 病毒性脑炎表现为高热、神经症状，易混淆狂犬病；MRI显示脑部病变，治疗需对症支持。
# Processed row 15 / level 3.0 with description: 破伤风是由梭状芽孢杆菌引起的神经毒素中毒疾病，表现为全身骨骼肌痉挛，治疗原则多方面。
# Processed row 14 / level 3.0 with description: 狂犬病引发的少见精神障碍，表现为攻击、咬人、吼叫等症状，与精神因素和性格特征相关，治疗后症状消失。
# Processed row 13 / level 2.0 with description: 狂犬病需与类狂犬病性癔症、破伤风、病毒性脑炎/脑膜炎、脊髓灰质炎、吉兰-巴雷综合征等鉴别。
# Processed row 12 / level 3.0 with description: 根据临床诊断和实验室检测结果，狂犬病确诊标准为病毒分离、抗原检测、核酸检测或中和抗体检测阳性。
# Processed row 11 / level 3.0 with description: 流行病学史符合狂犬病临床症状，可诊断为病例。
# Processed row 10 / level 3.0 with description: 狂犬病诊断需综合流行病学史、临床表现和实验室检查结果。
# Processed row 9 / level 2.0 with description: 狂犬病诊断：结合流行病学史、临床表现和实验室检查结果，确定临床或确诊病例。
# Processed row 8 / level 3.0 with description: 狂犬病病程：持续6-18小时，兴奋-麻痹期，意识逐渐深昏，呼吸麻痹致死。
# Processed row 7 / level 3.0 with description: 恐水症是狂犬病特征性表现，持续1-3天，患者恐水、怕风、咽肌痉挛，可能伴有兴奋、攻击、抽搐、构音障碍等症状。
# Processed row 6 / level 3.0 with description: 流行病毒感染后症状包括低热、乏力、头痛、恶心、烦躁、失眠等，部分患者出现异常感觉和肌肉水肿。
# Processed row 5 / level 3.0 with description: 节点描述：多数情况下持续1-3个月，极少出现在1周内或1年以上。
# Processed row 4 / level 2.0 with description: 狂犬病进展分前驱、兴奋、麻痹三阶段，症状多样，恐水症最典型，可导致呼吸心跳停止死亡。
# Processed row 3 / level 2.0 with description: 狂犬病病毒侵入人体后，经过神经外繁殖、快速逆轴浆移行和扩散阶段，引发神经系统感染，出现吞咽困难、呼吸肌痉挛等症状。
# Processed row 2 / level 2.0 with description: 全球狂犬病主要分布在亚洲和非洲，我国狂犬病发病率逐年下降，犬是主要传染源。
# Processed row 1 / level 2.0 with description: 狂犬病病毒属于Rhabdoviridae科，分为16种病毒，遗传谱系Ⅰ主流，易被灭活，疫苗有效。
# Processed row 0 / level 1.0 with description: 狂犬病是致命的传染病，由狂犬病病毒引起，主要通过动物传播。全球发病率下降，但仍需严格隔离治疗，无特效药物，应依法预防控制。
# Updated CSV has been saved.
